# %% [markdown]
# # TP6
#
# ### `Resolver usando Pandas`
#
# Resolver los ejercicios del TP3 utilizando la librería Pandas.

# %% [markdown]
# ### Ejercicio 1: Cargar Datos de ventas.
#
# El archivo datos.dat contiene el registro de las ventas realizadas.
#
# Tiene un formato de ancho fijo:
# - `fecha`:    10 lugares
# - `producto`: 30 lugares
# - `precio`:   10 lugares
# - `cantidad`:  5 lugares
#
# Hacer una funcion que cargue los datos en un DataFrame de Pandas.

# %%
import pandas as pd
import numpy as np
from numpy.random import randint

def cargar_datos():
    formato_fijo = [10, 30, 10, 5]
    data_frame = pd.read_fwf('datos.dat', widths=formato_fijo, names=['fecha', 'producto', 'precio', 'cantidad'])
    return data_frame

datos = cargar_datos()
print(datos)
# Out:
#          fecha    producto  precio  cantidad
# 0   2024-08-27     Mirinda    1510        14
# 1   2024-08-27     Mirinda    1560        12
# 2   2024-08-28     Torasso     940         8
# 3   2024-08-29  Pepsi Cola    1210        10
# 4   2024-08-30     Mirinda    1520         1
# 5   2024-09-01     Mirinda    1550        15
# 6   2024-09-01      Sprite     810         4
# 7   2024-09-02   Coca Cola    1100         4
# 8   2024-09-02  Pepsi Cola    1220        13
# 9   2024-09-02     Torasso     910         5
# 10  2024-09-02     Torasso     920         3
# 11  2024-09-03   Coca Cola    1020         8
# 12  2024-09-03     Mirinda    1570         7
# 13  2024-09-03     Mirinda    1590         2
# 14  2024-09-04  Pepsi Cola    1220        13
# 15  2024-09-05     Mirinda    1500         3
# 16  2024-09-05  Pepsi Cola    1300         5
# 17  2024-09-06   Coca Cola    1080         1
# 18  2024-09-06      Sprite     860        12
# 19  2024-09-06     Torasso     930         3
# 20  2024-09-07   Coca Cola    1080        14
# 21  2024-09-07      Sprite     870        13
# 22  2024-09-08   Coca Cola    1040        10
# 23  2024-09-08     Mirinda    1580         2
# 24  2024-09-08  Pepsi Cola    1240         9
# 25  2024-09-09     Mirinda    1500         3
# 26  2024-09-09      Sprite     850         9
# 27  2024-09-10     Mirinda    1590         8
# 28  2024-09-10  Pepsi Cola    1250        12
# 29  2024-09-11      Sprite     810         6
# 30  2024-09-11      Sprite     820        14
# 31  2024-09-12   Coca Cola    1080         4
# 32  2024-09-13     Mirinda    1580         5
# 33  2024-09-13  Pepsi Cola    1250        13
# 34  2024-09-14   Coca Cola    1080        15
# 35  2024-09-14  Pepsi Cola    1270        14
# 36  2024-09-15   Coca Cola    1100         1
# 37  2024-09-15     Mirinda    1500        13
# 38  2024-09-15      Sprite     870        14
# 39  2024-09-15     Torasso     900        13

# %% [markdown]
# ### Ejercicio 2: Calcular el total de ventas.
# Hacer una función que sume los importes vendidos (precio * cantidad) y las cantidades.

# %%
def calcular_totales(datos):
    total_cantidad = datos['cantidad'].sum()
    total_precio = datos['precio'].sum()
    total_importe = total_precio * total_cantidad
    return total_importe, total_cantidad

importe, cantidad = calcular_totales(datos)
print(f"Las ventas fueron de ${importe:.2f} en {cantidad} unidades")
# Out:
# Las ventas fueron de $15939300.00 en 335 unidades

# %% [markdown]
# ### Ejercicio 3: Listar las unidades vendidas.
# Listar cuántas unidades se vendieron en total para cada producto

# %%
def unidades_vendidas(datos):
    productos_agrupados = datos.groupby('producto').sum().reset_index()
    return productos_agrupados[['producto', 'cantidad']]

unidades_vendidas(datos)
# Out:
#      producto  cantidad
# 0   Coca Cola        57
# 1     Mirinda        85
# 2  Pepsi Cola        89
# 3      Sprite        72
# 4     Torasso        32

# %% [markdown]
# ###  Ejercicio 4: Listar el precio promedio por producto.
# Hacer un listado del precio promedio por producto.

# %%
def precio_promedio(datos):
    agrupados = datos.groupby('producto').sum()
    precios = datos.groupby('producto')['precio'].sum()
    total_valor = agrupados['cantidad'] * precios
    promedio_precio = total_valor / agrupados['cantidad']
    df_resultado = pd.DataFrame({'producto': promedio_precio.index, 'promedio': promedio_precio.values})
    return df_resultado

precio_promedio(datos)
# Out:
#      producto  promedio
# 0   Coca Cola    8580.0
# 1     Mirinda   18550.0
# 2  Pepsi Cola    9960.0
# 3      Sprite    5890.0
# 4     Torasso    4600.0

# %% [markdown]
# ### Ejercicio 5: Ranking de productos
# Realizar un listado de los 3 productos más vendidos ordenados por la cantidad de unidades vendidas (ordenadas de mayor a menor)

# %%
def ranking_productos(datos, top=3):
    total_cantidad = datos.groupby('producto')['cantidad'].sum().reset_index()
    return total_cantidad.nlargest(top, 'cantidad')

ranking_productos(datos)
# Out:
#      producto  cantidad
# 2  Pepsi Cola        89
# 1     Mirinda        85
# 3      Sprite        72

# %% [markdown]
# ### Ejercicio 6: Listar las ventas por mes
# Realizar un listado del total de unidades vendidas por producto separado por mes.

# %%
def ventas_por_mes(datos):
    datos['fecha'] = pd.to_datetime(datos['fecha'])
    datos['mes'] = datos['fecha'].dt.month
    cantidad_por_mes = datos.groupby('mes')['cantidad'].sum().reset_index()
    return cantidad_por_mes

ventas_por_mes(datos)
# Out:
#    mes  cantidad
# 0    8        45
# 1    9       290

# %% [markdown]
# ### Ejercicio 7: Informe general
#
# Mostrar un listado de productos ordenados alfabeticamente que contengan el precio promedio, la cantidad de unidades vendidas y el importe total vendido para cada producto

# %%
def resumen_ventas(datos):
    resumen = datos.groupby('producto')[['cantidad']].sum()
    total_precios = datos.groupby('producto')['precio'].sum()
    total_ventas = resumen['cantidad'] * total_precios
    promedio_ventas = total_ventas / resumen['cantidad']
    listado_resumen = pd.DataFrame({
        'producto': promedio_ventas.index,
        'cantidad': resumen['cantidad'],
        'total': total_ventas,
        'promedio': promedio_ventas.values
    }).reset_index(drop=True)
    return listado_resumen.sort_values(by='producto')

resumen_ventas(datos)
# Out:
#      producto  cantidad    total  promedio
# 0   Coca Cola        57   489060    8580.0
# 1     Mirinda        85  1576750   18550.0
# 2  Pepsi Cola        89   886440    9960.0
# 3      Sprite        72   424080    5890.0
# 4     Torasso        32   147200    4600.0

# %% [markdown]
# ## `Resolver usando NumPy`
# ## Resolver el ejercicio 2 del tp1 usando NumPy

# %% [markdown]
# ### Ejercicio 8
#
# Escribe una función en Python que encuentre los valores de `a`, `b`, y `c` para que la función cuadrática `f(x) = a x^2 + b x + c` pase exactamente por los siguientes puntos:
#
# | x  | y  |
# |---:|---:|
# |  0 |  0 |
# |  1 |  8 |
# |  2 | 12 |
# |  3 | 12 |
# |  5 |  0 |
#
# ### Requisitos:
# - La función debe explorar posibles valores de `a`, `b`, y `c` utilizando un método de prueba y error.
# - Debe devolver los valores que hagan que la diferencia entre la función `f(x)` y los valores medidos `y` sea exactamente cero para cada punto.
#
# > **Pista**: Los valores de `a`, `b`, y `c` son números pequeños.
#
# La idea es implementar el mismo algoritmo que se uso en el TP1 pero usando NumPy en lugar de Python puro.

# %%
def f(x, coef):
    return coef[0] * x**2 + coef[1] * x + coef[2]

def error(y_real, y_predicho):
    return np.sum((y_real - y_predicho)**2)

X = np.array([0, 1, 2, 3, 5])
Y = np.array([0, 8, 12, 11, 1])

def buscar_coeficientes():
    coeficientes = randint(-10, 10, 3)
    y_predicho = f(X, coeficientes)
    error_actual = error(Y, y_predicho)
    tasa_aprendizaje = 0.001

    while error_actual > 1:
        nuevos_coef = coeficientes + randint(-10, 10, 3) * tasa_aprendizaje
        y_predicho_nuevo = f(X, nuevos_coef)
        nuevo_error = error(Y, y_predicho_nuevo)
        if nuevo_error < error_actual:
            coeficientes = nuevos_coef
            error_actual = nuevo_error
            print(f"Coeficientes actuales: {coeficientes}, Error actual: {error_actual}")

    return coeficientes

coeficientes = buscar_coeficientes()
coeficientes
# Out:
# Coeficientes actuales: [ 8.999 -3.009 -1.004], Error actual: 47126.63196400002
# Coeficientes actuales: [ 8.989 -3.002 -0.997], Error actual: 47032.06406200001
# Coeficientes actuales: [ 8.986 -2.993 -0.996], Error actual: 47020.330391
# Coeficientes actuales: [ 8.977 -2.995 -0.996], Error actual: 46911.06775600001
# Coeficientes actuales: [ 8.967 -2.995 -1.005], Error actual: 46790.317637000015
# Coeficientes actuales: [ 8.969 -3.004 -1.015], Error actual: 46785.42607000001
# Coeficientes actuales: [ 8.966 -2.996 -1.017], Error actual: 46769.551653000024
# Coeficientes actuales: [ 8.966 -3.002 -1.026], Error actual: 46749.57531600002
# Coeficientes actuales: [ 8.962 -3.007 -1.031], Error actual: 46688.11703800002
# Coeficientes actuales: [ 8.955 -3.01  -1.027], Error actual: 46602.07323000002
# Coeficientes actuales: [ 8.954 -3.016 -1.023], Error actual: 46577.852109000036
# Coeficientes actuales: [ 8.944 -3.019 -1.022], Error actual: 46455.669727000044
# Coeficientes actuales: [ 8.943 -3.023 -1.028], Error actual: 46430.88237600003
# Coeficientes actuales: [ 8.933 -3.021 -1.032], Error actual: 46318.506936000034
# Coeficientes actuales: [ 8.924 -3.026 -1.024], Error actual: 46207.09756400004
# Coeficientes actuales: [ 8.922 -3.033 -1.032], Error actual: 46162.36307100003
# Coeficientes actuales: [ 8.912 -3.032 -1.023], Error actual: 46055.052309000035
# Coeficientes actuales: [ 8.907 -3.033 -1.017], Error actual: 45998.571021000025
# Coeficientes actuales: [ 8.898 -3.03  -1.027], Error actual: 45897.32478900002
# Coeficientes actuales: [ 8.893 -3.021 -1.02 ], Error actual: 45866.14452000001
# Coeficientes actuales: [ 8.891 -3.013 -1.027], Error actual: 45859.10374900001
# Coeficientes actuales: [ 8.886 -3.009 -1.037], Error actual: 45806.220813999986
# Coeficientes actuales: [ 8.884 -3.012 -1.045], Error actual: 45771.53769299999
# Coeficientes actuales: [ 8.874 -3.009 -1.037], Error actual: 45669.052461999985
# Coeficientes actuales: [ 8.872 -3.01  -1.047], Error actual: 45638.23832499998
# Coeficientes actuales: [ 8.872 -3.015 -1.054], Error actual: 45622.086182999985
# Coeficientes actuales: [ 8.869 -3.016 -1.048], Error actual: 45588.69317899998
# Coeficientes actuales: [ 8.866 -3.016 -1.058], Error actual: 45548.95799199998
# Coeficientes actuales: [ 8.856 -3.017 -1.05 ], Error actual: 45436.91045499997
# Coeficientes actuales: [ 8.846 -3.012 -1.046], Error actual: 45337.506615999984
# Coeficientes actuales: [ 8.84  -3.004 -1.038], Error actual: 45293.23630799998
# Coeficientes actuales: [ 8.839 -3.013 -1.042], Error actual: 45257.62968799998
# Coeficientes actuales: [ 8.833 -3.022 -1.034], Error actual: 45171.808770999996
# Coeficientes actuales: [ 8.831 -3.023 -1.035], Error actual: 45146.101052999984
# Coeficientes actuales: [ 8.83 -3.02 -1.04], Error actual: 45139.34109999998
# Coeficientes actuales: [ 8.827 -3.015 -1.034], Error actual: 45120.79082799999
# Coeficientes actuales: [ 8.823 -3.009 -1.03 ], Error actual: 45092.243591999984
# Coeficientes actuales: [ 8.82  -3.001 -1.028], Error actual: 45078.84285499999
# Coeficientes actuales: [ 8.811 -2.998 -1.035], Error actual: 44980.269277999985
# Coeficientes actuales: [ 8.808 -3.005 -1.036], Error actual: 44928.65034299998
# Coeficientes actuales: [ 8.799 -2.997 -1.036], Error actual: 44846.24861999998
# Coeficientes actuales: [ 8.797 -2.992 -1.035], Error actual: 44836.34382999996
# Coeficientes actuales: [ 8.795 -2.983 -1.035], Error actual: 44835.63986099997
# Coeficientes actuales: [ 8.786 -2.984 -1.041], Error actual: 44728.14630899996
# Coeficientes actuales: [ 8.785 -2.987 -1.041], Error actual: 44709.545524999965
# Coeficientes actuales: [ 8.781 -2.991 -1.04 ], Error actual: 44655.17565999997
# Coeficientes actuales: [ 8.777 -2.997 -1.038], Error actual: 44596.524683999975
# Coeficientes actuales: [ 8.773 -2.993 -1.031], Error actual: 44564.91663699997
# Coeficientes actuales: [ 8.764 -2.987 -1.022], Error actual: 44482.89000699997
# Coeficientes actuales: [ 8.759 -2.997 -1.028], Error actual: 44399.04852399997
# Coeficientes actuales: [ 8.75  -2.999 -1.022], Error actual: 44296.17597499996
# Coeficientes actuales: [ 8.743 -3.006 -1.014], Error actual: 44204.884826999965
# Coeficientes actuales: [ 8.741 -3.015 -1.009], Error actual: 44163.36650099997
# Coeficientes actuales: [ 8.734 -3.024 -1.003], Error actual: 44066.304572999965
# Coeficientes actuales: [ 8.725 -3.032 -1.   ], Error actual: 43947.73641099996
# Coeficientes actuales: [ 8.721 -3.037 -0.994], Error actual: 43894.12916399996
# Coeficientes actuales: [ 8.72  -3.043 -1.004], Error actual: 43863.089414999966
# Coeficientes actuales: [ 8.716 -3.035 -1.003], Error actual: 43838.135553999986
# Coeficientes actuales: [ 8.716 -3.044 -0.995], Error actual: 43820.78002899998
# Coeficientes actuales: [ 8.708 -3.036 -0.99 ], Error actual: 43753.27409999999
# Coeficientes actuales: [ 8.709 -3.045 -0.989], Error actual: 43743.34196499997
# Coeficientes actuales: [ 8.704 -3.036 -0.997], Error actual: 43704.81054899997
# Coeficientes actuales: [ 8.697 -3.044 -0.994], Error actual: 43609.05288299997
# Coeficientes actuales: [ 8.694 -3.035 -0.993], Error actual: 43597.727001999985
# Coeficientes actuales: [ 8.693 -3.043 -1.   ], Error actual: 43563.60885999997
# Coeficientes actuales: [ 8.69  -3.041 -0.991], Error actual: 43539.78914599998
# Coeficientes actuales: [ 8.688 -3.045 -0.988], Error actual: 43509.51037499997
# Coeficientes actuales: [ 8.682 -3.045 -0.995], Error actual: 43438.91060199997
# Coeficientes actuales: [ 8.68  -3.052 -0.989], Error actual: 43403.09019699997
# Coeficientes actuales: [ 8.678 -3.057 -0.983], Error actual: 43372.073385999945
# Coeficientes actuales: [ 8.668 -3.058 -0.989], Error actual: 43255.27129299996
# Coeficientes actuales: [ 8.659 -3.049 -0.999], Error actual: 43171.47142899995
# Coeficientes actuales: [ 8.651 -3.044 -1.007], Error actual: 43090.36783399996
# Coeficientes actuales: [ 8.644 -3.046 -1.009], Error actual: 43006.93514899997
# Coeficientes actuales: [ 8.643 -3.048 -1.009], Error actual: 42991.08979799998
# Coeficientes actuales: [ 8.639 -3.04  -1.019], Error actual: 42960.51968999997
# Coeficientes actuales: [ 8.636 -3.044 -1.015], Error actual: 42919.91078899999
# Coeficientes actuales: [ 8.629 -3.047 -1.023], Error actual: 42831.07730899998
# Coeficientes actuales: [ 8.621 -3.046 -1.032], Error actual: 42740.266202999985
# Coeficientes actuales: [ 8.614 -3.05  -1.033], Error actual: 42652.96551699999
# Coeficientes actuales: [ 8.607 -3.058 -1.033], Error actual: 42556.804626
# Coeficientes actuales: [ 8.597 -3.064 -1.025], Error actual: 42436.70265
# Coeficientes actuales: [ 8.59  -3.073 -1.024], Error actual: 42338.95653500001
# Coeficientes actuales: [ 8.586 -3.081 -1.032], Error actual: 42271.882623
# Coeficientes actuales: [ 8.588 -3.091 -1.034], Error actual: 42269.17676700002
# Coeficientes actuales: [ 8.579 -3.098 -1.038], Error actual: 42151.77986700002
# Coeficientes actuales: [ 8.572 -3.097 -1.034], Error actual: 42079.50852700001
# Coeficientes actuales: [ 8.563 -3.089 -1.038], Error actual: 41997.67594400001
# Coeficientes actuales: [ 8.556 -3.094 -1.03 ], Error actual: 41913.53042400001
# Coeficientes actuales: [ 8.548 -3.099 -1.025], Error actual: 41816.97386200002
# Coeficientes actuales: [ 8.546 -3.095 -1.025], Error actual: 41804.522378000016
# Coeficientes actuales: [ 8.54  -3.095 -1.031], Error actual: 41735.880050000014
# Coeficientes actuales: [ 8.532 -3.092 -1.034], Error actual: 41654.09221200003
# Coeficientes actuales: [ 8.53  -3.091 -1.042], Error actual: 41630.45222300002
# Coeficientes actuales: [ 8.527 -3.087 -1.044], Error actual: 41606.087112
# Coeficientes actuales: [ 8.521 -3.095 -1.035], Error actual: 41526.727373000016
# Coeficientes actuales: [ 8.518 -3.088 -1.029], Error actual: 41513.58685300001
# Coeficientes actuales: [ 8.516 -3.089 -1.025], Error actual: 41491.574354000004
# Coeficientes actuales: [ 8.511 -3.097 -1.025], Error actual: 41418.500884999994
# Coeficientes actuales: [ 8.506 -3.1   -1.026], Error actual: 41356.645239999976
# Coeficientes actuales: [ 8.499 -3.092 -1.019], Error actual: 41302.95618599999
# Coeficientes actuales: [ 8.498 -3.094 -1.011], Error actual: 41291.602101
# Coeficientes actuales: [ 8.491 -3.089 -1.021], Error actual: 41222.118469
# Coeficientes actuales: [ 8.49  -3.099 -1.028], Error actual: 41184.33706300001
# Coeficientes actuales: [ 8.48  -3.105 -1.036], Error actual: 41057.91817500001
# Coeficientes actuales: [ 8.47  -3.105 -1.028], Error actual: 40953.92009500002
# Coeficientes actuales: [ 8.462 -3.097 -1.028], Error actual: 40886.067519000026
# Coeficientes actuales: [ 8.455 -3.092 -1.038], Error actual: 40816.93376300003
# Coeficientes actuales: [ 8.446 -3.083 -1.038], Error actual: 40740.73180700002
# Coeficientes actuales: [ 8.439 -3.086 -1.048], Error actual: 40653.21165900003
# Coeficientes actuales: [ 8.431 -3.086 -1.052], Error actual: 40565.05816300004
# Coeficientes actuales: [ 8.423 -3.08  -1.05 ], Error actual: 40493.94158700005
# Coeficientes actuales: [ 8.425 -3.089 -1.058], Error actual: 40490.536828000055
# Coeficientes actuales: [ 8.422 -3.089 -1.05 ], Error actual: 40462.42257500004
# Coeficientes actuales: [ 8.417 -3.092 -1.05 ], Error actual: 40401.81403500005
# Coeficientes actuales: [ 8.414 -3.094 -1.042], Error actual: 40369.120372000034
# Coeficientes actuales: [ 8.41  -3.097 -1.037], Error actual: 40321.87185400003
# Coeficientes actuales: [ 8.401 -3.102 -1.028], Error actual: 40218.53740300005
# Coeficientes actuales: [ 8.393 -3.102 -1.021], Error actual: 40136.49828600005
# Coeficientes actuales: [ 8.389 -3.102 -1.028], Error actual: 40090.13569900006
# Coeficientes actuales: [ 8.38 -3.1  -1.02], Error actual: 40002.64840000005
# Coeficientes actuales: [ 8.37  -3.101 -1.015], Error actual: 39896.184954000055
# Coeficientes actuales: [ 8.365 -3.107 -1.007], Error actual: 39833.221909000036
# Coeficientes actuales: [ 8.357 -3.11  -1.003], Error actual: 39743.19235400005
# Coeficientes actuales: [ 8.354 -3.102 -1.01 ], Error actual: 39725.985268000055
# Coeficientes actuales: [ 8.347 -3.11  -1.007], Error actual: 39634.784590000054
# Coeficientes actuales: [ 8.345 -3.118 -1.014], Error actual: 39591.714075000054
# Coeficientes actuales: [ 8.337 -3.117 -1.014], Error actual: 39509.04913200006
# Coeficientes actuales: [ 8.336 -3.111 -1.024], Error actual: 39507.035511000075
# Coeficientes actuales: [ 8.332 -3.109 -1.025], Error actual: 39468.646450000066
# Coeficientes actuales: [ 8.328 -3.114 -1.024], Error actual: 39415.35490800007
# Coeficientes actuales: [ 8.322 -3.111 -1.025], Error actual: 39358.09940200007
# Coeficientes actuales: [ 8.321 -3.118 -1.032], Error actual: 39328.04793900007
# Coeficientes actuales: [ 8.317 -3.119 -1.024], Error actual: 39287.483308000075
# Coeficientes actuales: [ 8.312 -3.121 -1.031], Error actual: 39226.51147800007
# Coeficientes actuales: [ 8.303 -3.122 -1.027], Error actual: 39131.15732600008
# Coeficientes actuales: [ 8.297 -3.118 -1.03 ], Error actual: 39075.36873100006
# Coeficientes actuales: [ 8.29  -3.114 -1.024], Error actual: 39013.61001600007
# Coeficientes actuales: [ 8.282 -3.112 -1.034], Error actual: 38928.78871200008
# Coeficientes actuales: [ 8.282 -3.121 -1.03 ], Error actual: 38910.45204700008
# Coeficientes actuales: [ 8.276 -3.112 -1.04 ], Error actual: 38862.60024000008
# Coeficientes actuales: [ 8.274 -3.122 -1.04 ], Error actual: 38818.97308800008
# Coeficientes actuales: [ 8.27 -3.12 -1.05], Error actual: 38776.40700000007
# Coeficientes actuales: [ 8.265 -3.128 -1.054], Error actual: 38703.82387500007
# Coeficientes actuales: [ 8.264 -3.123 -1.061], Error actual: 38701.08381400008
# Coeficientes actuales: [ 8.258 -3.12  -1.056], Error actual: 38647.36282800007
# Coeficientes actuales: [ 8.251 -3.125 -1.061], Error actual: 38560.18844500007
# Coeficientes actuales: [ 8.243 -3.118 -1.054], Error actual: 38495.60968300008
# Coeficientes actuales: [ 8.241 -3.113 -1.063], Error actual: 38481.40571700008
# Coeficientes actuales: [ 8.239 -3.11  -1.067], Error actual: 38465.20857400008
# Coeficientes actuales: [ 8.233 -3.119 -1.077], Error actual: 38377.23096500007
# Coeficientes actuales: [ 8.231 -3.113 -1.077], Error actual: 38369.782509000055
# Coeficientes actuales: [ 8.229 -3.111 -1.07 ], Error actual: 38356.851544000056
# Coeficientes actuales: [ 8.228 -3.111 -1.076], Error actual: 38343.40666300007
# Coeficientes actuales: [ 8.219 -3.118 -1.077], Error actual: 38233.219938000046
# Coeficientes actuales: [ 8.217 -3.111 -1.078], Error actual: 38227.52652000005
# Coeficientes actuales: [ 8.212 -3.104 -1.071], Error actual: 38194.51447700003
# Coeficientes actuales: [ 8.209 -3.112 -1.062], Error actual: 38149.80246700003
# Coeficientes actuales: [ 8.206 -3.116 -1.062], Error actual: 38109.58872800004
# Coeficientes actuales: [ 8.204 -3.12  -1.054], Error actual: 38083.785300000025
# Coeficientes actuales: [ 8.196 -3.121 -1.054], Error actual: 37998.269991000045
# Coeficientes actuales: [ 8.187 -3.125 -1.06 ], Error actual: 37892.801052000024
# Coeficientes actuales: [ 8.183 -3.125 -1.062], Error actual: 37850.264904000025
# Coeficientes actuales: [ 8.174 -3.129 -1.066], Error actual: 37745.99627100004
# Coeficientes actuales: [ 8.171 -3.128 -1.059], Error actual: 37720.57689000004
# Coeficientes actuales: [ 8.167 -3.125 -1.06 ], Error actual: 37685.300812000045
# Coeficientes actuales: [ 8.163 -3.135 -1.066], Error actual: 37618.70122800005
# Coeficientes actuales: [ 8.161 -3.131 -1.07 ], Error actual: 37604.91004000005
# Coeficientes actuales: [ 8.161 -3.141 -1.08 ], Error actual: 37577.78604000004
# Coeficientes actuales: [ 8.158 -3.141 -1.08 ], Error actual: 37546.75705500004
# Coeficientes actuales: [ 8.15  -3.137 -1.086], Error actual: 37469.98837500004
# Coeficientes actuales: [ 8.148 -3.131 -1.095], Error actual: 37458.19717000003
# Coeficientes actuales: [ 8.148 -3.133 -1.087], Error actual: 37457.70029400004
# Coeficientes actuales: [ 8.143 -3.135 -1.094], Error actual: 37398.21007600005
# Coeficientes actuales: [ 8.137 -3.127 -1.104], Error actual: 37349.10185200002
# Coeficientes actuales: [ 8.134 -3.12  -1.106], Error actual: 37332.66613600003
# Coeficientes actuales: [ 8.124 -3.111 -1.109], Error actual: 37248.03669400003
# Coeficientes actuales: [ 8.115 -3.121 -1.111], Error actual: 37132.36946100003
# Coeficientes actuales: [ 8.113 -3.129 -1.121], Error actual: 37089.285301000025
# Coeficientes actuales: [ 8.114 -3.137 -1.113], Error actual: 37085.84273400002
# Coeficientes actuales: [ 8.115 -3.146 -1.106], Error actual: 37079.708451000006
# Coeficientes actuales: [ 8.111 -3.151 -1.097], Error actual: 37032.005733000005
# Coeficientes actuales: [ 8.104 -3.155 -1.089], Error actual: 36955.26743000002
# Coeficientes actuales: [ 8.097 -3.165 -1.098], Error actual: 36857.14916400002
# Coeficientes actuales: [ 8.095 -3.165 -1.107], Error actual: 36832.284285000016
# Coeficientes actuales: [ 8.096 -3.173 -1.11 ], Error actual: 36823.50210300002
# Coeficientes actuales: [ 8.091 -3.165 -1.109], Error actual: 36790.36350099999
# Coeficientes actuales: [ 8.081 -3.173 -1.104], Error actual: 36672.99947999999
# Coeficientes actuales: [ 8.073 -3.166 -1.108], Error actual: 36604.68333900002
# Coeficientes actuales: [ 8.07  -3.166 -1.104], Error actual: 36576.005792
# Coeficientes actuales: [ 8.07  -3.168 -1.11 ], Error actual: 36568.723176
# Coeficientes actuales: [ 8.063 -3.175 -1.113], Error actual: 36480.59752500002
# Coeficientes actuales: [ 8.055 -3.172 -1.117], Error actual: 36403.735974000025
# Coeficientes actuales: [ 8.047 -3.171 -1.118], Error actual: 36324.04654000004
# Coeficientes actuales: [ 8.039 -3.171 -1.114], Error actual: 36244.67972400004
# Coeficientes actuales: [ 8.04  -3.18  -1.116], Error actual: 36234.28272000004
# Coeficientes actuales: [ 8.035 -3.19  -1.126], Error actual: 36156.97035500003
# Coeficientes actuales: [ 8.032 -3.19  -1.122], Error actual: 36128.47036000002
# Coeficientes actuales: [ 8.022 -3.183 -1.116], Error actual: 36045.21887100003
# Coeficientes actuales: [ 8.013 -3.18  -1.12 ], Error actual: 35958.70982700003
# Coeficientes actuales: [ 8.009 -3.173 -1.12 ], Error actual: 35933.42492000003
# Coeficientes actuales: [ 8.009 -3.18  -1.123], Error actual: 35916.820902000036
# Coeficientes actuales: [ 8.002 -3.19  -1.132], Error actual: 35820.14672000003
# Coeficientes actuales: [ 7.997 -3.196 -1.136], Error actual: 35754.80880300004
# Coeficientes actuales: [ 7.99  -3.2   -1.128], Error actual: 35679.42926000005
# Coeficientes actuales: [ 7.985 -3.201 -1.133], Error actual: 35624.52932500004
# Coeficientes actuales: [ 7.983 -3.202 -1.127], Error actual: 35605.103486000036
# Coeficientes actuales: [ 7.981 -3.207 -1.129], Error actual: 35573.24838900006
# Coeficientes actuales: [ 7.971 -3.2   -1.128], Error actual: 35488.26229900005
# Coeficientes actuales: [ 7.961 -3.197 -1.134], Error actual: 35391.453324000046
# Coeficientes actuales: [ 7.955 -3.2   -1.132], Error actual: 35325.785315000045
# Coeficientes actuales: [ 7.945 -3.205 -1.136], Error actual: 35213.00188000005
# Coeficientes actuales: [ 7.943 -3.214 -1.142], Error actual: 35170.867515000056
# Coeficientes actuales: [ 7.934 -3.222 -1.138], Error actual: 35065.693044000036
# Coeficientes actuales: [ 7.93  -3.216 -1.137], Error actual: 35039.05581300005
# Coeficientes actuales: [ 7.928 -3.212 -1.131], Error actual: 35030.47634100005
# Coeficientes actuales: [ 7.928 -3.218 -1.122], Error actual: 35021.904264000055
# Coeficientes actuales: [ 7.923 -3.213 -1.126], Error actual: 34980.81175200005
# Coeficientes actuales: [ 7.918 -3.213 -1.128], Error actual: 34930.01531100006
# Coeficientes actuales: [ 7.918 -3.221 -1.12 ], Error actual: 34916.71649500006
# Coeficientes actuales: [ 7.912 -3.213 -1.117], Error actual: 34875.42366600006
# Coeficientes actuales: [ 7.906 -3.221 -1.116], Error actual: 34799.12423900006
# Coeficientes actuales: [ 7.9   -3.227 -1.113], Error actual: 34728.10659800005
# Coeficientes actuales: [ 7.89  -3.231 -1.117], Error actual: 34618.43029800006
# Coeficientes actuales: [ 7.887 -3.238 -1.114], Error actual: 34575.21965100005
# Coeficientes actuales: [ 7.885 -3.233 -1.116], Error actual: 34565.06535200006
# Coeficientes actuales: [ 7.883 -3.231 -1.108], Error actual: 34553.23370400005
# Coeficientes actuales: [ 7.88  -3.237 -1.107], Error actual: 34511.24813400005
# Coeficientes actuales: [ 7.878 -3.229 -1.105], Error actual: 34509.33766200005
# Coeficientes actuales: [ 7.871 -3.223 -1.101], Error actual: 34454.61662100005
# Coeficientes actuales: [ 7.864 -3.228 -1.105], Error actual: 34372.91620500007
# Coeficientes actuales: [ 7.862 -3.233 -1.113], Error actual: 34338.835086000065
# Coeficientes actuales: [ 7.86  -3.23  -1.104], Error actual: 34329.62230000006
# Coeficientes actuales: [ 7.857 -3.235 -1.102], Error actual: 34290.35628000006
# Coeficientes actuales: [ 7.847 -3.23  -1.099], Error actual: 34203.642398000076
# Coeficientes actuales: [ 7.841 -3.236 -1.097], Error actual: 34132.78269800006
# Coeficientes actuales: [ 7.837 -3.239 -1.098], Error actual: 34086.60653600007
# Coeficientes actuales: [ 7.83  -3.23  -1.093], Error actual: 34039.00300500008
# Coeficientes actuales: [ 7.828 -3.234 -1.084], Error actual: 34015.09522800008
# Coeficientes actuales: [ 7.82  -3.234 -1.081], Error actual: 33937.866357000086
# Coeficientes actuales: [ 7.813 -3.231 -1.074], Error actual: 33878.69191200007
# Coeficientes actuales: [ 7.803 -3.227 -1.074], Error actual: 33789.01807600008
# Coeficientes actuales: [ 7.797 -3.221 -1.073], Error actual: 33743.27824500008
# Coeficientes actuales: [ 7.788 -3.215 -1.078], Error actual: 33665.443215000065
# Coeficientes actuales: [ 7.784 -3.209 -1.087], Error actual: 33634.72386200008
# Coeficientes actuales: [ 7.778 -3.214 -1.095], Error actual: 33561.94535700008
# Coeficientes actuales: [ 7.778 -3.223 -1.099], Error actual: 33541.297678000075
# Coeficientes actuales: [ 7.772 -3.22  -1.109], Error actual: 33484.40097300007
# Coeficientes actuales: [ 7.763 -3.222 -1.119], Error actual: 33387.90180600007
# Coeficientes actuales: [ 7.759 -3.217 -1.128], Error actual: 33355.23180400007
# Coeficientes actuales: [ 7.756 -3.217 -1.12 ], Error actual: 33329.702975000066
# Coeficientes actuales: [ 7.747 -3.214 -1.116], Error actual: 33250.24482700007
# Coeficientes actuales: [ 7.74  -3.22  -1.125], Error actual: 33165.658925000076
# Coeficientes actuales: [ 7.733 -3.223 -1.13 ], Error actual: 33089.235240000075
# Coeficientes actuales: [ 7.733 -3.229 -1.134], Error actual: 33074.96674800008
# Coeficientes actuales: [ 7.734 -3.238 -1.144], Error actual: 33061.43625600007
# Coeficientes actuales: [ 7.725 -3.239 -1.141], Error actual: 32973.56927700008
# Coeficientes actuales: [ 7.723 -3.236 -1.142], Error actual: 32959.96713100008
# Coeficientes actuales: [ 7.722 -3.24  -1.14 ], Error actual: 32942.92753200008
# Coeficientes actuales: [ 7.712 -3.235 -1.141], Error actual: 32856.13504600009
# Coeficientes actuales: [ 7.709 -3.232 -1.144], Error actual: 32831.98953100008
# Coeficientes actuales: [ 7.709 -3.237 -1.142], Error actual: 32822.574652000076
# Coeficientes actuales: [ 7.71  -3.243 -1.14 ], Error actual: 32820.75179100008
# Coeficientes actuales: [ 7.703 -3.242 -1.137], Error actual: 32756.62350600008
# Coeficientes actuales: [ 7.694 -3.246 -1.143], Error actual: 32658.911109000077
# Coeficientes actuales: [ 7.684 -3.247 -1.15 ], Error actual: 32557.44878300009
# Coeficientes actuales: [ 7.68  -3.238 -1.148], Error actual: 32538.39436400009
# Coeficientes actuales: [ 7.678 -3.239 -1.141], Error actual: 32520.281866000092
# Coeficientes actuales: [ 7.67  -3.242 -1.14 ], Error actual: 32437.74057600009
# Coeficientes actuales: [ 7.667 -3.238 -1.139], Error actual: 32417.60844600008
# Coeficientes actuales: [ 7.658 -3.23  -1.138], Error actual: 32348.15138000008
# Coeficientes actuales: [ 7.659 -3.238 -1.129], Error actual: 32345.40294600009
# Coeficientes actuales: [ 7.653 -3.229 -1.129], Error actual: 32306.348613000093
# Coeficientes actuales: [ 7.65  -3.231 -1.136], Error actual: 32270.374711000088
# Coeficientes actuales: [ 7.64  -3.237 -1.136], Error actual: 32162.460895000087
# Coeficientes actuales: [ 7.636 -3.228 -1.132], Error actual: 32144.41838400009
# Coeficientes actuales: [ 7.63  -3.236 -1.131], Error actual: 32071.250501000086
# Coeficientes actuales: [ 7.623 -3.231 -1.136], Error actual: 32012.433208000093
# Coeficientes actuales: [ 7.615 -3.238 -1.128], Error actual: 31925.544619000095
# Coeficientes actuales: [ 7.605 -3.246 -1.121], Error actual: 31817.287006000086
# Coeficientes actuales: [ 7.605 -3.253 -1.12 ], Error actual: 31803.51861600009
# Coeficientes actuales: [ 7.602 -3.249 -1.118], Error actual: 31784.030191000093
# Coeficientes actuales: [ 7.598 -3.259 -1.109], Error actual: 31729.776138000096
# Coeficientes actuales: [ 7.592 -3.267 -1.107], Error actual: 31657.54206600009
# Coeficientes actuales: [ 7.589 -3.275 -1.107], Error actual: 31612.916109000096
# Coeficientes actuales: [ 7.581 -3.271 -1.113], Error actual: 31542.600197000094
# Coeficientes actuales: [ 7.573 -3.279 -1.119], Error actual: 31448.141133000092
# Coeficientes actuales: [ 7.571 -3.274 -1.119], Error actual: 31439.337534000086
# Coeficientes actuales: [ 7.571 -3.284 -1.126], Error actual: 31416.061259000093
# Coeficientes actuales: [ 7.565 -3.282 -1.134], Error actual: 31359.922587000096
# Coeficientes actuales: [ 7.562 -3.279 -1.136], Error actual: 31336.7856070001
# Coeficientes actuales: [ 7.56  -3.273 -1.133], Error actual: 31331.33787400008
# Coeficientes actuales: [ 7.555 -3.272 -1.143], Error actual: 31281.8018180001
# Coeficientes actuales: [ 7.552 -3.271 -1.135], Error actual: 31259.0880020001
# Coeficientes actuales: [ 7.547 -3.27  -1.137], Error actual: 31213.14141000009
# Coeficientes actuales: [ 7.54  -3.262 -1.143], Error actual: 31160.716693000097
# Coeficientes actuales: [ 7.54  -3.27  -1.151], Error actual: 31141.127125000094
# Coeficientes actuales: [ 7.541 -3.278 -1.149], Error actual: 31135.349070000102
# Coeficientes actuales: [ 7.534 -3.283 -1.143], Error actual: 31062.206302000108
# Coeficientes actuales: [ 7.525 -3.283 -1.134], Error actual: 30981.727960000095
# Coeficientes actuales: [ 7.518 -3.277 -1.132], Error actual: 30929.012391000106
# Coeficientes actuales: [ 7.515 -3.287 -1.135], Error actual: 30879.6114210001
# Coeficientes actuales: [ 7.508 -3.287 -1.128], Error actual: 30817.194591000098
# Coeficientes actuales: [ 7.504 -3.291 -1.121], Error actual: 30774.889414000096
# Coeficientes actuales: [ 7.5   -3.296 -1.127], Error actual: 30724.935693000105
# Coeficientes actuales: [ 7.495 -3.292 -1.136], Error actual: 30682.309675000106
# Coeficientes actuales: [ 7.493 -3.288 -1.145], Error actual: 30667.68841000011
# Coeficientes actuales: [ 7.483 -3.29  -1.146], Error actual: 30570.08096300012
# Coeficientes actuales: [ 7.478 -3.288 -1.15 ], Error actual: 30525.771240000115
# Coeficientes actuales: [ 7.475 -3.285 -1.156], Error actual: 30501.20790000012
# Coeficientes actuales: [ 7.466 -3.285 -1.16 ], Error actual: 30415.820263000114
# Coeficientes actuales: [ 7.464 -3.283 -1.158], Error actual: 30402.08020700012
# Coeficientes actuales: [ 7.463 -3.279 -1.155], Error actual: 30402.02543700011
# Coeficientes actuales: [ 7.453 -3.275 -1.162], Error actual: 30314.12154400011
# Coeficientes actuales: [ 7.445 -3.277 -1.168], Error actual: 30233.442808000116
# Coeficientes actuales: [ 7.444 -3.276 -1.175], Error actual: 30223.130149000113
# Coeficientes actuales: [ 7.434 -3.284 -1.176], Error actual: 30114.41911600012
# Coeficientes actuales: [ 7.424 -3.283 -1.177], Error actual: 30023.62499800012
# Coeficientes actuales: [ 7.424 -3.288 -1.173], Error actual: 30015.507117000114
# Coeficientes actuales: [ 7.416 -3.281 -1.164], Error actual: 29959.391311000112
# Coeficientes actuales: [ 7.407 -3.287 -1.166], Error actual: 29863.864188000112
# Coeficientes actuales: [ 7.405 -3.292 -1.166], Error actual: 29835.653875000116
# Coeficientes actuales: [ 7.401 -3.297 -1.163], Error actual: 29790.363613000118
# Coeficientes actuales: [ 7.391 -3.302 -1.154], Error actual: 29692.610579000124
# Coeficientes actuales: [ 7.386 -3.293 -1.154], Error actual: 29664.35929500012
# Coeficientes actuales: [ 7.378 -3.291 -1.154], Error actual: 29594.954287000124
# Coeficientes actuales: [ 7.371 -3.282 -1.159], Error actual: 29546.307294000122
# Coeficientes actuales: [ 7.367 -3.285 -1.155], Error actual: 29505.569277000126
# Coeficientes actuales: [ 7.357 -3.292 -1.163], Error actual: 29397.15741400012
# Coeficientes actuales: [ 7.353 -3.286 -1.157], Error actual: 29374.88612600013
# Coeficientes actuales: [ 7.343 -3.292 -1.165], Error actual: 29268.66496600013
# Coeficientes actuales: [ 7.342 -3.295 -1.168], Error actual: 29252.46023900013
# Coeficientes actuales: [ 7.337 -3.303 -1.168], Error actual: 29191.44015600013
# Coeficientes actuales: [ 7.331 -3.301 -1.172], Error actual: 29139.07906800013
# Coeficientes actuales: [ 7.327 -3.302 -1.164], Error actual: 29104.194947000135
# Coeficientes actuales: [ 7.327 -3.309 -1.163], Error actual: 29091.06702100012
# Coeficientes actuales: [ 7.321 -3.314 -1.171], Error actual: 29023.574194000135
# Coeficientes actuales: [ 7.316 -3.31  -1.177], Error actual: 28983.447757000125
# Coeficientes actuales: [ 7.313 -3.305 -1.181], Error actual: 28964.237213000124
# Coeficientes actuales: [ 7.312 -3.311 -1.175], Error actual: 28946.127202000123
# Coeficientes actuales: [ 7.306 -3.314 -1.184], Error actual: 28882.24566400013
# Coeficientes actuales: [ 7.302 -3.313 -1.18 ], Error actual: 28849.68731100013
# Coeficientes actuales: [ 7.299 -3.307 -1.174], Error actual: 28836.65583600012
# Coeficientes actuales: [ 7.291 -3.309 -1.173], Error actual: 28760.97114900013
# Coeficientes actuales: [ 7.284 -3.308 -1.17 ], Error actual: 28701.00658000014
# Coeficientes actuales: [ 7.274 -3.303 -1.173], Error actual: 28619.252922000134
# Coeficientes actuales: [ 7.266 -3.306 -1.171], Error actual: 28542.362349000137
# Coeficientes actuales: [ 7.258 -3.31  -1.172], Error actual: 28462.411744000125
# Coeficientes actuales: [ 7.251 -3.307 -1.175], Error actual: 28404.084005000135
# Coeficientes actuales: [ 7.245 -3.308 -1.177], Error actual: 28347.557178000137
# Coeficientes actuales: [ 7.24  -3.304 -1.171], Error actual: 28312.90663700013
# Coeficientes actuales: [ 7.23  -3.314 -1.166], Error actual: 28206.475572000138
# Coeficientes actuales: [ 7.228 -3.323 -1.16 ], Error actual: 28173.969415000134
# Coeficientes actuales: [ 7.218 -3.319 -1.155], Error actual: 28094.40030200014
# Coeficientes actuales: [ 7.213 -3.32  -1.158], Error actual: 28046.68599500014
# Coeficientes actuales: [ 7.209 -3.314 -1.149], Error actual: 28026.16233400014
# Coeficientes actuales: [ 7.208 -3.32  -1.148], Error actual: 28006.287440000142
# Coeficientes actuales: [ 7.207 -3.33  -1.147], Error actual: 27978.83691000014
# Coeficientes actuales: [ 7.199 -3.327 -1.144], Error actual: 27914.60469600014
# Coeficientes actuales: [ 7.189 -3.331 -1.14 ], Error actual: 27819.872764000145
# Coeficientes actuales: [ 7.188 -3.341 -1.146], Error actual: 27789.636823000146
# Coeficientes actuales: [ 7.178 -3.339 -1.144], Error actual: 27705.61566300014
# Coeficientes actuales: [ 7.173 -3.341 -1.135], Error actual: 27661.286085000145
# Coeficientes actuales: [ 7.166 -3.341 -1.129], Error actual: 27601.84748600015
# Coeficientes actuales: [ 7.162 -3.346 -1.136], Error actual: 27554.23580800015
# Coeficientes actuales: [ 7.152 -3.354 -1.129], Error actual: 27453.85377300015
# Coeficientes actuales: [ 7.15  -3.346 -1.139], Error actual: 27447.15099700015
# Coeficientes actuales: [ 7.144 -3.339 -1.137], Error actual: 27408.24010200015
# Coeficientes actuales: [ 7.141 -3.331 -1.141], Error actual: 27395.188229000145
# Coeficientes actuales: [ 7.139 -3.331 -1.148], Error actual: 27374.72570400015
# Coeficientes actuales: [ 7.129 -3.341 -1.151], Error actual: 27266.867389000152
# Coeficientes actuales: [ 7.125 -3.335 -1.15 ], Error actual: 27243.365400000155
# Coeficientes actuales: [ 7.124 -3.333 -1.151], Error actual: 27237.91725400015
# Coeficientes actuales: [ 7.122 -3.327 -1.153], Error actual: 27230.759274000156
# Coeficientes actuales: [ 7.113 -3.329 -1.144], Error actual: 27151.74712800014
# Coeficientes actuales: [ 7.104 -3.337 -1.149], Error actual: 27056.002706000145
# Coeficientes actuales: [ 7.101 -3.337 -1.148], Error actual: 27030.169448000142
# Coeficientes actuales: [ 7.102 -3.347 -1.151], Error actual: 27019.090558000145
# Coeficientes actuales: [ 7.096 -3.356 -1.152], Error actual: 26949.537008000145
# Coeficientes actuales: [ 7.09  -3.355 -1.16 ], Error actual: 26895.80777500014
# Coeficientes actuales: [ 7.08  -3.362 -1.164], Error actual: 26794.090012000142
# Coeficientes actuales: [ 7.073 -3.366 -1.155], Error actual: 26729.415570000147
# Coeficientes actuales: [ 7.07  -3.366 -1.161], Error actual: 26700.93026100015
# Coeficientes actuales: [ 7.063 -3.372 -1.166], Error actual: 26627.062771000154
# Coeficientes actuales: [ 7.056 -3.372 -1.161], Error actual: 26568.366381000156
# Coeficientes actuales: [ 7.055 -3.367 -1.164], Error actual: 26567.71543200015
# Coeficientes actuales: [ 7.051 -3.369 -1.168], Error actual: 26527.77572400015
# Coeficientes actuales: [ 7.041 -3.375 -1.166], Error actual: 26431.01740000015
# Coeficientes actuales: [ 7.037 -3.385 -1.172], Error actual: 26375.69604000016
# Coeficientes actuales: [ 7.032 -3.391 -1.173], Error actual: 26321.139830000157
# Coeficientes actuales: [ 7.032 -3.395 -1.182], Error actual: 26310.22217500016
# Coeficientes actuales: [ 7.031 -3.398 -1.173], Error actual: 26299.681842000155
# Coeficientes actuales: [ 7.028 -3.399 -1.164], Error actual: 26275.572183000157
# Coeficientes actuales: [ 7.024 -3.394 -1.157], Error actual: 26253.05403700015
# Coeficientes actuales: [ 7.022 -3.389 -1.153], Error actual: 26246.575646000165
# Coeficientes actuales: [ 7.019 -3.396 -1.151], Error actual: 26208.727834000154
# Coeficientes actuales: [ 7.009 -3.389 -1.154], Error actual: 26134.33716400016
# Coeficientes actuales: [ 7.01  -3.397 -1.145], Error actual: 26131.88316600016
# Coeficientes actuales: [ 7.008 -3.403 -1.14 ], Error actual: 26105.723975000165
# Coeficientes actuales: [ 7.008 -3.407 -1.133], Error actual: 26101.194486000164
# Coeficientes actuales: [ 7.005 -3.402 -1.128], Error actual: 26086.543443000162
# Coeficientes actuales: [ 6.997 -3.397 -1.125], Error actual: 26028.205885000167
# Coeficientes actuales: [ 6.993 -3.391 -1.129], Error actual: 26003.264397000174
# Coeficientes actuales: [ 6.984 -3.382 -1.129], Error actual: 25942.554501000166
# Coeficientes actuales: [ 6.977 -3.386 -1.137], Error actual: 25872.231054000178
# Coeficientes actuales: [ 6.975 -3.38  -1.14 ], Error actual: 25864.85387500016
# Coeficientes actuales: [ 6.974 -3.385 -1.131], Error actual: 25850.769786000168
# Coeficientes actuales: [ 6.97  -3.38  -1.123], Error actual: 25828.826845000167
# Coeficientes actuales: [ 6.966 -3.375 -1.123], Error actual: 25803.74225400017
# Coeficientes actuales: [ 6.962 -3.381 -1.119], Error actual: 25760.292186000177
# Coeficientes actuales: [ 6.952 -3.389 -1.113], Error actual: 25662.929666000182
# Coeficientes actuales: [ 6.945 -3.388 -1.114], Error actual: 25604.778915000177
# Coeficientes actuales: [ 6.94  -3.397 -1.107], Error actual: 25548.764134000186
# Coeficientes actuales: [ 6.939 -3.405 -1.105], Error actual: 25526.614533000175
# Coeficientes actuales: [ 6.934 -3.412 -1.114], Error actual: 25468.04237600018
# Coeficientes actuales: [ 6.925 -3.412 -1.106], Error actual: 25394.891755000175
# Coeficientes actuales: [ 6.918 -3.408 -1.101], Error actual: 25344.78395700018
# Coeficientes actuales: [ 6.91  -3.399 -1.094], Error actual: 25296.031351000172
# Coeficientes actuales: [ 6.902 -3.393 -1.096], Error actual: 25238.444631000173
# Coeficientes actuales: [ 6.896 -3.4   -1.098], Error actual: 25174.50056400017
# Coeficientes actuales: [ 6.894 -3.4   -1.104], Error actual: 25155.31358000017
# Coeficientes actuales: [ 6.89  -3.403 -1.101], Error actual: 25117.40956200019
# Coeficientes actuales: [ 6.885 -3.395 -1.105], Error actual: 25088.072925000186
# Coeficientes actuales: [ 6.88  -3.398 -1.102], Error actual: 25041.811528000177
# Coeficientes actuales: [ 6.876 -3.408 -1.108], Error actual: 24988.027872000188
# Coeficientes actuales: [ 6.87  -3.4   -1.108], Error actual: 24951.91854000018
# Coeficientes actuales: [ 6.868 -3.403 -1.104], Error actual: 24931.33354300019
# Coeficientes actuales: [ 6.859 -3.407 -1.114], Error actual: 24844.924396000177
# Coeficientes actuales: [ 6.859 -3.414 -1.118], Error actual: 24830.938963000182
# Coeficientes actuales: [ 6.858 -3.423 -1.111], Error actual: 24809.266062000177
# Coeficientes actuales: [ 6.855 -3.43  -1.114], Error actual: 24770.587635000178
# Coeficientes actuales: [ 6.852 -3.438 -1.116], Error actual: 24730.551996000173
# Coeficientes actuales: [ 6.849 -3.443 -1.123], Error actual: 24693.95147700018
# Coeficientes actuales: [ 6.845 -3.453 -1.117], Error actual: 24645.165453000187
# Coeficientes actuales: [ 6.838 -3.447 -1.127], Error actual: 24593.61460600018
# Coeficientes actuales: [ 6.834 -3.455 -1.131], Error actual: 24544.646926000187
# Coeficientes actuales: [ 6.828 -3.453 -1.122], Error actual: 24501.706359000185
# Coeficientes actuales: [ 6.824 -3.449 -1.126], Error actual: 24473.991551000185
# Coeficientes actuales: [ 6.824 -3.456 -1.124], Error actual: 24462.410704000187
# Coeficientes actuales: [ 6.814 -3.447 -1.13 ], Error actual: 24392.972143000192
# Coeficientes actuales: [ 6.815 -3.453 -1.136], Error actual: 24388.423372000194
# Coeficientes actuales: [ 6.805 -3.451 -1.133], Error actual: 24310.208005000186
# Coeficientes actuales: [ 6.797 -3.445 -1.127], Error actual: 24256.81384500019
# Coeficientes actuales: [ 6.796 -3.453 -1.127], Error actual: 24234.507334000184
# Coeficientes actuales: [ 6.79  -3.452 -1.134], Error actual: 24184.033592000185
# Coeficientes actuales: [ 6.785 -3.452 -1.143], Error actual: 24139.358838000193
# Coeficientes actuales: [ 6.779 -3.456 -1.143], Error actual: 24082.889274000187
# Coeficientes actuales: [ 6.776 -3.462 -1.143], Error actual: 24047.69289300018
# Coeficientes actuales: [ 6.769 -3.472 -1.143], Error actual: 23972.64861400019
# Coeficientes actuales: [ 6.765 -3.471 -1.146], Error actual: 23940.391656000185
# Coeficientes actuales: [ 6.76  -3.476 -1.139], Error actual: 23893.258837000187
# Coeficientes actuales: [ 6.751 -3.474 -1.149], Error actual: 23819.184114000185
# Coeficientes actuales: [ 6.745 -3.473 -1.145], Error actual: 23773.28058100018
# Coeficientes actuales: [ 6.742 -3.472 -1.149], Error actual: 23748.968917000177
# Coeficientes actuales: [ 6.735 -3.472 -1.142], Error actual: 23694.349499000182
# Coeficientes actuales: [ 6.731 -3.475 -1.138], Error actual: 23657.972764000187
# Coeficientes actuales: [ 6.722 -3.477 -1.144], Error actual: 23578.852407000188
# Coeficientes actuales: [ 6.718 -3.474 -1.154], Error actual: 23547.719188000192
# Coeficientes actuales: [ 6.717 -3.477 -1.16 ], Error actual: 23532.16396000019
# Coeficientes actuales: [ 6.71  -3.47  -1.163], Error actual: 23486.155325000193
# Coeficientes actuales: [ 6.707 -3.461 -1.172], Error actual: 23473.92988400019
# Coeficientes actuales: [ 6.698 -3.464 -1.179], Error actual: 23393.040213000193
# Coeficientes actuales: [ 6.688 -3.465 -1.185], Error actual: 23307.998082000184
# Coeficientes actuales: [ 6.683 -3.466 -1.181], Error actual: 23267.263938000182
# Coeficientes actuales: [ 6.674 -3.463 -1.187], Error actual: 23197.39063800018
# Coeficientes actuales: [ 6.672 -3.472 -1.197], Error actual: 23162.14030100018
# Coeficientes actuales: [ 6.67  -3.479 -1.196], Error actual: 23134.386007000183
# Coeficientes actuales: [ 6.666 -3.486 -1.199], Error actual: 23089.05102100019
# Coeficientes actuales: [ 6.665 -3.483 -1.2  ], Error actual: 23085.7453560002
# Coeficientes actuales: [ 6.659 -3.481 -1.191], Error actual: 23044.110789000188
# Coeficientes actuales: [ 6.649 -3.488 -1.201], Error actual: 22948.05159400019
# Coeficientes actuales: [ 6.64  -3.493 -1.202], Error actual: 22866.90934300018
# Coeficientes actuales: [ 6.631 -3.503 -1.195], Error actual: 22780.35169300018
# Coeficientes actuales: [ 6.625 -3.5   -1.197], Error actual: 22736.68817000018
# Coeficientes actuales: [ 6.615 -3.505 -1.189], Error actual: 22651.217565000185
# Coeficientes actuales: [ 6.609 -3.504 -1.199], Error actual: 22601.403814000172
# Coeficientes actuales: [ 6.605 -3.498 -1.203], Error actual: 22578.191394000176
# Coeficientes actuales: [ 6.604 -3.501 -1.197], Error actual: 22567.33283400018
# Coeficientes actuales: [ 6.6   -3.496 -1.193], Error actual: 22545.347285000178
# Coeficientes actuales: [ 6.597 -3.488 -1.2  ], Error actual: 22532.41113100019
# Coeficientes actuales: [ 6.587 -3.496 -1.192], Error actual: 22442.287579000185
# Coeficientes actuales: [ 6.584 -3.504 -1.186], Error actual: 22407.172596000175
# Coeficientes actuales: [ 6.581 -3.498 -1.18 ], Error actual: 22395.602763000177
# Coeficientes actuales: [ 6.581 -3.506 -1.187], Error actual: 22379.640578000177
# Coeficientes actuales: [ 6.577 -3.497 -1.184], Error actual: 22364.10143200018
# Coeficientes actuales: [ 6.572 -3.507 -1.175], Error actual: 22310.92693000018
# Coeficientes actuales: [ 6.563 -3.515 -1.179], Error actual: 22224.86174100018
# Coeficientes actuales: [ 6.563 -3.517 -1.171], Error actual: 22224.385861000184
# Coeficientes actuales: [ 6.561 -3.522 -1.167], Error actual: 22201.648722000187
# Coeficientes actuales: [ 6.56  -3.518 -1.164], Error actual: 22201.511580000184
# Coeficientes actuales: [ 6.556 -3.511 -1.157], Error actual: 22184.123158000177
# Coeficientes actuales: [ 6.548 -3.519 -1.164], Error actual: 22105.12122300019
# Coeficientes actuales: [ 6.546 -3.52  -1.169], Error actual: 22085.90002100019
# Coeficientes actuales: [ 6.539 -3.52  -1.16 ], Error actual: 22033.981803000188
# Coeficientes actuales: [ 6.535 -3.523 -1.157], Error actual: 21998.585173000185
# Coeficientes actuales: [ 6.527 -3.518 -1.155], Error actual: 21944.73228600019
# Coeficientes actuales: [ 6.521 -3.519 -1.16 ], Error actual: 21894.18924400019
# Coeficientes actuales: [ 6.517 -3.514 -1.162], Error actual: 21870.400259000195
# Coeficientes actuales: [ 6.514 -3.518 -1.162], Error actual: 21840.251668000194
# Coeficientes actuales: [ 6.512 -3.526 -1.162], Error actual: 21811.330264000193
# Coeficientes actuales: [ 6.506 -3.525 -1.154], Error actual: 21768.86331100019
# Coeficientes actuales: [ 6.503 -3.527 -1.148], Error actual: 21744.219656000198
# Coeficientes actuales: [ 6.493 -3.523 -1.148], Error actual: 21672.713116000188
# Coeficientes actuales: [ 6.484 -3.528 -1.151], Error actual: 21593.231389000186
# Coeficientes actuales: [ 6.482 -3.52  -1.157], Error actual: 21588.71452500019
# Coeficientes actuales: [ 6.473 -3.517 -1.159], Error actual: 21522.89886100019
# Coeficientes actuales: [ 6.47  -3.523 -1.169], Error actual: 21486.19929000018
# Coeficientes actuales: [ 6.462 -3.519 -1.165], Error actual: 21432.050730000192
# Coeficientes actuales: [ 6.461 -3.525 -1.163], Error actual: 21415.152349000182
# Coeficientes actuales: [ 6.454 -3.518 -1.167], Error actual: 21370.953893000184
# Coeficientes actuales: [ 6.452 -3.52  -1.173], Error actual: 21350.08398900019
# Coeficientes actuales: [ 6.442 -3.511 -1.175], Error actual: 21286.719502000182
# Coeficientes actuales: [ 6.441 -3.508 -1.182], Error actual: 21281.44445900019
# Coeficientes actuales: [ 6.435 -3.5   -1.186], Error actual: 21246.744675000184
# Coeficientes actuales: [ 6.426 -3.506 -1.178], Error actual: 21170.28085200018
# Coeficientes actuales: [ 6.42  -3.508 -1.177], Error actual: 21121.13205300018
# Coeficientes actuales: [ 6.417 -3.501 -1.182], Error actual: 21107.683404000185
# Coeficientes actuales: [ 6.412 -3.497 -1.181], Error actual: 21076.054498000183
# Coeficientes actuales: [ 6.402 -3.495 -1.173], Error actual: 21005.209914000177
# Coeficientes actuales: [ 6.396 -3.497 -1.182], Error actual: 20952.795847000183
# Coeficientes actuales: [ 6.386 -3.506 -1.186], Error actual: 20860.229204000174
# Coeficientes actuales: [ 6.379 -3.501 -1.194], Error actual: 20812.011864000186
# Coeficientes actuales: [ 6.373 -3.5   -1.186], Error actual: 20770.54276300018
# Coeficientes actuales: [ 6.366 -3.504 -1.184], Error actual: 20711.37204400019
# Coeficientes actuales: [ 6.357 -3.499 -1.194], Error actual: 20647.41840800018
# Coeficientes actuales: [ 6.35  -3.494 -1.19 ], Error actual: 20603.565524000183
# Coeficientes actuales: [ 6.34  -3.496 -1.186], Error actual: 20525.757236000183
# Coeficientes actuales: [ 6.33  -3.502 -1.183], Error actual: 20441.362413000184
# Coeficientes actuales: [ 6.32  -3.493 -1.188], Error actual: 20378.36667900019
# Coeficientes actuales: [ 6.31  -3.501 -1.193], Error actual: 20288.38627000019
# Coeficientes actuales: [ 6.308 -3.511 -1.194], Error actual: 20257.04792700019
# Coeficientes actuales: [ 6.301 -3.517 -1.185], Error actual: 20197.832005000197
# Coeficientes actuales: [ 6.298 -3.515 -1.19 ], Error actual: 20176.744567000198
# Coeficientes actuales: [ 6.293 -3.513 -1.192], Error actual: 20141.648184000194
# Coeficientes actuales: [ 6.283 -3.504 -1.199], Error actual: 20078.455258000195
# Coeficientes actuales: [ 6.276 -3.509 -1.204], Error actual: 20016.38031900019
# Coeficientes actuales: [ 6.27  -3.508 -1.213], Error actual: 19970.015229000197
# Coeficientes actuales: [ 6.265 -3.505 -1.217], Error actual: 19936.01192500019
# Coeficientes actuales: [ 6.266 -3.512 -1.219], Error actual: 19931.7771890002
# Coeficientes actuales: [ 6.257 -3.511 -1.219], Error actual: 19866.137581000192
# Coeficientes actuales: [ 6.255 -3.509 -1.217], Error actual: 19855.032525000195
# Coeficientes actuales: [ 6.249 -3.508 -1.216], Error actual: 19812.204939000192
# Coeficientes actuales: [ 6.241 -3.517 -1.217], Error actual: 19738.18503700018
# Coeficientes actuales: [ 6.24  -3.527 -1.225], Error actual: 19712.407446000194
# Coeficientes actuales: [ 6.234 -3.518 -1.228], Error actual: 19680.935712000184
# Coeficientes actuales: [ 6.234 -3.525 -1.232], Error actual: 19668.646519000184
# Coeficientes actuales: [ 6.228 -3.517 -1.232], Error actual: 19636.64263100019
# Coeficientes actuales: [ 6.219 -3.527 -1.24 ], Error actual: 19551.691128000184
# Coeficientes actuales: [ 6.215 -3.528 -1.249], Error actual: 19517.56647000019
# Coeficientes actuales: [ 6.212 -3.519 -1.248], Error actual: 19509.744831000186
# Coeficientes actuales: [ 6.202 -3.521 -1.242], Error actual: 19434.765239000197
# Coeficientes actuales: [ 6.201 -3.519 -1.245], Error actual: 19429.508709000187
# Coeficientes actuales: [ 6.199 -3.528 -1.254], Error actual: 19397.80937100019
# Coeficientes actuales: [ 6.195 -3.538 -1.248], Error actual: 19354.798139000188
# Coeficientes actuales: [ 6.186 -3.547 -1.255], Error actual: 19272.375390000194
# Coeficientes actuales: [ 6.188 -3.557 -1.262], Error actual: 19269.294671000185
# Coeficientes actuales: [ 6.188 -3.559 -1.255], Error actual: 19268.494642000183
# Coeficientes actuales: [ 6.185 -3.551 -1.263], Error actual: 19256.220885000184
# Coeficientes actuales: [ 6.176 -3.558 -1.255], Error actual: 19182.01473300018
# Coeficientes actuales: [ 6.175 -3.557 -1.246], Error actual: 19179.173800000175
# Coeficientes actuales: [ 6.174 -3.56  -1.254], Error actual: 19164.604840000182
# Coeficientes actuales: [ 6.167 -3.553 -1.246], Error actual: 19126.77229600018
# Coeficientes actuales: [ 6.161 -3.547 -1.246], Error actual: 19092.138136000176
# Coeficientes actuales: [ 6.156 -3.549 -1.249], Error actual: 19051.555794000178
# Coeficientes actuales: [ 6.155 -3.546 -1.256], Error actual: 19046.589451000178
# Coeficientes actuales: [ 6.147 -3.55  -1.257], Error actual: 18981.768290000167
# Coeficientes actuales: [ 6.144 -3.554 -1.252], Error actual: 18955.400412000177
# Coeficientes actuales: [ 6.138 -3.555 -1.253], Error actual: 18909.877690000183
# Coeficientes actuales: [ 6.129 -3.549 -1.256], Error actual: 18852.681496000172
# Coeficientes actuales: [ 6.131 -3.558 -1.259], Error actual: 18852.47347000017
# Coeficientes actuales: [ 6.126 -3.561 -1.251], Error actual: 18814.185594000173
# Coeficientes actuales: [ 6.119 -3.569 -1.248], Error actual: 18752.212188000176
# Coeficientes actuales: [ 6.113 -3.564 -1.246], Error actual: 18717.04673100017
# Coeficientes actuales: [ 6.108 -3.563 -1.248], Error actual: 18681.770071000174
# Coeficientes actuales: [ 6.1   -3.561 -1.239], Error actual: 18629.92306200016
# Coeficientes actuales: [ 6.093 -3.567 -1.245], Error actual: 18568.414941000174
# Coeficientes actuales: [ 6.086 -3.572 -1.239], Error actual: 18512.365629000175
# Coeficientes actuales: [ 6.082 -3.581 -1.237], Error actual: 18470.631934000176
# Coeficientes actuales: [ 6.073 -3.582 -1.244], Error actual: 18402.28713100017
# Coeficientes actuales: [ 6.073 -3.592 -1.248], Error actual: 18385.930771000178
# Coeficientes actuales: [ 6.068 -3.587 -1.241], Error actual: 18359.86880600018
# Coeficientes actuales: [ 6.067 -3.591 -1.238], Error actual: 18347.635180000172
# Coeficientes actuales: [ 6.058 -3.596 -1.248], Error actual: 18272.56804400017
# Coeficientes actuales: [ 6.05  -3.592 -1.241], Error actual: 18223.673685000165
# Coeficientes actuales: [ 6.043 -3.59  -1.243], Error actual: 18176.129950000173
# Coeficientes actuales: [ 6.035 -3.596 -1.244], Error actual: 18109.885067000174
# Coeficientes actuales: [ 6.034 -3.603 -1.246], Error actual: 18091.68051900017
# Coeficientes actuales: [ 6.025 -3.602 -1.237], Error actual: 18032.089054000167
# Coeficientes actuales: [ 6.016 -3.605 -1.23 ], Error actual: 17966.013863000164
# Coeficientes actuales: [ 6.012 -3.61  -1.232], Error actual: 17929.632380000166
# Coeficientes actuales: [ 6.008 -3.618 -1.226], Error actual: 17891.336392000165
# Coeficientes actuales: [ 5.999 -3.617 -1.234], Error actual: 17826.778616000163
# Coeficientes actuales: [ 5.995 -3.625 -1.242], Error actual: 17784.23740000017
# Coeficientes actuales: [ 5.987 -3.632 -1.251], Error actual: 17714.788698000164
# Coeficientes actuales: [ 5.985 -3.639 -1.243], Error actual: 17692.881213000168
# Coeficientes actuales: [ 5.975 -3.633 -1.235], Error actual: 17634.013381000168
# Coeficientes actuales: [ 5.966 -3.642 -1.229], Error actual: 17559.570709000156
# Coeficientes actuales: [ 5.958 -3.65  -1.233], Error actual: 17490.662125000166
# Coeficientes actuales: [ 5.951 -3.654 -1.229], Error actual: 17437.183954000167
# Coeficientes actuales: [ 5.948 -3.652 -1.23 ], Error actual: 17418.891636000168
# Coeficientes actuales: [ 5.943 -3.653 -1.24 ], Error actual: 17379.535020000167
# Coeficientes actuales: [ 5.938 -3.658 -1.24 ], Error actual: 17337.452000000165
# Coeficientes actuales: [ 5.93  -3.66  -1.236], Error actual: 17280.193260000175
# Coeficientes actuales: [ 5.922 -3.66  -1.229], Error actual: 17226.85621300017
# ...
# Coeficientes actuales: [-1.654  8.206  1.366], Error actual: 2.5866439999999224
# Coeficientes actuales: [-1.655  8.212  1.364], Error actual: 2.57238699999994
# Coeficientes actuales: [-1.653  8.216  1.36 ], Error actual: 2.5583150000001935
# Coeficientes actuales: [-1.659  8.223  1.357], Error actual: 2.55061299999976
# Coeficientes actuales: [-1.656  8.223  1.361], Error actual: 2.5466460000000612
# Coeficientes actuales: [-1.652  8.218  1.352], Error actual: 2.546236000000288
# Coeficientes actuales: [-1.659  8.227  1.345], Error actual: 2.5262129999997867
# Coeficientes actuales: [-1.655  8.232  1.345], Error actual: 2.5110460000002606
# Coeficientes actuales: [-1.656  8.239  1.34 ], Error actual: 2.4927990000002866
# Coeficientes actuales: [-1.658  8.234  1.332], Error actual: 2.4901599999999626
# Coeficientes actuales: [-1.66   8.242  1.334], Error actual: 2.4786319999999487
# Coeficientes actuales: [-1.656  8.25   1.334], Error actual: 2.4750960000004834
# Coeficientes actuales: [-1.657  8.256  1.327], Error actual: 2.4551740000004796
# Coeficientes actuales: [-1.662  8.26   1.327], Error actual: 2.436285000000097
# Coeficientes actuales: [-1.662  8.259  1.325], Error actual: 2.4353700000000673
# Coeficientes actuales: [-1.662  8.262  1.318], Error actual: 2.4208840000000946
# Coeficientes actuales: [-1.662  8.267  1.321], Error actual: 2.4174980000002098
# Coeficientes actuales: [-1.666  8.27   1.318], Error actual: 2.4111239999998832
# Coeficientes actuales: [-1.667  8.275  1.31 ], Error actual: 2.3932119999998527
# Coeficientes actuales: [-1.666  8.277  1.306], Error actual: 2.3810709999999666
# Coeficientes actuales: [-1.665  8.278  1.298], Error actual: 2.3679390000000424
# Coeficientes actuales: [-1.664  8.276  1.291], Error actual: 2.362549000000065
# Coeficientes actuales: [-1.659  8.285  1.281], Error actual: 2.361221000000664
# Coeficientes actuales: [-1.666  8.282  1.286], Error actual: 2.3471559999999765
# Coeficientes actuales: [-1.665  8.288  1.277], Error actual: 2.324778000000146
# Coeficientes actuales: [-1.671  8.295  1.278], Error actual: 2.3246039999997374
# Coeficientes actuales: [-1.665  8.296  1.282], Error actual: 2.321883000000336
# Coeficientes actuales: [-1.664  8.288  1.273], Error actual: 2.3210770000002223
# Coeficientes actuales: [-1.661  8.292  1.265], Error actual: 2.3199300000005447
# Coeficientes actuales: [-1.662  8.287  1.257], Error actual: 2.3072260000003117
# Coeficientes actuales: [-1.663  8.29   1.25 ], Error actual: 2.2923470000002473
# Coeficientes actuales: [-1.667  8.298  1.242], Error actual: 2.2685310000000043
# Coeficientes actuales: [-1.665  8.307  1.232], Error actual: 2.2446840000003228
# Coeficientes actuales: [-1.663  8.316  1.224], Error actual: 2.2413870000006546
# Coeficientes actuales: [-1.669  8.325  1.233], Error actual: 2.214117000000324
# Coeficientes actuales: [-1.673  8.322  1.223], Error actual: 2.21022599999984
# Coeficientes actuales: [-1.669  8.33   1.221], Error actual: 2.1942060000003694
# Coeficientes actuales: [-1.668  8.333  1.218], Error actual: 2.1936710000005037
# Coeficientes actuales: [-1.669  8.326  1.215], Error actual: 2.191074000000258
# Coeficientes actuales: [-1.675  8.332  1.216], Error actual: 2.185954999999826
# Coeficientes actuales: [-1.673  8.335  1.208], Error actual: 2.1664600000000305
# Coeficientes actuales: [-1.678  8.344  1.202], Error actual: 2.1561199999997203
# Coeficientes actuales: [-1.673  8.341  1.2  ], Error actual: 2.147480000000116
# Coeficientes actuales: [-1.671  8.345  1.195], Error actual: 2.1410930000003643
# Coeficientes actuales: [-1.674  8.352  1.19 ], Error actual: 2.119128000000205
# Coeficientes actuales: [-1.682  8.36   1.181], Error actual: 2.1184609999995847
# Coeficientes actuales: [-1.681  8.361  1.19 ], Error actual: 2.113979999999739
# Coeficientes actuales: [-1.678  8.365  1.197], Error actual: 2.1037740000001324
# Coeficientes actuales: [-1.68   8.373  1.19 ], Error actual: 2.0831910000000784
# Coeficientes actuales: [-1.679  8.38   1.189], Error actual: 2.0746300000003015
# Coeficientes actuales: [-1.68   8.386  1.194], Error actual: 2.073352000000359
# Coeficientes actuales: [-1.681  8.379  1.186], Error actual: 2.069224000000084
# Coeficientes actuales: [-1.677  8.383  1.177], Error actual: 2.066421000000495
# Coeficientes actuales: [-1.681  8.382  1.18 ], Error actual: 2.0579950000001164
# Coeficientes actuales: [-1.679  8.382  1.175], Error actual: 2.055438000000279
# Coeficientes actuales: [-1.683  8.385  1.177], Error actual: 2.05114899999998
# Coeficientes actuales: [-1.684  8.392  1.168], Error actual: 2.0303839999999886
# Coeficientes actuales: [-1.689  8.4    1.163], Error actual: 2.0273819999996676
# Coeficientes actuales: [-1.686  8.4    1.161], Error actual: 2.0117249999999327
# Coeficientes actuales: [-1.684  8.409  1.151], Error actual: 1.9869660000002496
# Coeficientes actuales: [-1.69   8.414  1.152], Error actual: 1.9855199999998057
# Coeficientes actuales: [-1.688  8.416  1.16 ], Error actual: 1.9840000000000633
# Coeficientes actuales: [-1.689  8.418  1.155], Error actual: 1.976369999999987
# Coeficientes actuales: [-1.692  8.427  1.154], Error actual: 1.9646069999998865
# Coeficientes actuales: [-1.695  8.436  1.162], Error actual: 1.9634829999998278
# Coeficientes actuales: [-1.696  8.443  1.171], Error actual: 1.9623859999999191
# Coeficientes actuales: [-1.695  8.444  1.166], Error actual: 1.9530270000000105
# Coeficientes actuales: [-1.698  8.453  1.162], Error actual: 1.9389589999998924
# Coeficientes actuales: [-1.696  8.453  1.164], Error actual: 1.9388550000000908
# Coeficientes actuales: [-1.699  8.462  1.169], Error actual: 1.9351060000000193
# Coeficientes actuales: [-1.7    8.462  1.159], Error actual: 1.9245969999998744
# Coeficientes actuales: [-1.7    8.464  1.151], Error actual: 1.9117569999998754
# Coeficientes actuales: [-1.701  8.467  1.147], Error actual: 1.9048769999998254
# Coeficientes actuales: [-1.698  8.47   1.14 ], Error actual: 1.8877120000001344
# Coeficientes actuales: [-1.702  8.474  1.133], Error actual: 1.8796209999998112
# Coeficientes actuales: [-1.698  8.477  1.128], Error actual: 1.8658310000002227
# Coeficientes actuales: [-1.704  8.486  1.13 ], Error actual: 1.8595439999998542
# Coeficientes actuales: [-1.702  8.484  1.126], Error actual: 1.853751999999982
# Coeficientes actuales: [-1.705  8.49   1.122], Error actual: 1.8468749999998026
# Coeficientes actuales: [-1.7    8.494  1.116], Error actual: 1.8341720000003239
# Coeficientes actuales: [-1.703  8.499  1.107], Error actual: 1.812165000000103
# Coeficientes actuales: [-1.704  8.501  1.097], Error actual: 1.7984340000000028
# Coeficientes actuales: [-1.705  8.505  1.097], Error actual: 1.7936849999999906
# Coeficientes actuales: [-1.701  8.503  1.088], Error actual: 1.7889720000002827
# Coeficientes actuales: [-1.705  8.507  1.081], Error actual: 1.774004999999954
# Coeficientes actuales: [-1.703  8.511  1.074], Error actual: 1.7613720000001962
# Coeficientes actuales: [-1.706  8.514  1.076], Error actual: 1.759343999999984
# Coeficientes actuales: [-1.706  8.514  1.071], Error actual: 1.7544689999999579
# Coeficientes actuales: [-1.702  8.52   1.062], Error actual: 1.7456400000004162
# Coeficientes actuales: [-1.705  8.52   1.061], Error actual: 1.73553000000013
# Coeficientes actuales: [-1.707  8.522  1.052], Error actual: 1.7254109999999354
# Coeficientes actuales: [-1.706  8.522  1.046], Error actual: 1.7185160000000017
# Coeficientes actuales: [-1.71   8.526  1.036], Error actual: 1.7179359999996602
# Coeficientes actuales: [-1.705  8.528  1.033], Error actual: 1.6984740000001572
# Coeficientes actuales: [-1.708  8.531  1.033], Error actual: 1.6956539999999365
# Coeficientes actuales: [-1.706  8.54   1.026], Error actual: 1.678840000000277
# Coeficientes actuales: [-1.708  8.539  1.022], Error actual: 1.6734950000000481
# Coeficientes actuales: [-1.706  8.546  1.02 ], Error actual: 1.6693600000003725
# Coeficientes actuales: [-1.707  8.544  1.018], Error actual: 1.6649710000002278
# Coeficientes actuales: [-1.708  8.552  1.009], Error actual: 1.6472610000002554
# Coeficientes actuales: [-1.711  8.556  1.003], Error actual: 1.6346020000000239
# Coeficientes actuales: [-1.711  8.563  0.997], Error actual: 1.6203890000001413
# Coeficientes actuales: [-1.715  8.566  0.989], Error actual: 1.6164819999997908
# Coeficientes actuales: [-1.716  8.573  0.993], Error actual: 1.6077619999998576
# Coeficientes actuales: [-1.714  8.579  0.986], Error actual: 1.5905110000001372
# Coeficientes actuales: [-1.712  8.581  0.981], Error actual: 1.589138000000344
# Coeficientes actuales: [-1.718  8.583  0.975], Error actual: 1.582829999999784
# Coeficientes actuales: [-1.718  8.584  0.965], Error actual: 1.5751569999997583
# Coeficientes actuales: [-1.716  8.581  0.959], Error actual: 1.5705659999998558
# Coeficientes actuales: [-1.713  8.589  0.958], Error actual: 1.5589240000003015
# Coeficientes actuales: [-1.716  8.592  0.956], Error actual: 1.5495360000000689
# Coeficientes actuales: [-1.715  8.593  0.956], Error actual: 1.5491320000001878
# Coeficientes actuales: [-1.721  8.601  0.956], Error actual: 1.5449039999997876
# Coeficientes actuales: [-1.718  8.609  0.946], Error actual: 1.5211510000001878
# Coeficientes actuales: [-1.725  8.618  0.943], Error actual: 1.5184339999997007
# Coeficientes actuales: [-1.723  8.623  0.936], Error actual: 1.4964719999999565
# Coeficientes actuales: [-1.725  8.632  0.93 ], Error actual: 1.4817309999999224
# Coeficientes actuales: [-1.725  8.631  0.925], Error actual: 1.4804289999998785
# Coeficientes actuales: [-1.725  8.636  0.923], Error actual: 1.470629999999971
# Coeficientes actuales: [-1.725  8.643  0.917], Error actual: 1.457013000000086
# Coeficientes actuales: [-1.729  8.647  0.913], Error actual: 1.4565889999997739
# Coeficientes actuales: [-1.722  8.645  0.909], Error actual: 1.4559980000003714
# Coeficientes actuales: [-1.725  8.653  0.903], Error actual: 1.436869000000227
# Coeficientes actuales: [-1.73   8.66   0.909], Error actual: 1.4331249999999285
# Coeficientes actuales: [-1.732  8.662  0.903], Error actual: 1.4328689999997535
# Coeficientes actuales: [-1.733  8.668  0.906], Error actual: 1.4264269999997994
# Coeficientes actuales: [-1.729  8.677  0.913], Error actual: 1.4261090000003898
# Coeficientes actuales: [-1.73   8.678  0.908], Error actual: 1.4162240000002964
# Coeficientes actuales: [-1.73   8.678  0.902], Error actual: 1.4100680000002674
# Coeficientes actuales: [-1.732  8.677  0.895], Error actual: 1.402310000000023
# Coeficientes actuales: [-1.733  8.68   0.892], Error actual: 1.3972989999999759
# Coeficientes actuales: [-1.734  8.687  0.889], Error actual: 1.3872260000000112
# Coeficientes actuales: [-1.739  8.696  0.88 ], Error actual: 1.3825389999996773
# Coeficientes actuales: [-1.733  8.689  0.872], Error actual: 1.3721200000000637
# Coeficientes actuales: [-1.733  8.698  0.866], Error actual: 1.3601470000002214
# Coeficientes actuales: [-1.733  8.694  0.857], Error actual: 1.3565100000000951
# Coeficientes actuales: [-1.735  8.696  0.854], Error actual: 1.35378699999993
# Coeficientes actuales: [-1.738  8.705  0.848], Error actual: 1.3439349999998003
# Coeficientes actuales: [-1.741  8.714  0.839], Error actual: 1.3358739999996565
# Coeficientes actuales: [-1.739  8.716  0.833], Error actual: 1.3202139999998603
# Coeficientes actuales: [-1.739  8.717  0.831], Error actual: 1.317564999999873
# Coeficientes actuales: [-1.738  8.72   0.827], Error actual: 1.3091890000000102
# Coeficientes actuales: [-1.735  8.724  0.817], Error actual: 1.3044700000003389
# Coeficientes actuales: [-1.736  8.728  0.811], Error actual: 1.2951010000002938
# Coeficientes actuales: [-1.736  8.728  0.806], Error actual: 1.2916360000002698
# Coeficientes actuales: [-1.736  8.735  0.803], Error actual: 1.2877940000004016
# Coeficientes actuales: [-1.736  8.733  0.801], Error actual: 1.2864660000003527
# Coeficientes actuales: [-1.736  8.735  0.799], Error actual: 1.2847060000003816
# Coeficientes actuales: [-1.738  8.735  0.795], Error actual: 1.2758220000001679
# Coeficientes actuales: [-1.74   8.737  0.797], Error actual: 1.2737940000000314
# Coeficientes actuales: [-1.743  8.742  0.791], Error actual: 1.2699659999998165
# Coeficientes actuales: [-1.743  8.746  0.795], Error actual: 1.26426999999992
# Coeficientes actuales: [-1.746  8.755  0.799], Error actual: 1.259165999999842
# Coeficientes actuales: [-1.744  8.764  0.796], Error actual: 1.246496000000211
# Coeficientes actuales: [-1.75   8.77   0.788], Error actual: 1.243039999999717
# Coeficientes actuales: [-1.743  8.764  0.781], Error actual: 1.2384060000002306
# Coeficientes actuales: [-1.749  8.771  0.772], Error actual: 1.231483999999756
# Coeficientes actuales: [-1.744  8.78   0.764], Error actual: 1.2193600000003861
# Coeficientes actuales: [-1.749  8.789  0.757], Error actual: 1.1983970000000599
# Coeficientes actuales: [-1.75   8.791  0.75 ], Error actual: 1.1935589999999716
# Coeficientes actuales: [-1.75   8.799  0.742], Error actual: 1.1813350000001028
# Coeficientes actuales: [-1.756  8.808  0.737], Error actual: 1.1805089999996874
# Coeficientes actuales: [-1.751  8.805  0.735], Error actual: 1.1721330000000958
# Coeficientes actuales: [-1.755  8.814  0.74 ], Error actual: 1.1670989999999277
# Coeficientes actuales: [-1.751  8.818  0.731], Error actual: 1.1645260000003526
# Coeficientes actuales: [-1.756  8.816  0.731], Error actual: 1.1635089999998272
# Coeficientes actuales: [-1.753  8.82   0.736], Error actual: 1.1606830000002262
# Coeficientes actuales: [-1.754  8.819  0.732], Error actual: 1.1572870000000905
# Coeficientes actuales: [-1.754  8.816  0.724], Error actual: 1.1566839999999878
# Coeficientes actuales: [-1.754  8.824  0.715], Error actual: 1.1448850000001125
# Coeficientes actuales: [-1.757  8.828  0.708], Error actual: 1.1405709999998772
# Coeficientes actuales: [-1.756  8.831  0.702], Error actual: 1.132863000000004
# Coeficientes actuales: [-1.756  8.834  0.692], Error actual: 1.1262040000000184
# Coeficientes actuales: [-1.756  8.841  0.691], Error actual: 1.119574000000159
# Coeficientes actuales: [-1.758  8.845  0.696], Error actual: 1.116943000000075
# Coeficientes actuales: [-1.762  8.852  0.688], Error actual: 1.112363999999802
# Coeficientes actuales: [-1.759  8.859  0.679], Error actual: 1.0988290000001921
# Coeficientes actuales: [-1.759  8.864  0.681], Error actual: 1.0987260000003045
# Coeficientes actuales: [-1.765  8.872  0.682], Error actual: 1.0890589999999047
# Coeficientes actuales: [-1.765  8.881  0.686], Error actual: 1.0826360000001118
# Coeficientes actuales: [-1.767  8.881  0.683], Error actual: 1.0823249999999034
# Coeficientes actuales: [-1.763  8.875  0.675], Error actual: 1.0822370000001258
# Coeficientes actuales: [-1.765  8.882  0.674], Error actual: 1.075747000000073
# Coeficientes actuales: [-1.763  8.881  0.664], Error actual: 1.0739320000001973
# Coeficientes actuales: [-1.765  8.889  0.664], Error actual: 1.0669360000001722
# Coeficientes actuales: [-1.768  8.898  0.659], Error actual: 1.0565730000000504
# Coeficientes actuales: [-1.772  8.904  0.656], Error actual: 1.056431999999777
# Coeficientes actuales: [-1.772  8.908  0.664], Error actual: 1.053375999999902
# Coeficientes actuales: [-1.774  8.913  0.658], Error actual: 1.050606999999783
# Coeficientes actuales: [-1.768  8.918  0.649], Error actual: 1.0487730000004187
# Coeficientes actuales: [-1.768  8.917  0.643], Error actual: 1.0438460000003704
# Coeficientes actuales: [-1.773  8.919  0.641], Error actual: 1.0344209999999239
# Coeficientes actuales: [-1.773  8.922  0.635], Error actual: 1.029185999999957
# Coeficientes actuales: [-1.776  8.928  0.625], Error actual: 1.0273329999997427
# Coeficientes actuales: [-1.777  8.936  0.622], Error actual: 1.0179389999997979
# Coeficientes actuales: [-1.775  8.945  0.623], Error actual: 1.0095650000001866
# Coeficientes actuales: [-1.776  8.943  0.617], Error actual: 1.0066140000000179
# Coeficientes actuales: [-1.778  8.951  0.618], Error actual: 1.0019590000000005
# Coeficientes actuales: [-1.777  8.952  0.617], Error actual: 1.0012260000001125
# Coeficientes actuales: [-1.78   8.956  0.616], Error actual: 0.9992959999999047
# array([-1.78 ,  8.956,  0.616])

# %% [markdown]
# ### Ejercicio 9: Resolver el ejercicio 3 del TP1 usando NumPy
# Buscar los coeficientes de la función que minimice la suma de los cuadrados de las diferencias entre los valores medidos y los valores de la función.
#
# 1. Crear un array con los coeficientes elegidos al azar (usar `randint(-10,10,3)`).
# 2. Calcular el valor de la función y el error correspondiente.
# 3. Mientras que el error sea mayor a 1:
#     1. Definir nuevos coeficientes agregándoles un pequeño valor al azar a los coeficientes actuales (aprendizaje = 0.001).
#     2. Si el error para los nuevos coeficientes es menor que el anterior, reemplazar los coeficientes actuales por los nuevos.

# %%
import numpy as np
from numpy.random import randint

def f(x, coeficientes):
    a,b,c = coeficientes
    return a*x**2 + b*x + c

def error(y, y_pred):
    return np.sum((y - y_pred)**2)

X = np.array([0, 1, 2, 3, 5])
Y = np.array([0, 8,12,11, 1])
def buscar_coeficientes():
    coeficientes = randint(-10, 10, 3)  
    Y_pred = f(X, coeficientes)
    error_actual = error(Y, Y_pred)
    
    aprendizaje = 0.001 

    while error_actual > 1:  
        nuevos_coeficientes = coeficientes + randint(-10, 10, 3) * aprendizaje
        Y_pred = f(X, nuevos_coeficientes)
        nuevo_error = error(Y, Y_pred)
        if nuevo_error < error_actual:
            coeficientes = nuevos_coeficientes
            error_actual = nuevo_error
            print(f"Coeficientes actuales: {coeficientes}, Error actual: {error_actual}")

    return coeficientes


coeficientes = buscar_coeficientes()
coeficientes
# Out:
# Coeficientes actuales: [ 4.992 -8.998 -8.005], Error actual: 5804.204301000002
# Coeficientes actuales: [ 4.989 -8.994 -8.006], Error actual: 5796.5081709999995
# Coeficientes actuales: [ 4.981 -8.988 -7.999], Error actual: 5773.73199
# Coeficientes actuales: [ 4.977 -8.998 -8.002], Error actual: 5754.455331000003
# Coeficientes actuales: [ 4.971 -9.003 -8.004], Error actual: 5731.585800000001
# Coeficientes actuales: [ 4.961 -9.01  -8.011], Error actual: 5694.245650000003
# Coeficientes actuales: [ 4.955 -9.02  -8.02 ], Error actual: 5668.390475000002
# Coeficientes actuales: [ 4.946 -9.025 -8.013], Error actual: 5636.414093999999
# Coeficientes actuales: [ 4.947 -9.034 -8.016], Error actual: 5634.395626999999
# Coeficientes actuales: [ 4.944 -9.032 -8.016], Error actual: 5625.766719999999
# Coeficientes actuales: [ 4.936 -9.035 -8.016], Error actual: 5598.063935000001
# Coeficientes actuales: [ 4.928 -9.036 -8.025], Error actual: 5571.228525
# Coeficientes actuales: [ 4.928 -9.042 -8.034], Error actual: 5567.466696
# Coeficientes actuales: [ 4.928 -9.042 -8.039], Error actual: 5567.261221000001
# Coeficientes actuales: [ 4.927 -9.051 -8.03 ], Error actual: 5559.326091999998
# Coeficientes actuales: [ 4.922 -9.044 -8.034], Error actual: 5547.000887999999
# Coeficientes actuales: [ 4.921 -9.042 -8.032], Error actual: 5544.989306999996
# Coeficientes actuales: [ 4.912 -9.038 -8.028], Error actual: 5518.487515999997
# Coeficientes actuales: [ 4.908 -9.048 -8.029], Error actual: 5500.050212999999
# Coeficientes actuales: [ 4.901 -9.052 -8.032], Error actual: 5475.366066999999
# Coeficientes actuales: [ 4.895 -9.047 -8.024], Error actual: 5459.354551999998
# Coeficientes actuales: [ 4.885 -9.049 -8.02 ], Error actual: 5426.684743999998
# Coeficientes actuales: [ 4.877 -9.056 -8.015], Error actual: 5397.766022000002
# Coeficientes actuales: [ 4.873 -9.06  -8.023], Error actual: 5382.696150000001
# Coeficientes actuales: [ 4.867 -9.062 -8.029], Error actual: 5362.558882000002
# Coeficientes actuales: [ 4.866 -9.06  -8.026], Error actual: 5360.620919999999
# Coeficientes actuales: [ 4.864 -9.056 -8.029], Error actual: 5356.422829
# Coeficientes actuales: [ 4.86  -9.057 -8.027], Error actual: 5343.439414000002
# Coeficientes actuales: [ 4.851 -9.059 -8.019], Error actual: 5314.573069000002
# Coeficientes actuales: [ 4.841 -9.051 -8.017], Error actual: 5287.882053000002
# Coeficientes actuales: [ 4.841 -9.06  -8.012], Error actual: 5283.227827
# Coeficientes actuales: [ 4.839 -9.066 -8.011], Error actual: 5273.859054000001
# Coeficientes actuales: [ 4.829 -9.064 -8.005], Error actual: 5244.262810000005
# Coeficientes actuales: [ 4.82  -9.074 -8.007], Error actual: 5211.253724999999
# Coeficientes actuales: [ 4.813 -9.072 -8.   ], Error actual: 5191.120171000001
# Coeficientes actuales: [ 4.813 -9.075 -8.007], Error actual: 5189.319909000002
# Coeficientes actuales: [ 4.81  -9.083 -8.007], Error actual: 5175.971678000002
# Coeficientes actuales: [ 4.809 -9.087 -8.012], Error actual: 5170.676092000002
# Coeficientes actuales: [ 4.8   -9.087 -8.011], Error actual: 5143.37925
# Coeficientes actuales: [ 4.796 -9.09  -8.02 ], Error actual: 5129.444028000001
# Coeficientes actuales: [ 4.79  -9.087 -8.022], Error actual: 5112.827319000002
# Coeficientes actuales: [ 4.785 -9.092 -8.024], Error actual: 5095.137867000001
# Coeficientes actuales: [ 4.776 -9.085 -8.019], Error actual: 5071.875205999999
# Coeficientes actuales: [ 4.771 -9.093 -8.011], Error actual: 5053.053381
# Coeficientes actuales: [ 4.762 -9.088 -8.018], Error actual: 5028.586216
# Coeficientes actuales: [ 4.76  -9.085 -8.026], Error actual: 5023.946095
# Coeficientes actuales: [ 4.752 -9.094 -8.021], Error actual: 4995.810317000002
# Coeficientes actuales: [ 4.745 -9.085 -8.012], Error actual: 4979.900040000002
# Coeficientes actuales: [ 4.736 -9.077 -8.017], Error actual: 4957.2753619999985
# Coeficientes actuales: [ 4.732 -9.075 -8.02 ], Error actual: 4946.449407000004
# Coeficientes actuales: [ 4.729 -9.074 -8.021], Error actual: 4938.125086000002
# Coeficientes actuales: [ 4.723 -9.075 -8.021], Error actual: 4920.070573000002
# Coeficientes actuales: [ 4.716 -9.078 -8.024], Error actual: 4898.100220000002
# Coeficientes actuales: [ 4.706 -9.08  -8.032], Error actual: 4867.903532000002
# Coeficientes actuales: [ 4.696 -9.083 -8.041], Error actual: 4837.369606000003
# Coeficientes actuales: [ 4.69  -9.085 -8.046], Error actual: 4819.047655000001
# Coeficientes actuales: [ 4.686 -9.09  -8.047], Error actual: 4805.147757000002
# Coeficientes actuales: [ 4.683 -9.092 -8.056], Error actual: 4795.420131000001
# Coeficientes actuales: [ 4.681 -9.085 -8.05 ], Error actual: 4793.204108000003
# Coeficientes actuales: [ 4.673 -9.076 -8.047], Error actual: 4774.781686000002
# Coeficientes actuales: [ 4.665 -9.067 -8.053], Error actual: 4756.230093000002
# Coeficientes actuales: [ 4.658 -9.07  -8.055], Error actual: 4734.935757000002
# Coeficientes actuales: [ 4.648 -9.074 -8.053], Error actual: 4704.891109000004
# Coeficientes actuales: [ 4.646 -9.068 -8.058], Error actual: 4702.008072000006
# Coeficientes actuales: [ 4.645 -9.075 -8.052], Error actual: 4696.011900000002
# Coeficientes actuales: [ 4.645 -9.081 -8.055], Error actual: 4693.1351490000025
# Coeficientes actuales: [ 4.644 -9.075 -8.061], Error actual: 4693.044006000002
# Coeficientes actuales: [ 4.636 -9.084 -8.064], Error actual: 4666.399104000002
# Coeficientes actuales: [ 4.635 -9.087 -8.067], Error actual: 4662.160149
# Coeficientes actuales: [ 4.627 -9.088 -8.067], Error actual: 4639.447066000001
# Coeficientes actuales: [ 4.624 -9.086 -8.059], Error actual: 4632.182869000001
# Coeficientes actuales: [ 4.616 -9.083 -8.057], Error actual: 4611.465734000003
# Coeficientes actuales: [ 4.615 -9.077 -8.059], Error actual: 4611.4367170000005
# Coeficientes actuales: [ 4.611 -9.08  -8.061], Error actual: 4598.992150000003
# Coeficientes actuales: [ 4.601 -9.076 -8.066], Error actual: 4573.266099000003
# Coeficientes actuales: [ 4.591 -9.067 -8.067], Error actual: 4549.989637000004
# Coeficientes actuales: [ 4.589 -9.059 -8.059], Error actual: 4548.271229000004
# Coeficientes actuales: [ 4.584 -9.067 -8.052], Error actual: 4531.118807000004
# Coeficientes actuales: [ 4.577 -9.071 -8.05 ], Error actual: 4510.337192000005
# Coeficientes actuales: [ 4.567 -9.069 -8.042], Error actual: 4484.303704000007
# Coeficientes actuales: [ 4.565 -9.066 -8.05 ], Error actual: 4480.1537790000075
# Coeficientes actuales: [ 4.561 -9.074 -8.047], Error actual: 4465.872274000009
# Coeficientes actuales: [ 4.552 -9.075 -8.055], Error actual: 4441.231362000006
# Coeficientes actuales: [ 4.549 -9.069 -8.061], Error actual: 4435.797981000008
# Coeficientes actuales: [ 4.548 -9.077 -8.059], Error actual: 4429.635366000007
# Coeficientes actuales: [ 4.538 -9.084 -8.055], Error actual: 4400.046117000006
# Coeficientes actuales: [ 4.536 -9.094 -8.055], Error actual: 4390.407389000009
# Coeficientes actuales: [ 4.529 -9.093 -8.064], Error actual: 4372.2995760000085
# Coeficientes actuales: [ 4.521 -9.086 -8.063], Error actual: 4354.303602000009
# Coeficientes actuales: [ 4.514 -9.094 -8.06 ], Error actual: 4332.585120000011
# Coeficientes actuales: [ 4.513 -9.102 -8.065], Error actual: 4326.53004600001
# Coeficientes actuales: [ 4.504 -9.103 -8.072], Error actual: 4302.66826300001
# Coeficientes actuales: [ 4.5   -9.107 -8.069], Error actual: 4290.644742000012
# Coeficientes actuales: [ 4.496 -9.105 -8.063], Error actual: 4281.189814000011
# Coeficientes actuales: [ 4.491 -9.106 -8.054], Error actual: 4267.935371000011
# Coeficientes actuales: [ 4.483 -9.107 -8.048], Error actual: 4247.005336000011
# Coeficientes actuales: [ 4.483 -9.114 -8.04 ], Error actual: 4244.132187000012
# Coeficientes actuales: [ 4.474 -9.113 -8.038], Error actual: 4221.56652700001
# Coeficientes actuales: [ 4.468 -9.117 -8.031], Error actual: 4204.68576600001
# Coeficientes actuales: [ 4.462 -9.123 -8.036], Error actual: 4187.0126710000095
# Coeficientes actuales: [ 4.463 -9.132 -8.033], Error actual: 4185.8744860000115
# Coeficientes actuales: [ 4.453 -9.138 -8.039], Error actual: 4158.243298000011
# Coeficientes actuales: [ 4.448 -9.137 -8.047], Error actual: 4146.104246000011
# Coeficientes actuales: [ 4.443 -9.13  -8.041], Error actual: 4136.42809800001
# Coeficientes actuales: [ 4.433 -9.127 -8.044], Error actual: 4112.719036000011
# Coeficientes actuales: [ 4.433 -9.129 -8.054], Error actual: 4111.917628000011
# Coeficientes actuales: [ 4.43 -9.12 -8.06], Error actual: 4108.053100000011
# Coeficientes actuales: [ 4.42  -9.12  -8.061], Error actual: 4083.321285000011
# Coeficientes actuales: [ 4.411 -9.116 -8.056], Error actual: 4062.7483390000093
# Coeficientes actuales: [ 4.401 -9.125 -8.059], Error actual: 4034.784501000011
# Coeficientes actuales: [ 4.399 -9.118 -8.055], Error actual: 4032.6191500000123
# Coeficientes actuales: [ 4.393 -9.12  -8.049], Error actual: 4017.2380260000114
# Coeficientes actuales: [ 4.384 -9.124 -8.041], Error actual: 3993.88822100001
# Coeficientes actuales: [ 4.375 -9.116 -8.044], Error actual: 3975.27462700001
# Coeficientes actuales: [ 4.373 -9.122 -8.046], Error actual: 3968.1995310000093
# Coeficientes actuales: [ 4.367 -9.117 -8.05 ], Error actual: 3955.7415600000095
# Coeficientes actuales: [ 4.362 -9.125 -8.048], Error actual: 3940.7858790000087
# Coeficientes actuales: [ 4.361 -9.125 -8.04 ], Error actual: 3938.3648880000082
# Coeficientes actuales: [ 4.361 -9.127 -8.037], Error actual: 3937.598757000008
# Coeficientes actuales: [ 4.359 -9.132 -8.045], Error actual: 3931.0102780000093
# Coeficientes actuales: [ 4.353 -9.133 -8.046], Error actual: 3916.4192120000075
# Coeficientes actuales: [ 4.348 -9.14  -8.049], Error actual: 3902.0336210000078
# Coeficientes actuales: [ 4.342 -9.144 -8.049], Error actual: 3886.4499330000076
# Coeficientes actuales: [ 4.338 -9.144 -8.04 ], Error actual: 3877.0108920000093
# Coeficientes actuales: [ 4.329 -9.139 -8.05 ], Error actual: 3857.896680000009
# Coeficientes actuales: [ 4.324 -9.146 -8.042], Error actual: 3843.667384000009
# Coeficientes actuales: [ 4.314 -9.139 -8.051], Error actual: 3823.1322860000087
# Coeficientes actuales: [ 4.304 -9.13  -8.047], Error actual: 3803.29942900001
# Coeficientes actuales: [ 4.299 -9.124 -8.049], Error actual: 3793.98901400001
# Coeficientes actuales: [ 4.297 -9.127 -8.052], Error actual: 3788.37679600001
# Coeficientes actuales: [ 4.292 -9.129 -8.061], Error actual: 3776.3521620000106
# Coeficientes actuales: [ 4.29  -9.126 -8.068], Error actual: 3772.931040000011
# Coeficientes actuales: [ 4.288 -9.131 -8.059], Error actual: 3766.527442000012
# Coeficientes actuales: [ 4.282 -9.123 -8.054], Error actual: 3755.6639110000115
# Coeficientes actuales: [ 4.279 -9.132 -8.054], Error actual: 3745.73421100001
# Coeficientes actuales: [ 4.27  -9.134 -8.05 ], Error actual: 3724.72392400001
# Coeficientes actuales: [ 4.26  -9.143 -8.053], Error actual: 3699.30629400001
# Coeficientes actuales: [ 4.259 -9.148 -8.046], Error actual: 3695.279979000008
# Coeficientes actuales: [ 4.258 -9.145 -8.04 ], Error actual: 3693.9963670000084
# Coeficientes actuales: [ 4.251 -9.147 -8.036], Error actual: 3677.7217360000077
# Coeficientes actuales: [ 4.249 -9.146 -8.046], Error actual: 3673.774979000008
# Coeficientes actuales: [ 4.239 -9.139 -8.039], Error actual: 3653.972669000008
# Coeficientes actuales: [ 4.231 -9.132 -8.033], Error actual: 3638.659798000009
# Coeficientes actuales: [ 4.23  -9.13  -8.039], Error actual: 3637.227485000007
# Coeficientes actuales: [ 4.22  -9.136 -8.038], Error actual: 3613.409140000009
# Coeficientes actuales: [ 4.219 -9.137 -8.043], Error actual: 3610.989149000008
# Coeficientes actuales: [ 4.217 -9.146 -8.037], Error actual: 3603.598494000008
# Coeficientes actuales: [ 4.207 -9.146 -8.028], Error actual: 3581.8554350000077
# Coeficientes actuales: [ 4.201 -9.151 -8.019], Error actual: 3567.195181000008
# Coeficientes actuales: [ 4.193 -9.152 -8.013], Error actual: 3549.6705060000068
# Coeficientes actuales: [ 4.192 -9.154 -8.023], Error actual: 3547.086821000007
# Coeficientes actuales: [ 4.185 -9.152 -8.016], Error actual: 3532.724995000008
# Coeficientes actuales: [ 4.185 -9.161 -8.015], Error actual: 3529.8526290000077
# Coeficientes actuales: [ 4.178 -9.152 -8.015], Error actual: 3517.905581000008
# Coeficientes actuales: [ 4.175 -9.149 -8.021], Error actual: 3512.645957000008
# Coeficientes actuales: [ 4.17  -9.145 -8.018], Error actual: 3503.327735000008
# Coeficientes actuales: [ 4.168 -9.152 -8.014], Error actual: 3496.864756000007
# Coeficientes actuales: [ 4.164 -9.155 -8.022], Error actual: 3487.73155900001
# Coeficientes actuales: [ 4.163 -9.154 -8.015], Error actual: 3485.8087020000094
# Coeficientes actuales: [ 4.16  -9.146 -8.019], Error actual: 3482.1139170000074
# Coeficientes actuales: [ 4.156 -9.143 -8.021], Error actual: 3474.754006000009
# Coeficientes actuales: [ 4.154 -9.152 -8.019], Error actual: 3467.7854610000095
# Coeficientes actuales: [ 4.144 -9.152 -8.017], Error actual: 3447.0705970000095
# Coeficientes actuales: [ 4.134 -9.159 -8.021], Error actual: 3424.53178600001
# Coeficientes actuales: [ 4.129 -9.159 -8.014], Error actual: 3414.169944000011
# Coeficientes actuales: [ 4.125 -9.151 -8.018], Error actual: 3408.514280000011
# Coeficientes actuales: [ 4.12  -9.159 -8.019], Error actual: 3396.0238260000124
# Coeficientes actuales: [ 4.114 -9.157 -8.028], Error actual: 3384.723919000012
# Coeficientes actuales: [ 4.112 -9.166 -8.025], Error actual: 3377.987397000012
# Coeficientes actuales: [ 4.109 -9.157 -8.031], Error actual: 3374.7472050000124
# Coeficientes actuales: [ 4.105 -9.158 -8.041], Error actual: 3366.697822000012
# Coeficientes actuales: [ 4.099 -9.158 -8.033], Error actual: 3354.5163220000113
# Coeficientes actuales: [ 4.091 -9.161 -8.039], Error actual: 3337.931381000011
# Coeficientes actuales: [ 4.082 -9.167 -8.034], Error actual: 3318.34688700001
# Coeficientes actuales: [ 4.073 -9.16  -8.026], Error actual: 3302.4631630000104
# Coeficientes actuales: [ 4.066 -9.167 -8.025], Error actual: 3286.8462500000114
# Coeficientes actuales: [ 4.063 -9.164 -8.033], Error actual: 3282.0899740000104
# Coeficientes actuales: [ 4.055 -9.169 -8.039], Error actual: 3265.4432610000104
# Coeficientes actuales: [ 4.045 -9.177 -8.031], Error actual: 3243.8678850000106
# Coeficientes actuales: [ 4.044 -9.171 -8.033], Error actual: 3243.64173400001
# Coeficientes actuales: [ 4.042 -9.176 -8.042], Error actual: 3238.76106400001
# Coeficientes actuales: [ 4.041 -9.178 -8.037], Error actual: 3236.1664940000096
# Coeficientes actuales: [ 4.032 -9.182 -8.033], Error actual: 3217.9260690000087
# Coeficientes actuales: [ 4.024 -9.176 -8.039], Error actual: 3204.6479890000082
# Coeficientes actuales: [ 4.014 -9.177 -8.042], Error actual: 3185.79012700001
# Coeficientes actuales: [ 4.013 -9.173 -8.046], Error actual: 3185.100252000008
# Coeficientes actuales: [ 4.011 -9.164 -8.046], Error actual: 3183.7146190000094
# Coeficientes actuales: [ 4.008 -9.168 -8.052], Error actual: 3177.3035040000095
# Coeficientes actuales: [ 4.005 -9.167 -8.044], Error actual: 3171.731052000009
# Coeficientes actuales: [ 4.001 -9.173 -8.039], Error actual: 3162.627245000009
# Coeficientes actuales: [ 4.001 -9.175 -8.038], Error actual: 3162.0813040000094
# Coeficientes actuales: [ 4.002 -9.185 -8.035], Error actual: 3161.2656420000094
# Coeficientes actuales: [ 3.992 -9.177 -8.04 ], Error actual: 3145.10677500001
# Coeficientes actuales: [ 3.982 -9.171 -8.031], Error actual: 3128.0547180000103
# Coeficientes actuales: [ 3.979 -9.175 -8.028], Error actual: 3121.50215200001
# Coeficientes actuales: [ 3.972 -9.179 -8.032], Error actual: 3108.005319000011
# Coeficientes actuales: [ 3.97  -9.178 -8.041], Error actual: 3104.980757000011
# Coeficientes actuales: [ 3.967 -9.171 -8.05 ], Error actual: 3101.6380920000106
# Coeficientes actuales: [ 3.958 -9.163 -8.058], Error actual: 3087.7767910000102
# Coeficientes actuales: [ 3.951 -9.168 -8.067], Error actual: 3074.4655140000104
# Coeficientes actuales: [ 3.951 -9.168 -8.058], Error actual: 3074.12222700001
# Coeficientes actuales: [ 3.952 -9.174 -8.049], Error actual: 3074.1129330000094
# Coeficientes actuales: [ 3.945 -9.182 -8.048], Error actual: 3059.801763000009
# Coeficientes actuales: [ 3.944 -9.178 -8.041], Error actual: 3058.7187490000097
# Coeficientes actuales: [ 3.935 -9.172 -8.033], Error actual: 3044.0260380000095
# Coeficientes actuales: [ 3.927 -9.164 -8.04 ], Error actual: 3032.21087500001
# Coeficientes actuales: [ 3.925 -9.165 -8.033], Error actual: 3028.2216850000104
# Coeficientes actuales: [ 3.916 -9.164 -8.032], Error actual: 3012.8285440000104
# Coeficientes actuales: [ 3.913 -9.166 -8.042], Error actual: 3007.61061100001
# Coeficientes actuales: [ 3.903 -9.169 -8.034], Error actual: 2989.4805680000095
# Coeficientes actuales: [ 3.897 -9.172 -8.043], Error actual: 2978.99005400001
# Coeficientes actuales: [ 3.894 -9.179 -8.042], Error actual: 2972.32232700001
# Coeficientes actuales: [ 3.885 -9.173 -8.038], Error actual: 2958.3278040000105
# Coeficientes actuales: [ 3.878 -9.17  -8.043], Error actual: 2947.4917650000098
# Coeficientes actuales: [ 3.872 -9.171 -8.039], Error actual: 2937.1216660000105
# Coeficientes actuales: [ 3.863 -9.167 -8.044], Error actual: 2923.3222160000114
# Coeficientes actuales: [ 3.853 -9.168 -8.049], Error actual: 2906.9470980000115
# Coeficientes actuales: [ 3.843 -9.173 -8.052], Error actual: 2889.818524000011
# Coeficientes actuales: [ 3.835 -9.168 -8.044], Error actual: 2877.578835000011
# Coeficientes actuales: [ 3.833 -9.162 -8.047], Error actual: 2875.725426000012
# Coeficientes actuales: [ 3.825 -9.171 -8.044], Error actual: 2860.9939320000112
# Coeficientes actuales: [ 3.822 -9.167 -8.043], Error actual: 2856.975214000011
# Coeficientes actuales: [ 3.815 -9.161 -8.041], Error actual: 2846.9816210000113
# Coeficientes actuales: [ 3.813 -9.153 -8.037], Error actual: 2845.2053490000108
# Coeficientes actuales: [ 3.806 -9.153 -8.034], Error actual: 2834.03809500001
# Coeficientes actuales: [ 3.802 -9.156 -8.03 ], Error actual: 2826.9943120000107
# Coeficientes actuales: [ 3.793 -9.166 -8.031], Error actual: 2811.1336180000108
# Coeficientes actuales: [ 3.787 -9.161 -8.037], Error actual: 2803.1216690000115
# Coeficientes actuales: [ 3.782 -9.167 -8.037], Error actual: 2794.326186000011
# Coeficientes actuales: [ 3.773 -9.175 -8.03 ], Error actual: 2778.7884720000125
# Coeficientes actuales: [ 3.766 -9.185 -8.036], Error actual: 2766.7348150000116
# Coeficientes actuales: [ 3.762 -9.188 -8.03 ], Error actual: 2759.8890960000117
# Coeficientes actuales: [ 3.754 -9.189 -8.036], Error actual: 2748.1221910000118
# Coeficientes actuales: [ 3.747 -9.187 -8.032], Error actual: 2737.9086960000122
# Coeficientes actuales: [ 3.737 -9.178 -8.042], Error actual: 2725.327851000012
# Coeficientes actuales: [ 3.728 -9.181 -8.05 ], Error actual: 2712.179215000012
# Coeficientes actuales: [ 3.725 -9.187 -8.056], Error actual: 2707.186780000012
# Coeficientes actuales: [ 3.716 -9.185 -8.064], Error actual: 2695.0676310000113
# Coeficientes actuales: [ 3.716 -9.188 -8.058], Error actual: 2694.238452000011
# Coeficientes actuales: [ 3.712 -9.193 -8.058], Error actual: 2687.7392710000113
# Coeficientes actuales: [ 3.713 -9.203 -8.058], Error actual: 2687.5502160000106
# Coeficientes actuales: [ 3.706 -9.197 -8.056], Error actual: 2678.500951000011
# Coeficientes actuales: [ 3.698 -9.206 -8.055], Error actual: 2665.813725000011
# Coeficientes actuales: [ 3.692 -9.209 -8.055], Error actual: 2657.0113500000107
# Coeficientes actuales: [ 3.687 -9.21  -8.06 ], Error actual: 2650.2505870000114
# Coeficientes actuales: [ 3.677 -9.21  -8.052], Error actual: 2636.0688750000118
# Coeficientes actuales: [ 3.674 -9.212 -8.061], Error actual: 2632.236645000011
# Coeficientes actuales: [ 3.664 -9.211 -8.064], Error actual: 2619.0615190000117
# Coeficientes actuales: [ 3.66  -9.216 -8.071], Error actual: 2613.4215810000114
# Coeficientes actuales: [ 3.651 -9.224 -8.062], Error actual: 2599.7861790000106
# Coeficientes actuales: [ 3.65  -9.234 -8.055], Error actual: 2596.6445490000115
# Coeficientes actuales: [ 3.647 -9.244 -8.059], Error actual: 2591.591338000011
# Coeficientes actuales: [ 3.645 -9.246 -8.055], Error actual: 2588.452194000011
# Coeficientes actuales: [ 3.643 -9.238 -8.059], Error actual: 2587.179038000011
# Coeficientes actuales: [ 3.633 -9.241 -8.069], Error actual: 2574.4560770000126
# Coeficientes actuales: [ 3.629 -9.234 -8.067], Error actual: 2570.098242000012
# Coeficientes actuales: [ 3.623 -9.234 -8.074], Error actual: 2562.8713230000117
# Coeficientes actuales: [ 3.618 -9.237 -8.082], Error actual: 2556.6560310000114
# Coeficientes actuales: [ 3.617 -9.242 -8.083], Error actual: 2554.8249140000116
# Coeficientes actuales: [ 3.607 -9.247 -8.09 ], Error actual: 2542.1152600000114
# Coeficientes actuales: [ 3.598 -9.248 -8.091], Error actual: 2530.8977570000116
# Coeficientes actuales: [ 3.591 -9.24  -8.095], Error actual: 2523.5074980000118
# Coeficientes actuales: [ 3.585 -9.231 -8.097], Error actual: 2517.3581730000114
# Coeficientes actuales: [ 3.584 -9.223 -8.095], Error actual: 2516.9319700000115
# Coeficientes actuales: [ 3.58  -9.218 -8.092], Error actual: 2512.4304280000124
# Coeficientes actuales: [ 3.576 -9.218 -8.096], Error actual: 2507.847996000012
# Coeficientes actuales: [ 3.567 -9.218 -8.106], Error actual: 2497.7014510000117
# Coeficientes actuales: [ 3.561 -9.216 -8.106], Error actual: 2490.7617390000128
# Coeficientes actuales: [ 3.552 -9.216 -8.101], Error actual: 2479.762173000012
# Coeficientes actuales: [ 3.546 -9.211 -8.099], Error actual: 2473.110206000012
# Coeficientes actuales: [ 3.544 -9.218 -8.108], Error actual: 2470.686172000012
# Coeficientes actuales: [ 3.537 -9.223 -8.104], Error actual: 2461.7785560000125
# Coeficientes actuales: [ 3.527 -9.231 -8.095], Error actual: 2448.886677000012
# Coeficientes actuales: [ 3.523 -9.229 -8.086], Error actual: 2443.8876560000126
# Coeficientes actuales: [ 3.517 -9.236 -8.094], Error actual: 2437.051811000013
# Coeficientes actuales: [ 3.507 -9.231 -8.093], Error actual: 2426.301925000012
# Coeficientes actuales: [ 3.505 -9.236 -8.092], Error actual: 2423.5633630000125
# Coeficientes actuales: [ 3.499 -9.243 -8.098], Error actual: 2416.8074520000127
# Coeficientes actuales: [ 3.497 -9.252 -8.106], Error actual: 2414.454243000013
# Coeficientes actuales: [ 3.495 -9.258 -8.102], Error actual: 2411.471203000013
# Coeficientes actuales: [ 3.489 -9.262 -8.097], Error actual: 2404.2979820000132
# Coeficientes actuales: [ 3.489 -9.269 -8.101], Error actual: 2404.0267410000133
# Coeficientes actuales: [ 3.487 -9.269 -8.092], Error actual: 2401.200364000013
# Coeficientes actuales: [ 3.478 -9.262 -8.086], Error actual: 2391.751316000013
# Coeficientes actuales: [ 3.474 -9.266 -8.086], Error actual: 2387.2258440000137
# Coeficientes actuales: [ 3.47  -9.262 -8.08 ], Error actual: 2382.8810560000124
# Coeficientes actuales: [ 3.462 -9.262 -8.081], Error actual: 2374.645733000014
# Coeficientes actuales: [ 3.453 -9.267 -8.076], Error actual: 2364.6500760000126
# Coeficientes actuales: [ 3.45  -9.267 -8.072], Error actual: 2361.281119000012
# Coeficientes actuales: [ 3.443 -9.265 -8.068], Error actual: 2354.0275000000124
# Coeficientes actuales: [ 3.438 -9.263 -8.069], Error actual: 2349.230058000013
# Coeficientes actuales: [ 3.438 -9.262 -8.068], Error actual: 2349.2168160000124
# Coeficientes actuales: [ 3.436 -9.258 -8.077], Error actual: 2348.2103490000122
# Coeficientes actuales: [ 3.428 -9.266 -8.069], Error actual: 2339.1185570000134
# Coeficientes actuales: [ 3.42  -9.272 -8.073], Error actual: 2331.2572930000133
# Coeficientes actuales: [ 3.414 -9.271 -8.079], Error actual: 2326.0161740000135
# Coeficientes actuales: [ 3.412 -9.262 -8.089], Error actual: 2325.444557000013
# Coeficientes actuales: [ 3.412 -9.272 -8.089], Error actual: 2324.865757000013
# Coeficientes actuales: [ 3.409 -9.277 -8.085], Error actual: 2321.386693000013
# Coeficientes actuales: [ 3.399 -9.268 -8.094], Error actual: 2313.176291000013
# Coeficientes actuales: [ 3.39  -9.259 -8.091], Error actual: 2304.986942000013
# Coeficientes actuales: [ 3.381 -9.253 -8.084], Error actual: 2296.3797200000126
# Coeficientes actuales: [ 3.374 -9.251 -8.089], Error actual: 2290.5027140000125
# Coeficientes actuales: [ 3.364 -9.26  -8.099], Error actual: 2281.9574050000133
# Coeficientes actuales: [ 3.363 -9.253 -8.091], Error actual: 2280.6765170000126
# Coeficientes actuales: [ 3.357 -9.253 -8.098], Error actual: 2275.955196000013
# Coeficientes actuales: [ 3.356 -9.254 -8.094], Error actual: 2274.684984000013
# Coeficientes actuales: [ 3.352 -9.252 -8.085], Error actual: 2270.466165000013
# Coeficientes actuales: [ 3.344 -9.251 -8.083], Error actual: 2263.3569140000122
# Coeficientes actuales: [ 3.344 -9.247 -8.074], Error actual: 2262.7205110000123
# Coeficientes actuales: [ 3.337 -9.244 -8.078], Error actual: 2257.137691000012
# Coeficientes actuales: [ 3.327 -9.237 -8.086], Error actual: 2249.561448000012
# Coeficientes actuales: [ 3.324 -9.237 -8.088], Error actual: 2247.208119000012
# Coeficientes actuales: [ 3.317 -9.235 -8.079], Error actual: 2240.610213000012
# Coeficientes actuales: [ 3.311 -9.233 -8.079], Error actual: 2235.6972450000126
# Coeficientes actuales: [ 3.31  -9.232 -8.083], Error actual: 2235.260333000012
# Coeficientes actuales: [ 3.302 -9.238 -8.089], Error actual: 2229.1146610000123
# Coeficientes actuales: [ 3.293 -9.23  -8.099], Error actual: 2222.9797460000113
# Coeficientes actuales: [ 3.287 -9.239 -8.107], Error actual: 2218.774109000012
# Coeficientes actuales: [ 3.286 -9.244 -8.112], Error actual: 2218.355404000012
# Coeficientes actuales: [ 3.277 -9.246 -8.107], Error actual: 2210.8779540000114
# Coeficientes actuales: [ 3.272 -9.239 -8.117], Error actual: 2208.082934000012
# Coeficientes actuales: [ 3.267 -9.242 -8.125], Error actual: 2204.996610000012
# Coeficientes actuales: [ 3.258 -9.248 -8.127], Error actual: 2198.399389000012
# Coeficientes actuales: [ 3.254 -9.247 -8.12 ], Error actual: 2194.7974230000113
# Coeficientes actuales: [ 3.244 -9.256 -8.126], Error actual: 2188.062004000012
# Coeficientes actuales: [ 3.234 -9.259 -8.127], Error actual: 2181.0639020000112
# Coeficientes actuales: [ 3.226 -9.262 -8.123], Error actual: 2175.1191730000114
# Coeficientes actuales: [ 3.22  -9.259 -8.119], Error actual: 2170.608626000012
# Coeficientes actuales: [ 3.214 -9.256 -8.121], Error actual: 2166.7249090000114
# Coeficientes actuales: [ 3.213 -9.251 -8.116], Error actual: 2165.532348000011
# Coeficientes actuales: [ 3.21  -9.258 -8.11 ], Error actual: 2162.9733960000112
# Coeficientes actuales: [ 3.205 -9.259 -8.119], Error actual: 2160.549701000011
# Coeficientes actuales: [ 3.196 -9.254 -8.115], Error actual: 2154.2150690000108
# Coeficientes actuales: [ 3.187 -9.25  -8.108], Error actual: 2147.6796190000114
# Coeficientes actuales: [ 3.182 -9.26  -8.11 ], Error actual: 2144.868152000011
# Coeficientes actuales: [ 3.173 -9.255 -8.103], Error actual: 2138.482605000011
# Coeficientes actuales: [ 3.166 -9.256 -8.104], Error actual: 2134.328396000011
# Coeficientes actuales: [ 3.158 -9.248 -8.095], Error actual: 2128.4270450000104
# Coeficientes actuales: [ 3.151 -9.24  -8.1  ], Error actual: 2124.59844300001
# Coeficientes actuales: [ 3.143 -9.234 -8.091], Error actual: 2118.8442060000107
# Coeficientes actuales: [ 3.133 -9.226 -8.096], Error actual: 2113.3979230000105
# Coeficientes actuales: [ 3.123 -9.223 -8.101], Error actual: 2108.21507700001
# Coeficientes actuales: [ 3.12  -9.215 -8.095], Error actual: 2105.67165000001
# Coeficientes actuales: [ 3.111 -9.219 -8.099], Error actual: 2101.31590900001
# Coeficientes actuales: [ 3.104 -9.224 -8.104], Error actual: 2098.3024640000094
# Coeficientes actuales: [ 3.103 -9.216 -8.109], Error actual: 2097.999702000009
# Coeficientes actuales: [ 3.097 -9.214 -8.11 ], Error actual: 2094.8907950000103
# Coeficientes actuales: [ 3.088 -9.213 -8.108], Error actual: 2090.0238310000095
# Coeficientes actuales: [ 3.085 -9.218 -8.11 ], Error actual: 2088.9452110000097
# Coeficientes actuales: [ 3.082 -9.224 -8.113], Error actual: 2088.04578100001
# Coeficientes actuales: [ 3.078 -9.223 -8.114], Error actual: 2086.143983000009
# Coeficientes actuales: [ 3.074 -9.216 -8.122], Error actual: 2084.733864000009
# Coeficientes actuales: [ 3.067 -9.225 -8.126], Error actual: 2082.270376000009
# Coeficientes actuales: [ 3.067 -9.222 -8.126], Error actual: 2082.1184830000093
# Coeficientes actuales: [ 3.06  -9.232 -8.128], Error actual: 2079.6038880000087
# Coeficientes actuales: [ 3.056 -9.224 -8.125], Error actual: 2077.0171490000093
# Coeficientes actuales: [ 3.054 -9.215 -8.127], Error actual: 2075.8390540000096
# Coeficientes actuales: [ 3.049 -9.223 -8.119], Error actual: 2073.1486610000084
# Coeficientes actuales: [ 3.043 -9.232 -8.121], Error actual: 2071.248646000009
# Coeficientes actuales: [ 3.038 -9.228 -8.118], Error actual: 2068.521336000009
# Coeficientes actuales: [ 3.031 -9.238 -8.11 ], Error actual: 2065.2906830000093
# Coeficientes actuales: [ 3.023 -9.244 -8.114], Error actual: 2062.8577230000087
# Coeficientes actuales: [ 3.02  -9.236 -8.11 ], Error actual: 2060.673524000009
# Coeficientes actuales: [ 3.017 -9.236 -8.116], Error actual: 2060.1569630000085
# Coeficientes actuales: [ 3.011 -9.244 -8.122], Error actual: 2059.0497790000086
# Coeficientes actuales: [ 3.002 -9.251 -8.124], Error actual: 2056.396551000008
# Coeficientes actuales: [ 2.997 -9.258 -8.115], Error actual: 2054.065506000008
# Coeficientes actuales: [ 2.999 -9.256 -8.106], Error actual: 2053.604499000008
# Coeficientes actuales: [ 2.989 -9.252 -8.111], Error actual: 2050.304950000008
# Coeficientes actuales: [ 2.982 -9.261 -8.109], Error actual: 2048.378046000007
# Coeficientes actuales: [ 2.976 -9.257 -8.103], Error actual: 2045.3506780000077
# Coeficientes actuales: [ 2.967 -9.266 -8.106], Error actual: 2043.5546830000076
# Coeficientes actuales: [ 2.96  -9.271 -8.108], Error actual: 2042.0666550000078
# Coeficientes actuales: [ 2.961 -9.264 -8.101], Error actual: 2040.9299940000078
# Coeficientes actuales: [ 2.957 -9.265 -8.094], Error actual: 2038.9762680000078
# Coeficientes actuales: [ 2.953 -9.273 -8.095], Error actual: 2038.6232850000072
# Coeficientes actuales: [ 2.949 -9.276 -8.095], Error actual: 2037.739734000007
# Coeficientes actuales: [ 2.939 -9.269 -8.094], Error actual: 2034.1677840000073
# Coeficientes actuales: [ 2.941 -9.265 -8.09 ], Error actual: 2033.8653880000074
# Coeficientes actuales: [ 2.943 -9.265 -8.083], Error actual: 2033.5909650000074
# Coeficientes actuales: [ 2.941 -9.259 -8.091], Error actual: 2033.4241090000073
# Coeficientes actuales: [ 2.936 -9.256 -8.084], Error actual: 2030.920656000007
# Coeficientes actuales: [ 2.931 -9.253 -8.081], Error actual: 2028.919301000007
# Coeficientes actuales: [ 2.932 -9.249 -8.079], Error actual: 2028.5682780000072
# Coeficientes actuales: [ 2.928 -9.257 -8.077], Error actual: 2028.027666000007
# Coeficientes actuales: [ 2.923 -9.26  -8.078], Error actual: 2027.146555000007
# Coeficientes actuales: [ 2.924 -9.251 -8.08 ], Error actual: 2026.7595590000067
# Coeficientes actuales: [ 2.918 -9.245 -8.084], Error actual: 2025.1167110000067
# Coeficientes actuales: [ 2.911 -9.236 -8.085], Error actual: 2022.597830000006
# Coeficientes actuales: [ 2.908 -9.24  -8.079], Error actual: 2021.550861000006
# Coeficientes actuales: [ 2.899 -9.238 -8.082], Error actual: 2019.6096430000055
# Coeficientes actuales: [ 2.89  -9.24  -8.085], Error actual: 2018.2097250000054
# Coeficientes actuales: [ 2.885 -9.246 -8.077], Error actual: 2016.836238000006
# Coeficientes actuales: [ 2.878 -9.24  -8.079], Error actual: 2015.0157810000057
# Coeficientes actuales: [ 2.881 -9.239 -8.072], Error actual: 2014.6369240000063
# Coeficientes actuales: [ 2.877 -9.241 -8.075], Error actual: 2014.4377970000057
# Coeficientes actuales: [ 2.875 -9.234 -8.083], Error actual: 2014.2538380000055
# Coeficientes actuales: [ 2.872 -9.239 -8.074], Error actual: 2013.1312630000057
# Coeficientes actuales: [ 2.865 -9.239 -8.066], Error actual: 2010.8535120000056
# Coeficientes actuales: [ 2.871 -9.232 -8.059], Error actual: 2010.2915940000064
# Coeficientes actuales: [ 2.863 -9.232 -8.061], Error actual: 2009.065366000006
# Coeficientes actuales: [ 2.853 -9.228 -8.062], Error actual: 2007.0039390000056
# Coeficientes actuales: [ 2.85  -9.232 -8.058], Error actual: 2006.491688000006
# Coeficientes actuales: [ 2.844 -9.233 -8.051], Error actual: 2004.799254000006
# Coeficientes actuales: [ 2.838 -9.24  -8.045], Error actual: 2004.024517000005
# Coeficientes actuales: [ 2.828 -9.237 -8.043], Error actual: 2002.0521660000052
# Coeficientes actuales: [ 2.83 -9.23 -8.04], Error actual: 2001.0488000000055
# Coeficientes actuales: [ 2.824 -9.223 -8.047], Error actual: 2000.275778000005
# Coeficientes actuales: [ 2.815 -9.224 -8.041], Error actual: 1998.5633020000046
# Coeficientes actuales: [ 2.807 -9.226 -8.035], Error actual: 1997.1990220000046
# Coeficientes actuales: [ 2.801 -9.218 -8.037], Error actual: 1995.8005740000049
# Coeficientes actuales: [ 2.802 -9.212 -8.041], Error actual: 1995.6104130000049
# Coeficientes actuales: [ 2.792 -9.203 -8.044], Error actual: 1993.8631910000045
# Coeficientes actuales: [ 2.796 -9.198 -8.042], Error actual: 1993.2916240000043
# Coeficientes actuales: [ 2.804 -9.192 -8.033], Error actual: 1992.1513090000049
# Coeficientes actuales: [ 2.799 -9.183 -8.036], Error actual: 1990.823944000004
# Coeficientes actuales: [ 2.792 -9.174 -8.041], Error actual: 1989.5729970000043
# Coeficientes actuales: [ 2.791 -9.175 -8.033], Error actual: 1988.5833490000045
# Coeficientes actuales: [ 2.79  -9.166 -8.034], Error actual: 1987.4147720000046
# Coeficientes actuales: [ 2.787 -9.169 -8.033], Error actual: 1987.4071010000048
# Coeficientes actuales: [ 2.784 -9.162 -8.035], Error actual: 1986.4517730000048
# Coeficientes actuales: [ 2.774 -9.153 -8.035], Error actual: 1984.3959300000042
# Coeficientes actuales: [ 2.779 -9.154 -8.027], Error actual: 1983.9044620000045
# Coeficientes actuales: [ 2.782 -9.151 -8.019], Error actual: 1982.7326860000048
# Coeficientes actuales: [ 2.787 -9.152 -8.014], Error actual: 1982.6963070000047
# Coeficientes actuales: [ 2.777 -9.15  -8.022], Error actual: 1982.5481550000036
# Coeficientes actuales: [ 2.774 -9.141 -8.028], Error actual: 1981.8485190000038
# Coeficientes actuales: [ 2.772 -9.148 -8.019], Error actual: 1981.485821000004
# Coeficientes actuales: [ 2.764 -9.149 -8.022], Error actual: 1981.4443670000037
# Coeficientes actuales: [ 2.759 -9.146 -8.02 ], Error actual: 1980.4519790000036
# Coeficientes actuales: [ 2.763 -9.139 -8.017], Error actual: 1979.3310450000035
# Coeficientes actuales: [ 2.762 -9.141 -8.013], Error actual: 1979.0251500000038
# Coeficientes actuales: [ 2.765 -9.134 -8.013], Error actual: 1978.2571980000039
# Coeficientes actuales: [ 2.755 -9.136 -8.005], Error actual: 1976.8510940000037
# Coeficientes actuales: [ 2.751 -9.138 -7.999], Error actual: 1976.1355500000036
# Coeficientes actuales: [ 2.752 -9.134 -7.997], Error actual: 1975.3575490000035
# Coeficientes actuales: [ 2.745 -9.138 -7.994], Error actual: 1975.1975950000037
# Coeficientes actuales: [ 2.751 -9.131 -7.996], Error actual: 1974.7461840000037
# Coeficientes actuales: [ 2.748 -9.125 -7.991], Error actual: 1973.0805180000036
# Coeficientes actuales: [ 2.739 -9.127 -7.99 ], Error actual: 1972.8308280000035
# Coeficientes actuales: [ 2.742 -9.123 -7.99 ], Error actual: 1972.3743510000038
# Coeficientes actuales: [ 2.74  -9.125 -7.987], Error actual: 1972.1866300000038
# Coeficientes actuales: [ 2.749 -9.117 -7.98 ], Error actual: 1970.566728000004
# Coeficientes actuales: [ 2.739 -9.12  -7.979], Error actual: 1970.3733700000041
# Coeficientes actuales: [ 2.737 -9.113 -7.975], Error actual: 1968.7528210000044
# Coeficientes actuales: [ 2.746 -9.106 -7.973], Error actual: 1967.9305570000045
# Coeficientes actuales: [ 2.745 -9.097 -7.977], Error actual: 1967.1207890000046
# Coeficientes actuales: [ 2.748 -9.103 -7.968], Error actual: 1966.9765910000049
# Coeficientes actuales: [ 2.738 -9.103 -7.972], Error actual: 1966.9611190000041
# Coeficientes actuales: [ 2.733 -9.095 -7.976], Error actual: 1966.110348000004
# Coeficientes actuales: [ 2.731 -9.091 -7.977], Error actual: 1965.5802130000047
# Coeficientes actuales: [ 2.73  -9.084 -7.979], Error actual: 1964.7859810000043
# Coeficientes actuales: [ 2.736 -9.077 -7.973], Error actual: 1963.2729780000045
# Coeficientes actuales: [ 2.738 -9.081 -7.964], Error actual: 1962.7776070000043
# Coeficientes actuales: [ 2.735 -9.08  -7.965], Error actual: 1962.6097500000044
# Coeficientes actuales: [ 2.742 -9.079 -7.962], Error actual: 1962.4646390000048
# Coeficientes actuales: [ 2.734 -9.071 -7.957], Error actual: 1960.2363940000046
# Coeficientes actuales: [ 2.732 -9.072 -7.955], Error actual: 1960.0184050000048
# Coeficientes actuales: [ 2.737 -9.064 -7.95 ], Error actual: 1958.5052350000046
# Coeficientes actuales: [ 2.727 -9.063 -7.951], Error actual: 1957.9740210000045
# Coeficientes actuales: [ 2.717 -9.064 -7.942], Error actual: 1956.5670190000042
# Coeficientes actuales: [ 2.717 -9.056 -7.95 ], Error actual: 1956.4409070000045
# Coeficientes actuales: [ 2.713 -9.05  -7.955], Error actual: 1956.0922420000045
# Coeficientes actuales: [ 2.71  -9.045 -7.959], Error actual: 1955.7977700000042
# Coeficientes actuales: [ 2.7   -9.038 -7.968], Error actual: 1955.746684000004
# Coeficientes actuales: [ 2.704 -9.031 -7.966], Error actual: 1954.5001190000041
# Coeficientes actuales: [ 2.705 -9.024 -7.972], Error actual: 1954.2701550000043
# Coeficientes actuales: [ 2.698 -9.023 -7.971], Error actual: 1953.8561420000044
# Coeficientes actuales: [ 2.695 -9.019 -7.967], Error actual: 1952.6877250000048
# Coeficientes actuales: [ 2.7   -9.015 -7.967], Error actual: 1952.1661300000048
# Coeficientes actuales: [ 2.704 -9.009 -7.964], Error actual: 1950.9795190000045
# Coeficientes actuales: [ 2.706 -9.01  -7.958], Error actual: 1950.4002440000047
# Coeficientes actuales: [ 2.708 -9.001 -7.965], Error actual: 1950.068130000005
# Coeficientes actuales: [ 2.706 -8.993 -7.962], Error actual: 1948.4421190000046
# Coeficientes actuales: [ 2.697 -8.987 -7.955], Error actual: 1946.3716050000046
# Coeficientes actuales: [ 2.701 -8.985 -7.951], Error actual: 1945.6709250000047
# Coeficientes actuales: [ 2.694 -8.98  -7.954], Error actual: 1945.1326800000045
# Coeficientes actuales: [ 2.701 -8.979 -7.953], Error actual: 1945.0569090000047
# Coeficientes actuales: [ 2.693 -8.971 -7.959], Error actual: 1944.4328370000046
# Coeficientes actuales: [ 2.685 -8.965 -7.963], Error actual: 1943.907645000004
# Coeficientes actuales: [ 2.675 -8.96  -7.957], Error actual: 1942.2763100000043
# Coeficientes actuales: [ 2.678 -8.964 -7.95 ], Error actual: 1941.973752000004
# Coeficientes actuales: [ 2.673 -8.957 -7.946], Error actual: 1940.362476000004
# Coeficientes actuales: [ 2.676 -8.96  -7.937], Error actual: 1939.6420770000043
# Coeficientes actuales: [ 2.684 -8.957 -7.939], Error actual: 1939.5454460000042
# Coeficientes actuales: [ 2.676 -8.948 -7.938], Error actual: 1937.9573320000043
# Coeficientes actuales: [ 2.681 -8.943 -7.937], Error actual: 1937.144269000004
# Coeficientes actuales: [ 2.671 -8.939 -7.93 ], Error actual: 1935.5072440000038
# Coeficientes actuales: [ 2.675 -8.941 -7.925], Error actual: 1935.1845090000045
# Coeficientes actuales: [ 2.681 -8.942 -7.923], Error actual: 1935.162738000004
# Coeficientes actuales: [ 2.678 -8.947 -7.916], Error actual: 1934.9413110000044
# Coeficientes actuales: [ 2.679 -8.948 -7.907], Error actual: 1933.9263780000042
# Coeficientes actuales: [ 2.683 -8.947 -7.904], Error actual: 1933.4614960000044
# Coeficientes actuales: [ 2.675 -8.941 -7.909], Error actual: 1933.0849570000044
# Coeficientes actuales: [ 2.674 -8.934 -7.912], Error actual: 1932.4161120000037
# Coeficientes actuales: [ 2.673 -8.926 -7.915], Error actual: 1931.5979700000044
# Coeficientes actuales: [ 2.676 -8.928 -7.908], Error actual: 1931.027232000005
# Coeficientes actuales: [ 2.67  -8.932 -7.901], Error actual: 1930.6302050000045
# Coeficientes actuales: [ 2.672 -8.934 -7.894], Error actual: 1930.0326480000049
# Coeficientes actuales: [ 2.669 -8.933 -7.889], Error actual: 1929.198101000005
# Coeficientes actuales: [ 2.673 -8.939 -7.881], Error actual: 1929.0911410000049
# Coeficientes actuales: [ 2.67  -8.942 -7.875], Error actual: 1928.7269410000044
# Coeficientes actuales: [ 2.669 -8.934 -7.878], Error actual: 1927.905843000005
# Coeficientes actuales: [ 2.662 -8.929 -7.878], Error actual: 1927.1202310000047
# Coeficientes actuales: [ 2.663 -8.926 -7.877], Error actual: 1926.5326260000047
# Coeficientes actuales: [ 2.67  -8.92  -7.868], Error actual: 1924.5092600000048
# Coeficientes actuales: [ 2.669 -8.912 -7.873], Error actual: 1923.955034000005
# Coeficientes actuales: [ 2.674 -8.911 -7.871], Error actual: 1923.6435340000048
# Coeficientes actuales: [ 2.671 -8.905 -7.876], Error actual: 1923.344060000005
# Coeficientes actuales: [ 2.663 -8.9   -7.87 ], Error actual: 1921.6903070000049
# Coeficientes actuales: [ 2.669 -8.902 -7.866], Error actual: 1921.557195000005
# Coeficientes actuales: [ 2.668 -8.896 -7.871], Error actual: 1921.3015330000048
# Coeficientes actuales: [ 2.665 -8.893 -7.866], Error actual: 1920.1508920000044
# Coeficientes actuales: [ 2.66  -8.894 -7.861], Error actual: 1919.5825970000049
# Coeficientes actuales: [ 2.664 -8.893 -7.852], Error actual: 1918.3089030000049
# Coeficientes actuales: [ 2.655 -8.886 -7.85 ], Error actual: 1916.9018590000048
# Coeficientes actuales: [ 2.656 -8.877 -7.855], Error actual: 1916.2093500000046
# Coeficientes actuales: [ 2.651 -8.876 -7.849], Error actual: 1915.2423260000041
# Coeficientes actuales: [ 2.65  -8.88  -7.843], Error actual: 1915.0607250000046
# Coeficientes actuales: [ 2.657 -8.881 -7.84 ], Error actual: 1914.8596720000046
# Coeficientes actuales: [ 2.649 -8.874 -7.84 ], Error actual: 1913.7557550000047
# Coeficientes actuales: [ 2.657 -8.874 -7.839], Error actual: 1913.6836980000044
# Coeficientes actuales: [ 2.651 -8.873 -7.837], Error actual: 1913.2182290000042
# Coeficientes actuales: [ 2.643 -8.865 -7.844], Error actual: 1912.9186360000047
# Coeficientes actuales: [ 2.648 -8.87  -7.838], Error actual: 1912.8856400000047
# Coeficientes actuales: [ 2.643 -8.873 -7.833], Error actual: 1912.6992610000043
# Coeficientes actuales: [ 2.636 -8.865 -7.835], Error actual: 1911.7997980000046
# Coeficientes actuales: [ 2.635 -8.858 -7.839], Error actual: 1911.2557100000045
# Coeficientes actuales: [ 2.636 -8.85  -7.835], Error actual: 1909.4828530000045
# Coeficientes actuales: [ 2.641 -8.841 -7.845], Error actual: 1909.396845000005
# Coeficientes actuales: [ 2.636 -8.841 -7.843], Error actual: 1909.1513820000046
# Coeficientes actuales: [ 2.628 -8.832 -7.848], Error actual: 1908.5115360000045
# Coeficientes actuales: [ 2.619 -8.831 -7.843], Error actual: 1907.8932690000047
# Coeficientes actuales: [ 2.624 -8.824 -7.847], Error actual: 1907.2045170000047
# Coeficientes actuales: [ 2.621 -8.826 -7.84 ], Error actual: 1906.657155000005
# Coeficientes actuales: [ 2.625 -8.821 -7.832], Error actual: 1904.7439280000049
# Coeficientes actuales: [ 2.63  -8.815 -7.83 ], Error actual: 1903.502775000005
# Coeficientes actuales: [ 2.625 -8.81  -7.831], Error actual: 1902.9112500000047
# Coeficientes actuales: [ 2.628 -8.802 -7.83 ], Error actual: 1901.5276560000048
# Coeficientes actuales: [ 2.622 -8.803 -7.821], Error actual: 1900.5549860000046
# Coeficientes actuales: [ 2.63  -8.794 -7.816], Error actual: 1898.4797920000053
# Coeficientes actuales: [ 2.623 -8.798 -7.81 ], Error actual: 1898.3307550000047
# Coeficientes actuales: [ 2.614 -8.799 -7.804], Error actual: 1897.8386790000043
# Coeficientes actuales: [ 2.621 -8.793 -7.808], Error actual: 1897.3204720000044
# Coeficientes actuales: [ 2.611 -8.793 -7.799], Error actual: 1896.310405000004
# Coeficientes actuales: [ 2.609 -8.79  -7.801], Error actual: 1896.1537260000039
# Coeficientes actuales: [ 2.617 -8.79  -7.799], Error actual: 1895.7275380000042
# Coeficientes actuales: [ 2.623 -8.784 -7.806], Error actual: 1895.6670510000044
# Coeficientes actuales: [ 2.613 -8.775 -7.799], Error actual: 1893.4687810000041
# Coeficientes actuales: [ 2.62  -8.768 -7.798], Error actual: 1892.2005640000043
# Coeficientes actuales: [ 2.613 -8.766 -7.793], Error actual: 1891.2941740000042
# Coeficientes actuales: [ 2.619 -8.758 -7.789], Error actual: 1889.5138260000047
# Coeficientes actuales: [ 2.624 -8.75  -7.792], Error actual: 1888.7244440000047
# Coeficientes actuales: [ 2.623 -8.743 -7.786], Error actual: 1886.8949720000048
# Coeficientes actuales: [ 2.632 -8.738 -7.783], Error actual: 1885.9321810000047
# Coeficientes actuales: [ 2.632 -8.741 -7.774], Error actual: 1885.2092710000047
# Coeficientes actuales: [ 2.63  -8.74  -7.768], Error actual: 1884.243340000005
# Coeficientes actuales: [ 2.63  -8.747 -7.76 ], Error actual: 1884.2340710000046
# Coeficientes actuales: [ 2.621 -8.744 -7.751], Error actual: 1882.4900540000042
# Coeficientes actuales: [ 2.625 -8.744 -7.742], Error actual: 1881.3791550000049
# Coeficientes actuales: [ 2.62  -8.742 -7.739], Error actual: 1880.6303170000047
# Coeficientes actuales: [ 2.612 -8.738 -7.731], Error actual: 1878.9545010000043
# Coeficientes actuales: [ 2.617 -8.738 -7.725], Error actual: 1878.1977260000044
# Coeficientes actuales: [ 2.624 -8.739 -7.719], Error actual: 1877.6629140000043
# Coeficientes actuales: [ 2.625 -8.734 -7.724], Error actual: 1877.5948910000047
# Coeficientes actuales: [ 2.619 -8.728 -7.731], Error actual: 1877.5126340000045
# Coeficientes actuales: [ 2.614 -8.719 -7.723], Error actual: 1875.0896780000044
# Coeficientes actuales: [ 2.615 -8.723 -7.716], Error actual: 1874.788872000004
# Coeficientes actuales: [ 2.606 -8.715 -7.712], Error actual: 1873.0276870000043
# Coeficientes actuales: [ 2.599 -8.721 -7.703], Error actual: 1872.8043490000039
# Coeficientes actuales: [ 2.589 -8.712 -7.704], Error actual: 1871.714571000004
# Coeficientes actuales: [ 2.583 -8.715 -7.697], Error actual: 1871.4289090000036
# Coeficientes actuales: [ 2.589 -8.714 -7.689], Error actual: 1870.0644940000038
# Coeficientes actuales: [ 2.58  -8.71  -7.691], Error actual: 1869.9514850000035
# Coeficientes actuales: [ 2.574 -8.714 -7.682], Error actual: 1869.633972000003
# Coeficientes actuales: [ 2.583 -8.713 -7.674], Error actual: 1868.0997680000041
# Coeficientes actuales: [ 2.578 -8.706 -7.679], Error actual: 1867.813237000004
# Coeficientes actuales: [ 2.583 -8.709 -7.674], Error actual: 1867.473528000004
# Coeficientes actuales: [ 2.581 -8.703 -7.668], Error actual: 1865.806092000004
# Coeficientes actuales: [ 2.571 -8.7   -7.664], Error actual: 1865.1570910000034
# Coeficientes actuales: [ 2.57  -8.697 -7.66 ], Error actual: 1864.194711000004
# Coeficientes actuales: [ 2.579 -8.705 -7.651], Error actual: 1863.9539810000038
# Coeficientes actuales: [ 2.587 -8.699 -7.655], Error actual: 1863.3519250000038
# Coeficientes actuales: [ 2.584 -8.69  -7.646], Error actual: 1860.8485360000036
# Coeficientes actuales: [ 2.584 -8.683 -7.654], Error actual: 1860.812351000004
# Coeficientes actuales: [ 2.586 -8.676 -7.659], Error actual: 1860.3620610000041
# Coeficientes actuales: [ 2.583 -8.681 -7.65 ], Error actual: 1860.0017200000038
# Coeficientes actuales: [ 2.575 -8.673 -7.649], Error actual: 1858.8056050000039
# Coeficientes actuales: [ 2.57  -8.676 -7.644], Error actual: 1858.7707320000036
# Coeficientes actuales: [ 2.565 -8.672 -7.643], Error actual: 1858.1908380000036
# Coeficientes actuales: [ 2.572 -8.666 -7.638], Error actual: 1856.360360000004
# Coeficientes actuales: [ 2.579 -8.672 -7.629], Error actual: 1855.959126000004
# Coeficientes actuales: [ 2.585 -8.671 -7.625], Error actual: 1855.2064290000042
# Coeficientes actuales: [ 2.576 -8.67  -7.625], Error actual: 1855.190533000004
# Coeficientes actuales: [ 2.583 -8.664 -7.628], Error actual: 1854.550699000004
# Coeficientes actuales: [ 2.592 -8.664 -7.624], Error actual: 1854.0065280000044
# Coeficientes actuales: [ 2.585 -8.668 -7.618], Error actual: 1853.8466590000041
# Coeficientes actuales: [ 2.58  -8.66  -7.609], Error actual: 1851.5159250000042
# Coeficientes actuales: [ 2.574 -8.651 -7.615], Error actual: 1851.0047340000037
# Coeficientes actuales: [ 2.566 -8.643 -7.615], Error actual: 1849.945758000004
# Coeficientes actuales: [ 2.56  -8.638 -7.612], Error actual: 1848.9539480000042
# Coeficientes actuales: [ 2.558 -8.63  -7.61 ], Error actual: 1847.5048520000041
# Coeficientes actuales: [ 2.564 -8.623 -7.607], Error actual: 1845.8572980000044
# ...
# Coeficientes actuales: [-1.665  8.301  1.284], Error actual: 2.321832000000155
# Coeficientes actuales: [-1.67   8.309  1.281], Error actual: 2.294782000000063
# Coeficientes actuales: [-1.668  8.311  1.271], Error actual: 2.2824180000001166
# Coeficientes actuales: [-1.671  8.307  1.263], Error actual: 2.278173000000005
# Coeficientes actuales: [-1.667  8.314  1.255], Error actual: 2.2609900000001435
# Coeficientes actuales: [-1.669  8.321  1.256], Error actual: 2.2489840000001293
# Coeficientes actuales: [-1.669  8.33   1.25 ], Error actual: 2.2357630000001727
# Coeficientes actuales: [-1.674  8.332  1.24 ], Error actual: 2.206668000000037
# Coeficientes actuales: [-1.673  8.339  1.246], Error actual: 2.205976000000112
# Coeficientes actuales: [-1.673  8.344  1.243], Error actual: 2.1981340000001355
# Coeficientes actuales: [-1.674  8.34   1.235], Error actual: 2.187933000000075
# Coeficientes actuales: [-1.672  8.342  1.232], Error actual: 2.187676000000139
# Coeficientes actuales: [-1.675  8.35   1.231], Error actual: 2.169230000000102
# Coeficientes actuales: [-1.675  8.344  1.223], Error actual: 2.1669380000000613
# Coeficientes actuales: [-1.674  8.34   1.216], Error actual: 2.1658360000000565
# Coeficientes actuales: [-1.673  8.338  1.209], Error actual: 2.1618380000000688
# Coeficientes actuales: [-1.673  8.342  1.202], Error actual: 2.1478910000000853
# Coeficientes actuales: [-1.674  8.35   1.192], Error actual: 2.124144000000091
# Coeficientes actuales: [-1.673  8.357  1.187], Error actual: 2.113301000000156
# Coeficientes actuales: [-1.675  8.356  1.177], Error actual: 2.0988380000000832
# Coeficientes actuales: [-1.678  8.363  1.182], Error actual: 2.0919990000000475
# Coeficientes actuales: [-1.677  8.364  1.178], Error actual: 2.0857710000000744
# Coeficientes actuales: [-1.676  8.362  1.169], Error actual: 2.0807890000000846
# Coeficientes actuales: [-1.677  8.361  1.162], Error actual: 2.0778040000000413
# Coeficientes actuales: [-1.674  8.367  1.163], Error actual: 2.0728140000001556
# Coeficientes actuales: [-1.679  8.374  1.172], Error actual: 2.062867000000069
# Coeficientes actuales: [-1.681  8.379  1.176], Error actual: 2.0589240000000477
# Coeficientes actuales: [-1.682  8.388  1.175], Error actual: 2.043141000000067
# Coeficientes actuales: [-1.687  8.393  1.172], Error actual: 2.0422359999999506
# Coeficientes actuales: [-1.683  8.398  1.177], Error actual: 2.0317140000000986
# Coeficientes actuales: [-1.689  8.403  1.172], Error actual: 2.025707999999949
# Coeficientes actuales: [-1.687  8.405  1.174], Error actual: 2.0166480000000178
# Coeficientes actuales: [-1.689  8.413  1.172], Error actual: 2.0032080000000074
# Coeficientes actuales: [-1.686  8.415  1.168], Error actual: 1.9971190000001007
# Coeficientes actuales: [-1.692  8.422  1.158], Error actual: 1.9797039999999622
# Coeficientes actuales: [-1.689  8.426  1.165], Error actual: 1.9764140000000772
# Coeficientes actuales: [-1.688  8.426  1.159], Error actual: 1.9709170000000924
# Coeficientes actuales: [-1.696  8.435  1.161], Error actual: 1.9698299999999254
# Coeficientes actuales: [-1.69   8.436  1.166], Error actual: 1.9674960000001023
# Coeficientes actuales: [-1.694  8.443  1.16 ], Error actual: 1.9464550000000267
# Coeficientes actuales: [-1.695  8.441  1.15 ], Error actual: 1.9407439999999803
# Coeficientes actuales: [-1.691  8.441  1.14 ], Error actual: 1.92670000000008
# Coeficientes actuales: [-1.693  8.445  1.14 ], Error actual: 1.9200720000000477
# Coeficientes actuales: [-1.695  8.453  1.137], Error actual: 1.9057730000000346
# Coeficientes actuales: [-1.696  8.459  1.135], Error actual: 1.8953940000000389
# Coeficientes actuales: [-1.698  8.461  1.134], Error actual: 1.8936069999999912
# Coeficientes actuales: [-1.697  8.463  1.124], Error actual: 1.8779160000000221
# Coeficientes actuales: [-1.694  8.471  1.114], Error actual: 1.8643990000001371
# Coeficientes actuales: [-1.693  8.477  1.105], Error actual: 1.8583410000001868
# Coeficientes actuales: [-1.695  8.468  1.102], Error actual: 1.8480830000000839
# Coeficientes actuales: [-1.694  8.475  1.098], Error actual: 1.8420870000001401
# Coeficientes actuales: [-1.694  8.474  1.097], Error actual: 1.8411170000001345
# Coeficientes actuales: [-1.697  8.468  1.091], Error actual: 1.8377660000000196
# Coeficientes actuales: [-1.7    8.473  1.084], Error actual: 1.8322149999999577
# Coeficientes actuales: [-1.701  8.482  1.084], Error actual: 1.8146189999999756
# Coeficientes actuales: [-1.696  8.486  1.077], Error actual: 1.8027330000001291
# Coeficientes actuales: [-1.696  8.486  1.07 ], Error actual: 1.7947600000001216
# Coeficientes actuales: [-1.699  8.491  1.061], Error actual: 1.7750690000000584
# Coeficientes actuales: [-1.696  8.494  1.055], Error actual: 1.7738690000001482
# Coeficientes actuales: [-1.7    8.495  1.06 ], Error actual: 1.768375000000055
# Coeficientes actuales: [-1.699  8.5    1.052], Error actual: 1.7558990000000956
# Coeficientes actuales: [-1.7    8.507  1.052], Error actual: 1.7474390000001123
# Coeficientes actuales: [-1.7    8.514  1.043], Error actual: 1.7337330000001434
# Coeficientes actuales: [-1.703  8.519  1.033], Error actual: 1.7109490000000764
# Coeficientes actuales: [-1.704  8.523  1.03 ], Error actual: 1.7024950000000703
# Coeficientes actuales: [-1.71   8.531  1.03 ], Error actual: 1.7011189999999508
# Coeficientes actuales: [-1.703  8.531  1.029], Error actual: 1.6980370000001415
# Coeficientes actuales: [-1.709  8.53   1.026], Error actual: 1.6962109999999657
# Coeficientes actuales: [-1.709  8.538  1.021], Error actual: 1.6757740000000079
# Coeficientes actuales: [-1.709  8.539  1.023], Error actual: 1.6754930000000166
# Coeficientes actuales: [-1.705  8.54   1.017], Error actual: 1.6726500000001248
# Coeficientes actuales: [-1.706  8.544  1.009], Error actual: 1.6586290000001107
# Coeficientes actuales: [-1.71   8.549  1.015], Error actual: 1.6541540000000394
# Coeficientes actuales: [-1.712  8.557  1.014], Error actual: 1.643207000000028
# Coeficientes actuales: [-1.711  8.555  1.009], Error actual: 1.6410210000000425
# Coeficientes actuales: [-1.713  8.557  1.007], Error actual: 1.6398209999999958
# Coeficientes actuales: [-1.712  8.558  1.002], Error actual: 1.6318960000000233
# Coeficientes actuales: [-1.713  8.561  0.997], Error actual: 1.6250210000000096
# Coeficientes actuales: [-1.714  8.561  0.991], Error actual: 1.6247939999999739
# Coeficientes actuales: [-1.717  8.569  0.981], Error actual: 1.6162769999999276
# Coeficientes actuales: [-1.709  8.559  0.977], Error actual: 1.610277000000084
# Coeficientes actuales: [-1.71   8.566  0.975], Error actual: 1.599589000000093
# Coeficientes actuales: [-1.714  8.568  0.968], Error actual: 1.5964919999999891
# Coeficientes actuales: [-1.714  8.569  0.96 ], Error actual: 1.5904949999999878
# Coeficientes actuales: [-1.713  8.577  0.95 ], Error actual: 1.5663960000000523
# Coeficientes actuales: [-1.711  8.583  0.949], Error actual: 1.5614050000001327
# Coeficientes actuales: [-1.71   8.578  0.94 ], Error actual: 1.5610560000001275
# Coeficientes actuales: [-1.713  8.58   0.945], Error actual: 1.5586020000000622
# Coeficientes actuales: [-1.713  8.589  0.95 ], Error actual: 1.5518520000001148
# Coeficientes actuales: [-1.719  8.598  0.943], Error actual: 1.5366219999999962
# Coeficientes actuales: [-1.716  8.598  0.942], Error actual: 1.5317040000000752
# Coeficientes actuales: [-1.72   8.604  0.933], Error actual: 1.5225329999999926
# Coeficientes actuales: [-1.719  8.609  0.94 ], Error actual: 1.5157400000000512
# Coeficientes actuales: [-1.72   8.615  0.932], Error actual: 1.502335000000049
# Coeficientes actuales: [-1.719  8.622  0.936], Error actual: 1.501035000000117
# Coeficientes actuales: [-1.72   8.622  0.939], Error actual: 1.5008370000000941
# Coeficientes actuales: [-1.725  8.63   0.933], Error actual: 1.4871499999999978
# Coeficientes actuales: [-1.72   8.637  0.926], Error actual: 1.4842950000001611
# Coeficientes actuales: [-1.725  8.637  0.925], Error actual: 1.4705410000000296
# Coeficientes actuales: [-1.726  8.636  0.917], Error actual: 1.4695329999999873
# Coeficientes actuales: [-1.723  8.64   0.923], Error actual: 1.4674500000000972
# Coeficientes actuales: [-1.728  8.645  0.925], Error actual: 1.4637619999999911
# Coeficientes actuales: [-1.724  8.65   0.923], Error actual: 1.4604370000001212
# Coeficientes actuales: [-1.725  8.65   0.926], Error actual: 1.4597550000001003
# Coeficientes actuales: [-1.728  8.655  0.935], Error actual: 1.4593620000000556
# Coeficientes actuales: [-1.732  8.661  0.939], Error actual: 1.458725999999982
# Coeficientes actuales: [-1.734  8.666  0.941], Error actual: 1.4583089999999537
# Coeficientes actuales: [-1.729  8.661  0.935], Error actual: 1.4538690000000607
# Coeficientes actuales: [-1.732  8.67   0.942], Error actual: 1.4516400000000356
# Coeficientes actuales: [-1.729  8.664  0.934], Error actual: 1.4512990000000758
# Coeficientes actuales: [-1.728  8.67   0.925], Error actual: 1.4442370000001294
# Coeficientes actuales: [-1.733  8.67   0.919], Error actual: 1.4315859999999871
# Coeficientes actuales: [-1.735  8.676  0.911], Error actual: 1.4221859999999544
# Coeficientes actuales: [-1.732  8.678  0.918], Error actual: 1.4214960000000534
# Coeficientes actuales: [-1.734  8.682  0.913], Error actual: 1.4125090000000171
# Coeficientes actuales: [-1.737  8.69   0.919], Error actual: 1.4120179999999833
# Coeficientes actuales: [-1.737  8.693  0.915], Error actual: 1.4048209999999957
# Coeficientes actuales: [-1.735  8.691  0.909], Error actual: 1.4005170000000369
# Coeficientes actuales: [-1.735  8.689  0.904], Error actual: 1.3977560000000222
# Coeficientes actuales: [-1.735  8.689  0.898], Error actual: 1.3927280000000164
# Coeficientes actuales: [-1.736  8.696  0.894], Error actual: 1.3823560000000228
# Coeficientes actuales: [-1.738  8.697  0.891], Error actual: 1.382345999999971
# Coeficientes actuales: [-1.736  8.703  0.889], Error actual: 1.372150000000056
# Coeficientes actuales: [-1.736  8.712  0.886], Error actual: 1.3665160000001024
# Coeficientes actuales: [-1.74   8.71   0.888], Error actual: 1.3658199999999858
# Coeficientes actuales: [-1.737  8.719  0.887], Error actual: 1.3642290000001132
# Coeficientes actuales: [-1.74   8.727  0.894], Error actual: 1.3610070000000838
# Coeficientes actuales: [-1.741  8.726  0.888], Error actual: 1.3517070000000477
# Coeficientes actuales: [-1.747  8.735  0.879], Error actual: 1.3436129999999245
# Coeficientes actuales: [-1.745  8.735  0.885], Error actual: 1.3419249999999856
# Coeficientes actuales: [-1.74   8.726  0.876], Error actual: 1.3411160000000628
# Coeficientes actuales: [-1.741  8.721  0.87 ], Error actual: 1.339500000000003
# Coeficientes actuales: [-1.742  8.727  0.875], Error actual: 1.3380300000000127
# Coeficientes actuales: [-1.745  8.736  0.871], Error actual: 1.3288059999999788
# Coeficientes actuales: [-1.749  8.745  0.865], Error actual: 1.3255329999999108
# Coeficientes actuales: [-1.747  8.753  0.869], Error actual: 1.3122610000000148
# Coeficientes actuales: [-1.744  8.743  0.859], Error actual: 1.3105460000000273
# Coeficientes actuales: [-1.748  8.749  0.858], Error actual: 1.3090789999999541
# Coeficientes actuales: [-1.742  8.751  0.848], Error actual: 1.3032150000001186
# Coeficientes actuales: [-1.747  8.75   0.85 ], Error actual: 1.298906999999979
# Coeficientes actuales: [-1.747  8.756  0.843], Error actual: 1.2864900000000055
# Coeficientes actuales: [-1.747  8.761  0.841], Error actual: 1.2805730000000297
# Coeficientes actuales: [-1.745  8.761  0.835], Error actual: 1.2783490000000801
# Coeficientes actuales: [-1.751  8.765  0.826], Error actual: 1.2741999999999267
# Coeficientes actuales: [-1.746  8.761  0.816], Error actual: 1.2607990000000315
# Coeficientes actuales: [-1.748  8.768  0.815], Error actual: 1.254125000000017
# Coeficientes actuales: [-1.744  8.766  0.806], Error actual: 1.254024000000103
# Coeficientes actuales: [-1.748  8.775  0.805], Error actual: 1.2408220000000447
# Coeficientes actuales: [-1.748  8.777  0.802], Error actual: 1.2372310000000537
# Coeficientes actuales: [-1.747  8.774  0.793], Error actual: 1.2336660000000528
# Coeficientes actuales: [-1.747  8.772  0.788], Error actual: 1.2321390000000352
# Coeficientes actuales: [-1.747  8.781  0.785], Error actual: 1.2241170000000823
# Coeficientes actuales: [-1.753  8.79   0.78 ], Error actual: 1.215146999999965
# Coeficientes actuales: [-1.753  8.792  0.78 ], Error actual: 1.211930999999976
# Coeficientes actuales: [-1.75   8.797  0.77 ], Error actual: 1.1998310000000734
# Coeficientes actuales: [-1.752  8.799  0.77 ], Error actual: 1.1964150000000284
# Coeficientes actuales: [-1.75   8.806  0.766], Error actual: 1.1957960000001202
# Coeficientes actuales: [-1.756  8.808  0.763], Error actual: 1.1885169999999596
# Coeficientes actuales: [-1.759  8.815  0.756], Error actual: 1.1870159999999086
# Coeficientes actuales: [-1.753  8.807  0.75 ], Error actual: 1.177656000000026
# Coeficientes actuales: [-1.756  8.816  0.746], Error actual: 1.1690439999999886
# Coeficientes actuales: [-1.755  8.821  0.753], Error actual: 1.1679250000000534
# Coeficientes actuales: [-1.756  8.825  0.75 ], Error actual: 1.1625030000000462
# Coeficientes actuales: [-1.756  8.827  0.75 ], Error actual: 1.1614950000000597
# Coeficientes actuales: [-1.758  8.832  0.756], Error actual: 1.1610360000000328
# Coeficientes actuales: [-1.762  8.839  0.758], Error actual: 1.1596309999999646
# Coeficientes actuales: [-1.762  8.842  0.759], Error actual: 1.1569169999999835
# Coeficientes actuales: [-1.761  8.844  0.756], Error actual: 1.152579000000017
# Coeficientes actuales: [-1.763  8.846  0.746], Error actual: 1.1464429999999557
# Coeficientes actuales: [-1.763  8.853  0.74 ], Error actual: 1.1352599999999955
# Coeficientes actuales: [-1.764  8.861  0.738], Error actual: 1.1283590000000134
# Coeficientes actuales: [-1.764  8.857  0.728], Error actual: 1.1255189999999795
# Coeficientes actuales: [-1.766  8.866  0.722], Error actual: 1.1161479999999655
# Coeficientes actuales: [-1.764  8.875  0.721], Error actual: 1.1112060000000807
# Coeficientes actuales: [-1.768  8.879  0.722], Error actual: 1.1063349999999839
# Coeficientes actuales: [-1.766  8.877  0.718], Error actual: 1.104463000000025
# Coeficientes actuales: [-1.765  8.878  0.708], Error actual: 1.0980990000000508
# Coeficientes actuales: [-1.765  8.88   0.707], Error actual: 1.0969500000000616
# Coeficientes actuales: [-1.768  8.889  0.703], Error actual: 1.0869340000000216
# Coeficientes actuales: [-1.767  8.896  0.693], Error actual: 1.0803100000000856
# Coeficientes actuales: [-1.771  8.903  0.686], Error actual: 1.067596000000003
# Coeficientes actuales: [-1.772  8.91   0.685], Error actual: 1.0627570000000164
# Coeficientes actuales: [-1.77   8.904  0.675], Error actual: 1.0603890000000253
# Coeficientes actuales: [-1.773  8.913  0.683], Error actual: 1.0598609999999984
# Coeficientes actuales: [-1.776  8.922  0.677], Error actual: 1.0529969999999607
# Coeficientes actuales: [-1.772  8.925  0.67 ], Error actual: 1.0498870000000882
# Coeficientes actuales: [-1.779  8.931  0.66 ], Error actual: 1.044743999999905
# Coeficientes actuales: [-1.777  8.926  0.658], Error actual: 1.0428349999999285
# Coeficientes actuales: [-1.776  8.935  0.655], Error actual: 1.030338000000012
# Coeficientes actuales: [-1.778  8.937  0.646], Error actual: 1.0269909999999545
# Coeficientes actuales: [-1.773  8.929  0.64 ], Error actual: 1.0265520000000452
# Coeficientes actuales: [-1.776  8.937  0.637], Error actual: 1.0196020000000054
# Coeficientes actuales: [-1.778  8.943  0.633], Error actual: 1.0151459999999757
# Coeficientes actuales: [-1.778  8.945  0.628], Error actual: 1.0111749999999826
# Coeficientes actuales: [-1.778  8.947  0.632], Error actual: 1.0111509999999975
# Coeficientes actuales: [-1.78   8.951  0.632], Error actual: 1.0106229999999643
# Coeficientes actuales: [-1.779  8.948  0.626], Error actual: 1.0092989999999713
# Coeficientes actuales: [-1.779  8.953  0.617], Error actual: 1.0008929999999892
# Coeficientes actuales: [-1.781  8.956  0.611], Error actual: 1.0007739999999379
# Coeficientes actuales: [-1.778  8.95   0.602], Error actual: 0.9976839999999808
# array([-1.778,  8.95 ,  0.602])
