# %% [markdown]
# # Simulación del Truco

# %% [markdown]
# Las **cartas** deben registra el numero, palo y valor de la carta.
# El valor debe reflejar la jerarquía de las cartas en el juego del truco.

# %%
def calcular_valor(numero, palo):
    
    valores = {
        (1, "espada"): 14,
        (1, "basto"): 13,
        (7, "espada"): 12,
        (7, "oro"): 11,
        (3,"espada"): 10,
        (3,"oro"): 10,
        (3,"basto"): 10,
        (3,"copa"): 10,
        (2,"basto"): 9,
        (2,"espada"): 9,
        (2,"copa"): 9,
        (2,"oro"): 9,
        (1,"copa"): 8,
        (1, "oro"): 8,
        (12,"oro"): 7,
        (12,"espada"): 7,
        (12,"copa"): 7,
        (12,"basto"): 7,
        (11,"copa"): 6,
        (11,"basto"): 6,
        (11,"espada"): 6,
        (11,"oro"): 6,
        (10,"oro"): 5,
        (10,"basto"): 5,
        (10,"copa"): 5,
        (10,"espada"): 5,
        (7,"copa"): 4,
        (7,"basto"): 4,
        (6,"espada"): 3,
        (6,"basto"): 3,
        (6,"oro"): 3,
        (6,"copa"): 3,
        (5,"oro"): 2,
        (5,"espada"): 2,
        (5,"copa"): 2,
        (5,"basto"): 2,
        (4,"basto"): 1,
        (4,"copa"): 1,
        (4,"espada"): 1,
        (4,"oro"): 1    
    }
    
    return valores.get((numero,palo))
        

class Carta:
    def __init__(self, numero, palo):
        self.numero = numero
        self.palo = palo
        self.valor = calcular_valor(numero, palo)
        
    
    def __str__(self):
        return f"La carta con numero {self.numero} y palo {self.palo} vale {self.valor} puntos"
           

c = Carta(1,"oro")
print(c)
# Out:
# La carta con numero 1 y palo oro vale 8 puntos

# %% [markdown]
# **Mazo**: Representan las cartas españolas de 1 al 12, en los palos de oro, copa, espada y basto.
#
# Debe existir una función que permita barajar las cartas.
# y otra función que permita repartir las cartas a los jugadores.

# %%
import random
import itertools


numeros = [1,2,3,4,5,6,7,10,11,12]
palos = ["oro", "basto", "espada", "copa"]
mazo = list(itertools.product(numeros, palos))

     
class Mazo:
    def __init__(self):
        self.mazo = mazo
        
    def mezclar(self):
        random.shuffle(self.mazo)
        
    def repartir(self, cantidad):
        tres_cartas = self.mazo[:cantidad]
        self.mazo = self.mazo[cantidad:]
        return tres_cartas
    
    def __str__(self):
            return f"{self.mazo} ahora el mazo tiene {len(self.mazo)} cartas"

m = Mazo()
m.mezclar()
print(m.repartir(3))
# Out:
# [(2, 'copa'), (1, 'espada'), (3, 'copa')]

# %% [markdown]
# **Jugador**: Deben tener un nombre y las cartas que tiene en la mano. Debe acumular los puntos ganados.
#
# Nota: Para simplificar el problema, el jugador elige la carta a jugar de forma aleatoria.

# %%
class Jugador:
    def __init__(self, nombre):
        self.nombre = nombre
        self.cartas_jugador = []
        self.puntos = 0
        
    def recibir_cartas(self, cartas):
        self.cartas_jugador = cartas
        return f"El jugador {self.nombre} tiene las cartas {self.cartas_jugador}"
    
    def jugar_carta(self):
        decision_random = random.randint(0, len(self.cartas_jugador)-1)
        carta_a_jugar = self.cartas_jugador.pop(decision_random)
        
        return carta_a_jugar
    
   
        


j = Jugador("Juan")
j.recibir_cartas(m.repartir(3))
print(j.jugar_carta())
# Out:
# (3, 'espada')

# %% [markdown]
# **Partida**: Debe tener dos jugadores, un mazo de cartas y un puntaje. Debe permitir jugar una carta por ronda y definir el ganador de la ronda. Debe permitir jugar hasta que se terminen las cartas del mazo.

# %%
class Partida:
    def __init__(self, jugador1, jugador2):
        self.jugador1 = jugador1
        self.jugador2 = jugador2
        self.mazo = m2 = Mazo()
        

    def jugar_ronda(self):
    
        print(f"\n{self.jugador1.nombre} tiene las cartas: {self.jugador1.cartas_jugador}")
        print(f"{self.jugador2.nombre} tiene las cartas: {self.jugador2.cartas_jugador}")
   
        carta_jugada_j1 = self.jugador1.jugar_carta()
        cj1 = Carta(*carta_jugada_j1)
        print(f"\n{self.jugador1.nombre} juega: {cj1}")
    
        carta_jugada_j2 = self.jugador2.jugar_carta()
        cj2 = Carta(*carta_jugada_j2)
        print(f"{self.jugador2.nombre} juega: {cj2}")
    
        print("\nResultado:")
        print("="*30)
    
        if cj1.valor > cj2.valor:
            print(f"🏆 Gana la ronda: {self.jugador1.nombre}")
            self.jugador1.puntos += 1
        elif cj1.valor < cj2.valor:
            print(f"🏆 Gana la ronda: {self.jugador2.nombre}")
            self.jugador2.puntos += 1
        else:
            print("🤝 Empate, ninguno recibe puntos")


        print("-"*30)
        print(f"Puntos acumulados de {self.jugador1.nombre}: {self.jugador1.puntos}")
        print(f"Puntos acumulados de {self.jugador2.nombre}: {self.jugador2.puntos}")
        print("="*30, "\n\n")

           
    def jugar(self):
        r = 0
        p = 1
        while True:
            if self.jugador1.puntos >= 15 or self.jugador2.puntos >= 15:
                break
        
            self.mazo = Mazo()
            self.mazo.mezclar()
            self.jugador1.recibir_cartas(self.mazo.repartir(3))
            self.jugador2.recibir_cartas(self.mazo.repartir(3))
            
            print(f"MANO: {p}")
            
            while len(self.jugador1.cartas_jugador) > 0 and len(self.jugador2.cartas_jugador) > 0:
                r += 1
                print(F"Ronda: {r} ")
                self.jugar_ronda()
            
            p += 1
            r = 0
                
        if self.jugador1.puntos >= 15:
            print(f"El ganador es {self.jugador1.nombre} con {self.jugador1.puntos} puntos!")
        elif self.jugador2.puntos >= 15:
            print(f"El ganador es {self.jugador2.nombre} con {self.jugador2.puntos} puntos!")

      

p = Partida(Jugador("Juan"), Jugador("Pedro"))
p.jugar()
# Out:
# MANO: 1
# Ronda: 1
#
# Juan tiene las cartas: [(12, 'copa'), (1, 'espada'), (2, 'basto')]
# Pedro tiene las cartas: [(4, 'espada'), (12, 'espada'), (1, 'oro')]
#
# Juan juega: La carta con numero 2 y palo basto vale 9 puntos
# Pedro juega: La carta con numero 12 y palo espada vale 7 puntos
#
# Resultado:
# ...
# 🏆 Gana la ronda: Juan
# ------------------------------
# Puntos acumulados de Juan: 1
# Puntos acumulados de Pedro: 0
# ...
#
#
# Ronda: 2
#
# Juan tiene las cartas: [(12, 'copa'), (1, 'espada')]
# Pedro tiene las cartas: [(4, 'espada'), (1, 'oro')]
#
# Juan juega: La carta con numero 1 y palo espada vale 14 puntos
# Pedro juega: La carta con numero 1 y palo oro vale 8 puntos
#
# Resultado:
# ...
# 🏆 Gana la ronda: Juan
# ------------------------------
# Puntos acumulados de Juan: 2
# Puntos acumulados de Pedro: 0
# ...
#
#
# Ronda: 3
#
# Juan tiene las cartas: [(12, 'copa')]
# Pedro tiene las cartas: [(4, 'espada')]
#
# Juan juega: La carta con numero 12 y palo copa vale 7 puntos
# ...
