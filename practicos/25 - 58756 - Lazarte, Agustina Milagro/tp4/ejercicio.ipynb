# %% [markdown]
# # Simulación del Truco

# %% [markdown]
# Las **cartas** deben registra el numero, palo y valor de la carta.
# El valor debe reflejar la jerarquía de las cartas en el juego del truco.

# %%
def calcular_valor(numero, palo):
   
    jerarquia = {
        (1, 'espada'): 14,
        (1, 'basto'): 13,
        (7, 'espada'): 12,
        (7, 'oro'): 11
    }
    
    if (numero, palo) in jerarquia:
        return jerarquia[(numero, palo)]
    else:
        if numero == 3:
            return 10
        elif numero == 2:
            return 9
        elif numero == 1:
            return 8  
        elif numero == 12:
            return 7
        elif numero == 11:
            return 6
        elif numero == 10:
            return 5
        elif numero == 7:
            return 4  
        elif numero == 6:
            return 3
        elif numero == 5:
            return 2
        elif numero == 4:
            return 1
        else:
            return 0 


class Carta:
    def __init__(self, numero, palo):
        self.numero = numero
        self.palo = palo
        self.valor = calcular_valor(numero, palo)
    
    def __str__(self):
        return f"Carta: {self.numero} de {self.palo}, Valor Truco: {self.valor}"


c = Carta(1, "oro")
print(c)

c2 = Carta(7, "espada")
print(c2)

c3 = Carta(5, "basto")
print(c3)

c4 = Carta(12, "copa")
print(c4)
# Out:
# Carta: 1 de oro, Valor Truco: 8
# Carta: 7 de espada, Valor Truco: 12
# Carta: 5 de basto, Valor Truco: 2
# Carta: 12 de copa, Valor Truco: 7

# %% [markdown]
# **Mazo**: Representan las cartas españolas de 1 al 12, en los palos de oro, copa, espada y basto.
#
# Debe existir una función que permita barajar las cartas.
# y otra función que permita repartir las cartas a los jugadores.

# %%
import random


class Carta:
    def __init__(self, numero, palo):
        self.numero = numero
        self.palo = palo
        self.valor = calcular_valor(numero, palo)
    
    def __str__(self):
        return f"{self.numero} de {self.palo}"


def calcular_valor(numero, palo):
    jerarquia = {
        (1, 'espada'): 14,
        (1, 'basto'): 13,
        (7, 'espada'): 12,
        (7, 'oro'): 11
    }
    
    if (numero, palo) in jerarquia:
        return jerarquia[(numero, palo)]
    else:
        if numero == 3:
            return 10
        elif numero == 2:
            return 9
        elif numero == 1:
            return 8
        elif numero == 12:
            return 7
        elif numero == 11:
            return 6
        elif numero == 10:
            return 5
        elif numero == 7:
            return 4
        elif numero == 6:
            return 3
        elif numero == 5:
            return 2
        elif numero == 4:
            return 1
        else:
            return 0


class Mazo:
    palos = ["oro", "copa", "espada", "basto"]
    
    def __init__(self):
        self.cartas = [Carta(numero, palo) for palo in self.palos for numero in range(1, 13)]
    
   
    def mezclar(self):
        random.shuffle(self.cartas)
    
   
    def repartir(self, cantidad):
        
        if cantidad > len(self.cartas):
            raise ValueError("No hay suficientes cartas para repartir")
        repartidas = self.cartas[:cantidad]
        self.cartas = self.cartas[cantidad:]  
        return repartidas


m = Mazo()          
m.mezclar()          
repartidas = m.repartir(3)  


print("Cartas repartidas:")
for carta in repartidas:
    print(carta)
# Out:
# Cartas repartidas:
# 1 de oro
# 1 de espada
# 10 de oro

# %% [markdown]
# **Jugador**: Deben tener un nombre y las cartas que tiene en la mano. Debe acumular los puntos ganados.
#
# Nota: Para simplificar el problema, el jugador elige la carta a jugar de forma aleatoria.

# %%
import random


class Carta:
    def __init__(self, numero, palo):
        self.numero = numero
        self.palo = palo
        self.valor = calcular_valor(numero, palo)
    
    def __str__(self):
        return f"{self.numero} de {self.palo}"


def calcular_valor(numero, palo):
    jerarquia = {
        (1, 'espada'): 14,
        (1, 'basto'): 13,
        (7, 'espada'): 12,
        (7, 'oro'): 11
    }
    
    if (numero, palo) in jerarquia:
        return jerarquia[(numero, palo)]
    else:
        if numero == 3:
            return 10
        elif numero == 2:
            return 9
        elif numero == 1:
            return 8
        elif numero == 12:
            return 7
        elif numero == 11:
            return 6
        elif numero == 10:
            return 5
        elif numero == 7:
            return 4
        elif numero == 6:
            return 3
        elif numero == 5:
            return 2
        elif numero == 4:
            return 1
        else:
            return 0


class Mazo:
    palos = ["oro", "copa", "espada", "basto"]
    
    def __init__(self):
        self.cartas = [Carta(numero, palo) for palo in self.palos for numero in range(1, 13)]
    
    def mezclar(self):
        random.shuffle(self.cartas)
    
    def repartir(self, cantidad):
        if cantidad > len(self.cartas):
            raise ValueError("No hay suficientes cartas para repartir")
        repartidas = self.cartas[:cantidad]
        self.cartas = self.cartas[cantidad:]
        return repartidas


class Jugador:
    def __init__(self, nombre):
        self.nombre = nombre
        self.cartas = []  
        self.puntos = 0   

   
    def recibir_cartas(self, cartas):
        self.cartas = cartas

    
    def jugar_carta(self):
        if not self.cartas:
            raise ValueError("El jugador no tiene cartas para jugar")
        carta_a_jugar = random.choice(self.cartas)
        self.cartas.remove(carta_a_jugar)  
        return carta_a_jugar

    
    def ganar_puntos(self, puntos):
        self.puntos += puntos

    def __str__(self):
        return f"Jugador: {self.nombre}, Puntos: {self.puntos}"




m = Mazo()
m.mezclar()


j = Jugador("Juan")


j.recibir_cartas(m.repartir(3))


print("Carta jugada por Juan:")
print(j.jugar_carta())

print("Cartas restantes en la mano:")
for carta in j.cartas:
    print(carta)


j.ganar_puntos(5)
print(j)
# Out:
# Carta jugada por Juan:
# 7 de basto
# Cartas restantes en la mano:
# 10 de espada
# 12 de oro
# Jugador: Juan, Puntos: 5

# %% [markdown]
# **Partida**: Debe tener dos jugadores, un mazo de cartas y un puntaje. Debe permitir jugar una carta por ronda y definir el ganador de la ronda. Debe permitir jugar hasta que se terminen las cartas del mazo.

# %%
import random


class Carta:
    def __init__(self, numero, palo):
        self.numero = numero
        self.palo = palo
        self.valor = calcular_valor(numero, palo)
    
    def __str__(self):
        return f"{self.numero} de {self.palo}"


def calcular_valor(numero, palo):
    jerarquia = {
        (1, 'espada'): 14,
        (1, 'basto'): 13,
        (7, 'espada'): 12,
        (7, 'oro'): 11
    }
    
    if (numero, palo) in jerarquia:
        return jerarquia[(numero, palo)]
    else:
        if numero == 3:
            return 10
        elif numero == 2:
            return 9
        elif numero == 1:
            return 8
        elif numero == 12:
            return 7
        elif numero == 11:
            return 6
        elif numero == 10:
            return 5
        elif numero == 7:
            return 4
        elif numero == 6:
            return 3
        elif numero == 5:
            return 2
        elif numero == 4:
            return 1
        else:
            return 0


class Mazo:
    palos = ["oro", "copa", "espada", "basto"]
    
    def __init__(self):
        self.cartas = [Carta(numero, palo) for palo in self.palos for numero in range(1, 13)]
    
    def mezclar(self):
        random.shuffle(self.cartas)
    
    def repartir(self, cantidad):
        
        if cantidad > len(self.cartas):
            print("No hay suficientes cartas. Volviendo a mezclar el mazo.")
            self.__init__()  
            self.mezclar()
        repartidas = self.cartas[:cantidad]
        self.cartas = self.cartas[cantidad:]
        return repartidas


class Jugador:
    def __init__(self, nombre):
        self.nombre = nombre
        self.cartas = []
        self.puntos = 0

    def recibir_cartas(self, cartas):
        self.cartas = cartas

    def jugar_carta(self):
        if not self.cartas:
            raise ValueError(f"{self.nombre} no tiene cartas para jugar")
        carta_a_jugar = random.choice(self.cartas)
        self.cartas.remove(carta_a_jugar)
        return carta_a_jugar

    def ganar_puntos(self, puntos):
        self.puntos += puntos

    def __str__(self):
        return f"Jugador: {self.nombre}, Puntos: {self.puntos}"


class Partida:
    def __init__(self, jugador1, jugador2):
        self.jugador1 = jugador1
        self.jugador2 = jugador2
        self.mazo = Mazo()
        self.puntaje_maximo = 15

    def jugar_ronda(self):
        print(f"\n--- Ronda ---")
        
        carta1 = self.jugador1.jugar_carta()
        carta2 = self.jugador2.jugar_carta()

        print(f"{self.jugador1.nombre} juega: {carta1}")
        print(f"{self.jugador2.nombre} juega: {carta2}")

      
        if carta1.valor > carta2.valor:
            print(f"{self.jugador1.nombre} gana la ronda")
            self.jugador1.ganar_puntos(1)
        elif carta2.valor > carta1.valor:
            print(f"{self.jugador2.nombre} gana la ronda")
            self.jugador2.ganar_puntos(1)
        else:
            print("La ronda es un empate")

    def jugar(self):
        
        self.mazo.mezclar()

        while self.jugador1.puntos < self.puntaje_maximo and self.jugador2.puntos < self.puntaje_maximo:
         
            self.jugador1.recibir_cartas(self.mazo.repartir(3))
            self.jugador2.recibir_cartas(self.mazo.repartir(3))

            
            for _ in range(3):
                if self.jugador1.puntos >= self.puntaje_maximo or self.jugador2.puntos >= self.puntaje_maximo:
                    break
                self.jugar_ronda()

       
        if self.jugador1.puntos >= self.puntaje_maximo:
            print(f"\n{self.jugador1.nombre} ha ganado la partida con {self.jugador1.puntos} puntos.")
        elif self.jugador2.puntos >= self.puntaje_maximo:
            print(f"\n{self.jugador2.nombre} ha ganado la partida con {self.jugador2.puntos} puntos.")



p = Partida(Jugador("Juan"), Jugador("Pedro"))
p.jugar()
# Out:
# --- Ronda ---
# Juan juega: 3 de basto
# Pedro juega: 11 de espada
# Juan gana la ronda
#
# --- Ronda ---
# Juan juega: 6 de espada
# Pedro juega: 2 de basto
# Pedro gana la ronda
#
# --- Ronda ---
# Juan juega: 1 de oro
# Pedro juega: 3 de espada
# Pedro gana la ronda
#
# --- Ronda ---
# Juan juega: 6 de oro
# Pedro juega: 8 de oro
# Juan gana la ronda
#
# --- Ronda ---
# Juan juega: 10 de basto
# Pedro juega: 12 de copa
# Pedro gana la ronda
#
# --- Ronda ---
# Juan juega: 4 de basto
# Pedro juega: 5 de basto
# Pedro gana la ronda
#
# --- Ronda ---
# Juan juega: 2 de copa
# Pedro juega: 5 de copa
# Juan gana la ronda
#
# --- Ronda ---
# Juan juega: 8 de espada
# Pedro juega: 11 de copa
# Pedro gana la ronda
#
# --- Ronda ---
# Juan juega: 6 de basto
# Pedro juega: 7 de copa
# Pedro gana la ronda
#
# --- Ronda ---
# Juan juega: 4 de oro
# Pedro juega: 3 de oro
# Pedro gana la ronda
#
# --- Ronda ---
# Juan juega: 7 de espada
# Pedro juega: 7 de basto
# Juan gana la ronda
#
# --- Ronda ---
# Juan juega: 11 de basto
# Pedro juega: 3 de copa
# Pedro gana la ronda
#
# --- Ronda ---
# Juan juega: 7 de oro
# Pedro juega: 9 de oro
# Juan gana la ronda
#
# --- Ronda ---
# Juan juega: 12 de basto
# Pedro juega: 9 de basto
# Juan gana la ronda
#
# --- Ronda ---
# Juan juega: 12 de oro
# Pedro juega: 8 de copa
# Juan gana la ronda
#
# --- Ronda ---
# Juan juega: 10 de espada
# Pedro juega: 1 de copa
# Pedro gana la ronda
#
# --- Ronda ---
# Juan juega: 9 de copa
# Pedro juega: 11 de oro
# Pedro gana la ronda
#
# --- Ronda ---
# Juan juega: 4 de espada
# Pedro juega: 2 de oro
# Pedro gana la ronda
#
# --- Ronda ---
# Juan juega: 1 de espada
# Pedro juega: 10 de copa
# Juan gana la ronda
#
# --- Ronda ---
# Juan juega: 1 de basto
# Pedro juega: 9 de espada
# Juan gana la ronda
#
# --- Ronda ---
# Juan juega: 5 de oro
# Pedro juega: 12 de espada
# Pedro gana la ronda
#
# --- Ronda ---
# Juan juega: 4 de copa
# Pedro juega: 6 de copa
# Pedro gana la ronda
#
# --- Ronda ---
# Juan juega: 2 de espada
# Pedro juega: 5 de espada
# Juan gana la ronda
#
# --- Ronda ---
# Juan juega: 10 de oro
# Pedro juega: 8 de basto
# Juan gana la ronda
# No hay suficientes cartas. Volviendo a mezclar el mazo.
#
# --- Ronda ---
# Juan juega: 11 de oro
# Pedro juega: 8 de basto
# Juan gana la ronda
#
# --- Ronda ---
# Juan juega: 2 de basto
# Pedro juega: 1 de espada
# Pedro gana la ronda
#
# --- Ronda ---
# Juan juega: 6 de copa
# Pedro juega: 7 de copa
# Pedro gana la ronda
#
# Pedro ha ganado la partida con 15 puntos.
