# %% [markdown]
# # Trabajo práctico 1

# %% [markdown]
# ## Ejercicio 1
#
# Escribe una función en Python que procese una lista de cadenas de texto y realice las siguientes acciones:
#
# 1. Tomar una lista de frases y convertir cada frase en una lista de palabras.
# 1. Luego, debe crear una nueva lista que contenga la cantidad de palabras en cada frase.
# 1. Tambien debe crear un lista que contenga la cantidad de caracteres en cada frase.
# 1. Finalmente, debe imprimir cada frase original junto con la cantidad de palabras que contiene.
# Ejemplo de uso:
# ```python
#     frases = [
#         "Python es un lenguaje de programación",
#         "Me gusta resolver problemas con código",
#         "Las listas y los bucles son muy útiles"
#     ]
#
#     procesar_frases(frases)
# ```
#
# ejemplo de salida:
# ```bash
#     La frase: "Python es un..."
#     tiene 6 palabras y 38 caracteres
# ```

# %%
frases = [
        "Python es un lenguaje de programación",
        "Me gusta resolver problemas con código",
        "Las listas y los bucles son muy útiles"
    ]

def procesar(frases):
    
    cantidad_de_palabras = []
    cantidad_de_caracteres = []
  
    for i in frases:
        
        palabras = i.split()
   
        npalabras = len(palabras)
        ncaracteres = len(i)
        
        cantidad_de_palabras.append(npalabras)
        cantidad_de_caracteres.append(ncaracteres)

        print(f'"{i}" tiene {npalabras} palabras y {ncaracteres} caracteres.')

print(procesar(frases))
# Out:
# "Python es un lenguaje de programación" tiene 6 palabras y 37 caracteres.
# "Me gusta resolver problemas con código" tiene 6 palabras y 38 caracteres.
# "Las listas y los bucles son muy útiles" tiene 8 palabras y 38 caracteres.
# None

# %% [markdown]
# ## Ejercicio 2
#
# Escribe una función en Python que encuentre los valores de `a`, `b`, y `c` para que la función cuadrática `f(x) = aX^2 + bX + c` pase exactamente por los siguientes puntos:
#
# | x  | y  |
# |---:|---:|
# |  0 |  0 |
# |  1 |  8 |
# |  2 | 12 |
# |  3 | 12 |
# |  5 |  0 |
#
# ### Requisitos:
# - La función debe explorar posibles valores de `a`, `b`, y `c` utilizando un método de prueba y error.
# - Debe devolver los valores que hagan que la diferencia entre la función `f(x)` y los valores medidos `y` sea exactamente cero para cada punto.
#
# > **Pista**: Los valores de `a`, `b`, y `c` son números pequeños.

# %%
def funcion_cuadratica(a, b, c, x):
    return a * x**2 + b * x + c

def prueba():
    puntos = [(0, 0), (1, 8), (2, 12), (3, 12), (5, 0)]

    for a in range(-10, 11):
        for b in range(-10, 11):
            for c in range(-10, 11):
                error_total = 0
                for (x, y) in puntos:
                    y_calculado = funcion_cuadratica(a, b, c, x)
                    error_total += abs(y_calculado - y)

                if error_total == 0:
                    return a, b, c

    return None
coeficiente = prueba()
if coeficiente:
    a, b, c = coeficiente
    print(f"Los valores encontrados son: a = {a}, b = {b}, c = {c}")
else:
    print("No se encontraron valores.")
# Out:
# Los valores encontrados son: a = -2, b = 10, c = 0
