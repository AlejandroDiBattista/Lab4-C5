# %% [markdown]
# # TP6
#
# ### `Resolver usando Pandas`
#
# Resolver los ejercicios del TP3 utilizando la librería Pandas.

# %% [markdown]
# ### Ejercicio 1: Cargar Datos de ventas.
#
# El archivo datos.dat contiene el registro de las ventas realizadas.
#
# Tiene un formato de ancho fijo:
# - `fecha`:    10 lugares
# - `producto`: 30 lugares
# - `precio`:   10 lugares
# - `cantidad`:  5 lugares
#
# Hacer una funcion que cargue los datos en un DataFrame de Pandas.

# %%
import pandas as pd
def cargar_datos():
    ancho_fijo = [10, 30, 10, 5]
    df = pd.read_fwf('datos.dat', widths=ancho_fijo, names=['fecha', 'producto', 'precio', 'cantidad'])
    return df

datos = cargar_datos()
datos
# Out:
#          fecha    producto  precio  cantidad
# 0   2024-08-27     Mirinda    1510        14
# 1   2024-08-27     Mirinda    1560        12
# 2   2024-08-28     Torasso     940         8
# 3   2024-08-29  Pepsi Cola    1210        10
# 4   2024-08-30     Mirinda    1520         1
# 5   2024-09-01     Mirinda    1550        15
# 6   2024-09-01      Sprite     810         4
# 7   2024-09-02   Coca Cola    1100         4
# 8   2024-09-02  Pepsi Cola    1220        13
# 9   2024-09-02     Torasso     910         5
# 10  2024-09-02     Torasso     920         3
# 11  2024-09-03   Coca Cola    1020         8
# 12  2024-09-03     Mirinda    1570         7
# 13  2024-09-03     Mirinda    1590         2
# 14  2024-09-04  Pepsi Cola    1220        13
# 15  2024-09-05     Mirinda    1500         3
# 16  2024-09-05  Pepsi Cola    1300         5
# 17  2024-09-06   Coca Cola    1080         1
# 18  2024-09-06      Sprite     860        12
# 19  2024-09-06     Torasso     930         3
# 20  2024-09-07   Coca Cola    1080        14
# 21  2024-09-07      Sprite     870        13
# 22  2024-09-08   Coca Cola    1040        10
# 23  2024-09-08     Mirinda    1580         2
# 24  2024-09-08  Pepsi Cola    1240         9
# 25  2024-09-09     Mirinda    1500         3
# 26  2024-09-09      Sprite     850         9
# 27  2024-09-10     Mirinda    1590         8
# 28  2024-09-10  Pepsi Cola    1250        12
# 29  2024-09-11      Sprite     810         6
# 30  2024-09-11      Sprite     820        14
# 31  2024-09-12   Coca Cola    1080         4
# 32  2024-09-13     Mirinda    1580         5
# 33  2024-09-13  Pepsi Cola    1250        13
# 34  2024-09-14   Coca Cola    1080        15
# 35  2024-09-14  Pepsi Cola    1270        14
# 36  2024-09-15   Coca Cola    1100         1
# 37  2024-09-15     Mirinda    1500        13
# 38  2024-09-15      Sprite     870        14
# 39  2024-09-15     Torasso     900        13

# %% [markdown]
# ### Ejercicio 2: Calcular el total de ventas.
# Hacer una función que sume los importes vendidos (precio * cantidad) y las cantidades.

# %%
def calcular_totales(datos):
    cantidad = sum(datos['cantidad'])
    precio = sum(datos['precio'])
    importe = precio * cantidad
    return importe, cantidad

importe, cantidad = calcular_totales(datos)

print(f"Las ventas fueron de ${importe:.2f} en {cantidad} unidades")
# Out:
# Las ventas fueron de $15939300.00 en 335 unidades

# %% [markdown]
# ### Ejercicio 3: Listar las unidades vendidas.
# Listar cuántas unidades se vendieron en total para cada producto

# %%
def unidades_vendidas(datos):
    productos = datos.groupby('producto').sum()
    productos = productos.reset_index()
    return productos[['producto', 'cantidad']]

unidades_vendidas(datos)
# Out:
#      producto  cantidad
# 0   Coca Cola        57
# 1     Mirinda        85
# 2  Pepsi Cola        89
# 3      Sprite        72
# 4     Torasso        32

# %% [markdown]
# ###  Ejercicio 4: Listar el precio promedio por producto.
# Hacer un listado del precio promedio por producto.

# %%
def precio_promedio(datos):
    productos = datos.groupby('producto').sum()
    precio = datos.groupby('producto')['precio'].sum()
    total = productos['cantidad'] * precio
    promedio = total / productos['cantidad']
    df_resultado = pd.DataFrame({
        'producto': promedio.index,
         'promedio' : promedio.values
    })

    return df_resultado

precio_promedio(datos)
# Out:
#      producto  promedio
# 0   Coca Cola    8580.0
# 1     Mirinda   18550.0
# 2  Pepsi Cola    9960.0
# 3      Sprite    5890.0
# 4     Torasso    4600.0

# %% [markdown]
# ### Ejercicio 5: Ranking de productos
# Realizar un listado de los 3 productos más vendidos ordenados por la cantidad de unidades vendidas (ordenadas de mayor a menor)

# %%
def ranking_productos(datos, top=3):
    total = datos.groupby('producto')['cantidad'].sum().reset_index()
    return total.head(top).sort_values(ascending=False, by='cantidad')

ranking_productos(datos)
# Out:
#      producto  cantidad
# 2  Pepsi Cola        89
# 1     Mirinda        85
# 0   Coca Cola        57

# %% [markdown]
# ### Ejercicio 6: Listar las ventas por mes
# Realizar un listado del total de unidades vendidas por producto separado por mes.

# %%
def ventas_por_mes(datos):
    datos['fecha'] = pd.to_datetime(datos['fecha'])
    datos['mes'] = datos['fecha'].dt.month
    mes = datos.groupby('mes')['cantidad'].sum().reset_index()
    return mes

ventas_por_mes(datos)
# Out:
#    mes  cantidad
# 0    8        45
# 1    9       290

# %% [markdown]
# ### Ejercicio 7: Informe general
#
# Mostrar un listado de productos ordenados alfabeticamente que contengan el precio promedio, la cantidad de unidades vendidas y el importe total vendido para cada producto

# %%
def resumen_ventas(datos):
    productos = datos.groupby('producto')[['cantidad']].sum()
    precio = datos.groupby('producto')['precio'].sum()
    total = productos['cantidad'] * precio
    promedio = total / productos['cantidad']
    listado = pd.DataFrame({
        'producto': promedio.index,
        'cantidad': productos['cantidad'],
        'total': total,
        'promedio': promedio.values
    }).reset_index(drop=True)
    return listado.sort_values(by='producto')

resumen_ventas(datos)
# Out:
#      producto  cantidad    total  promedio
# 0   Coca Cola        57   489060    8580.0
# 1     Mirinda        85  1576750   18550.0
# 2  Pepsi Cola        89   886440    9960.0
# 3      Sprite        72   424080    5890.0
# 4     Torasso        32   147200    4600.0

# %% [markdown]
# ## `Resolver usando NumPy`
# ## Resolver el ejercicio 2 del tp1 usando NumPy

# %% [markdown]
# ### Ejercicio 8
#
# Escribe una función en Python que encuentre los valores de `a`, `b`, y `c` para que la función cuadrática `f(x) = a x^2 + b x + c` pase exactamente por los siguientes puntos:
#
# | x  | y  |
# |---:|---:|
# |  0 |  0 |
# |  1 |  8 |
# |  2 | 12 |
# |  3 | 12 |
# |  5 |  0 |
#
# ### Requisitos:
# - La función debe explorar posibles valores de `a`, `b`, y `c` utilizando un método de prueba y error.
# - Debe devolver los valores que hagan que la diferencia entre la función `f(x)` y los valores medidos `y` sea exactamente cero para cada punto.
#
# > **Pista**: Los valores de `a`, `b`, y `c` son números pequeños.
#
# La idea es implementar el mismo algoritmo que se uso en el TP1 pero usando NumPy en lugar de Python puro.

# %%
import numpy as np
def f(x, coeficientes):
    a,b,c = coeficientes
    return a*x**2 + b*x + c

def error(y, y_pred):
    return y - y_pred

X = np.array([0,1,2,3,5])
Y = np.array([0,8,12,12,0])

def buscar_coeficientes():
   for a in range(-10, 11):  
        for b in range(-10, 11):  
            for c in range(-10, 11): 
                coeficientes = (a, b, c) 
                Y_pred = f(X, coeficientes)  
                if np.array_equal(Y_pred, Y):  
                    return a, b, c  
   return None  

coeficientes = buscar_coeficientes()
coeficientes
# Out:
# (-2, 10, 0)

# %% [markdown]
# ### Ejercicio 9: Resolver el ejercicio 3 del TP1 usando NumPy
# Buscar los coeficientes de la función que minimice la suma de los cuadrados de las diferencias entre los valores medidos y los valores de la función.
#
# 1. Crear un array con los coeficientes elegidos al azar (usar `randint(-10,10,3)`).
# 2. Calcular el valor de la función y el error correspondiente.
# 3. Mientras que el error sea mayor a 1:
#     1. Definir nuevos coeficientes agregándoles un pequeño valor al azar a los coeficientes actuales (aprendizaje = 0.001).
#     2. Si el error para los nuevos coeficientes es menor que el anterior, reemplazar los coeficientes actuales por los nuevos.

# %%
import numpy as np
from numpy.random import randint

def f(x, coeficientes):
    a,b,c = coeficientes
    return a*x**2 + b*x + c

def error(y, y_pred):
    return np.sum((y - y_pred)**2)

X = np.array([0, 1, 2, 3, 5])
Y = np.array([0, 8,12,11, 1]) # Observar que no son los mismos valores que en el ejemplo anterior

def buscar_coeficientes():
    coeficientes = randint(-10, 10, 3)  
    Y_pred = f(X, coeficientes)
    error_actual = error(Y, Y_pred)
    
    aprendizaje = 0.001 

    while error_actual > 1:  
        nuevos_coeficientes = coeficientes + randint(-10, 10, 3) * aprendizaje
        Y_pred = f(X, nuevos_coeficientes)
        nuevo_error = error(Y, Y_pred)
        if nuevo_error < error_actual:
            coeficientes = nuevos_coeficientes
            error_actual = nuevo_error
            print(f"Coeficientes actuales: {coeficientes}, Error actual: {error_actual}")

    return coeficientes


coeficientes = buscar_coeficientes()
coeficientes
# Out:
# Coeficientes actuales: [ 6.995 -5.008  8.006], Error actual: 26881.662235000003
# Coeficientes actuales: [ 6.992 -5.011  8.003], Error actual: 26848.324773999997
# Coeficientes actuales: [ 6.986 -5.014  8.007], Error actual: 26791.902909000004
# Coeficientes actuales: [ 6.985 -5.014  8.005], Error actual: 26782.250674000003
# Coeficientes actuales: [ 6.979 -5.005  8.008], Error actual: 26748.159963999988
# Coeficientes actuales: [ 6.97  -4.999  8.009], Error actual: 26681.308621999986
# Coeficientes actuales: [ 6.963 -5.006  8.014], Error actual: 26609.237403
# Coeficientes actuales: [ 6.954 -5.007  8.012], Error actual: 26528.01927899999
# Coeficientes actuales: [ 6.953 -5.017  8.011], Error actual: 26500.021820999984
# Coeficientes actuales: [ 6.948 -5.021  8.002], Error actual: 26444.96679899999
# Coeficientes actuales: [ 6.942 -5.03   8.006], Error actual: 26377.700627999984
# Coeficientes actuales: [ 6.932 -5.026  7.999], Error actual: 26295.32469299998
# Coeficientes actuales: [ 6.928 -5.032  7.996], Error actual: 26248.075216
# Coeficientes actuales: [ 6.919 -5.026  8.004], Error actual: 26184.972618999986
# Coeficientes actuales: [ 6.909 -5.026  7.994], Error actual: 26094.09357899999
# Coeficientes actuales: [ 6.901 -5.029  7.984], Error actual: 26015.02242399999
# Coeficientes actuales: [ 6.894 -5.027  7.993], Error actual: 25962.415901999997
# Coeficientes actuales: [ 6.888 -5.029  7.985], Error actual: 25903.497701999986
# Coeficientes actuales: [ 6.878 -5.032  7.978], Error actual: 25808.869416
# Coeficientes actuales: [ 6.872 -5.026  7.987], Error actual: 25772.477684999994
# Coeficientes actuales: [ 6.865 -5.018  7.991], Error actual: 25729.042509999985
# Coeficientes actuales: [ 6.856 -5.017  7.989], Error actual: 25652.90392599999
# Coeficientes actuales: [ 6.856 -5.02   7.998], Error actual: 25651.31045199999
# Coeficientes actuales: [ 6.849 -5.017  8.002], Error actual: 25598.726683999997
# Coeficientes actuales: [ 6.843 -5.023  8.006], Error actual: 25538.10826799999
# Coeficientes actuales: [ 6.841 -5.032  7.996], Error actual: 25500.016938999994
# Coeficientes actuales: [ 6.835 -5.031  7.995], Error actual: 25450.23606899999
# Coeficientes actuales: [ 6.825 -5.027  8.002], Error actual: 25375.467287999996
# Coeficientes actuales: [ 6.82  -5.029  7.996], Error actual: 25326.609630999992
# Coeficientes actuales: [ 6.815 -5.036  8.005], Error actual: 25275.163753999997
# Coeficientes actuales: [ 6.807 -5.035  8.002], Error actual: 25207.758284000003
# Coeficientes actuales: [ 6.807 -5.04   8.002], Error actual: 25198.583419000002
# Coeficientes actuales: [ 6.805 -5.04   8.007], Error actual: 25183.797690000007
# Coeficientes actuales: [ 6.801 -5.031  8.002], Error actual: 25164.203032000005
# Coeficientes actuales: [ 6.792 -5.024  8.003], Error actual: 25101.20754899999
# Coeficientes actuales: [ 6.782 -5.016  8.003], Error actual: 25031.228949000004
# Coeficientes actuales: [ 6.782 -5.021  8.011], Error actual: 25025.563646000006
# Coeficientes actuales: [ 6.774 -5.015  8.019], Error actual: 24972.400906000003
# Coeficientes actuales: [ 6.774 -5.017  8.013], Error actual: 24966.143161999997
# Coeficientes actuales: [ 6.775 -5.025  8.004], Error actual: 24956.07318
# Coeficientes actuales: [ 6.772 -5.032  8.011], Error actual: 24921.014917
# Coeficientes actuales: [ 6.769 -5.031  8.013], Error actual: 24898.401069
# Coeficientes actuales: [ 6.759 -5.023  8.017], Error actual: 24830.43931700001
# Coeficientes actuales: [ 6.758 -5.018  8.008], Error actual: 24827.227184
# Coeficientes actuales: [ 6.752 -5.011  8.007], Error actual: 24789.029670000004
# Coeficientes actuales: [ 6.752 -5.01   7.997], Error actual: 24786.524588999993
# Coeficientes actuales: [ 6.743 -5.017  8.006], Error actual: 24702.029176000004
# Coeficientes actuales: [ 6.734 -5.01   8.012], Error actual: 24641.774111999996
# Coeficientes actuales: [ 6.724 -5.008  8.015], Error actual: 24562.868284999997
# Coeficientes actuales: [ 6.717 -5.006  8.011], Error actual: 24506.172845999994
# Coeficientes actuales: [ 6.714 -5.014  8.007], Error actual: 24464.905373
# Coeficientes actuales: [ 6.714 -5.016  8.015], Error actual: 24464.727188999997
# Coeficientes actuales: [ 6.711 -5.017  8.006], Error actual: 24433.989623999998
# Coeficientes actuales: [ 6.707 -5.016  8.   ], Error actual: 24399.820346999997
# Coeficientes actuales: [ 6.706 -5.014  7.993], Error actual: 24392.081148999994
# Coeficientes actuales: [ 6.702 -5.012  8.001], Error actual: 24365.742877000004
# Coeficientes actuales: [ 6.698 -5.013  8.008], Error actual: 24333.58483900001
# Coeficientes actuales: [ 6.699 -5.022  8.013], Error actual: 24327.845022000012
# Coeficientes actuales: [ 6.694 -5.022  8.009], Error actual: 24284.478645000007
# Coeficientes actuales: [ 6.684 -5.017  8.01 ], Error actual: 24210.691223
# Coeficientes actuales: [ 6.677 -5.012  8.   ], Error actual: 24157.235555000014
# Coeficientes actuales: [ 6.671 -5.014  7.999], Error actual: 24103.41899400001
# Coeficientes actuales: [ 6.661 -5.02   7.996], Error actual: 24008.522251000013
# Coeficientes actuales: [ 6.656 -5.018  7.989], Error actual: 23967.74750100001
# Coeficientes actuales: [ 6.653 -5.022  7.991], Error actual: 23936.641086000014
# Coeficientes actuales: [ 6.65  -5.014  7.987], Error actual: 23924.43669300001
# Coeficientes actuales: [ 6.648 -5.017  7.987], Error actual: 23902.555346000012
# Coeficientes actuales: [ 6.638 -5.014  7.978], Error actual: 23821.55874000002
# Coeficientes actuales: [ 6.636 -5.01   7.982], Error actual: 23813.887224000006
# Coeficientes actuales: [ 6.626 -5.019  7.976], Error actual: 23712.973599000023
# Coeficientes actuales: [ 6.624 -5.019  7.979], Error actual: 23697.788166000013
# Coeficientes actuales: [ 6.616 -5.012  7.974], Error actual: 23642.353076000014
# Coeficientes actuales: [ 6.615 -5.009  7.967], Error actual: 23636.51253300001
# Coeficientes actuales: [ 6.609 -5.002  7.957], Error actual: 23595.455474000006
# Coeficientes actuales: [ 6.604 -5.009  7.96 ], Error actual: 23543.304175000023
# Coeficientes actuales: [ 6.595 -5.018  7.968], Error actual: 23457.034763000007
# Coeficientes actuales: [ 6.588 -5.019  7.962], Error actual: 23395.515879000013
# Coeficientes actuales: [ 6.581 -5.024  7.97 ], Error actual: 23332.88789900002
# Coeficientes actuales: [ 6.579 -5.032  7.967], Error actual: 23301.223494000013
# Coeficientes actuales: [ 6.572 -5.025  7.976], Error actual: 23260.25310300002
# Coeficientes actuales: [ 6.57  -5.03   7.979], Error actual: 23236.42000500002
# Coeficientes actuales: [ 6.562 -5.027  7.978], Error actual: 23176.174711000025
# Coeficientes actuales: [ 6.56  -5.03   7.968], Error actual: 23150.47878000002
# Coeficientes actuales: [ 6.56  -5.038  7.965], Error actual: 23135.18954100003
# Coeficientes actuales: [ 6.558 -5.03   7.966], Error actual: 23133.393396000025
# Coeficientes actuales: [ 6.553 -5.023  7.975], Error actual: 23108.808445000017
# Coeficientes actuales: [ 6.549 -5.018  7.973], Error actual: 23084.26969800003
# Coeficientes actuales: [ 6.543 -5.028  7.979], Error actual: 23020.588422000023
# Coeficientes actuales: [ 6.535 -5.038  7.988], Error actual: 22942.058723000027
# Coeficientes actuales: [ 6.533 -5.04   7.994], Error actual: 22924.875723000037
# Coeficientes actuales: [ 6.532 -5.043  7.999], Error actual: 22913.623846000028
# Coeficientes actuales: [ 6.525 -5.038  7.998], Error actual: 22865.367083000026
# Coeficientes actuales: [ 6.516 -5.029  7.998], Error actual: 22808.408279000025
# Coeficientes actuales: [ 6.507 -5.028  8.003], Error actual: 22739.670726000022
# Coeficientes actuales: [ 6.5   -5.023  8.004], Error actual: 22692.42368700002
# Coeficientes actuales: [ 6.501 -5.029  7.996], Error actual: 22686.746504000028
# Coeficientes actuales: [ 6.501 -5.035  7.991], Error actual: 22674.26486100002
# Coeficientes actuales: [ 6.492 -5.029  7.992], Error actual: 22612.755191000022
# Coeficientes actuales: [ 6.488 -5.034  7.992], Error actual: 22571.978364000024
# Coeficientes actuales: [ 6.486 -5.03   7.998], Error actual: 22565.327572000024
# Coeficientes actuales: [ 6.478 -5.023  7.989], Error actual: 22509.602542000033
# Coeficientes actuales: [ 6.471 -5.022  7.994], Error actual: 22457.326011000034
# Coeficientes actuales: [ 6.463 -5.027  7.995], Error actual: 22385.128421000038
# Coeficientes actuales: [ 6.46  -5.029  7.99 ], Error actual: 22355.670199000033
# Coeficientes actuales: [ 6.46  -5.036  7.993], Error actual: 22344.83365300003
# Coeficientes actuales: [ 6.453 -5.03   7.996], Error actual: 22300.540611000044
# Coeficientes actuales: [ 6.447 -5.025  7.999], Error actual: 22262.539621000036
# Coeficientes actuales: [ 6.447 -5.027  8.003], Error actual: 22260.732981000037
# Coeficientes actuales: [ 6.447 -5.034  7.994], Error actual: 22245.022707000044
# Coeficientes actuales: [ 6.446 -5.044  7.984], Error actual: 22215.797004000033
# Coeficientes actuales: [ 6.437 -5.048  7.974], Error actual: 22133.292771000033
# Coeficientes actuales: [ 6.428 -5.058  7.978], Error actual: 22046.363944000026
# Coeficientes actuales: [ 6.422 -5.061  7.97 ], Error actual: 21990.45020700002
# Coeficientes actuales: [ 6.414 -5.058  7.97 ], Error actual: 21932.268660000027
# Coeficientes actuales: [ 6.407 -5.063  7.972], Error actual: 21869.240456000032
# Coeficientes actuales: [ 6.398 -5.07   7.965], Error actual: 21783.509757000025
# Coeficientes actuales: [ 6.393 -5.074  7.956], Error actual: 21733.71032300003
# Coeficientes actuales: [ 6.385 -5.066  7.96 ], Error actual: 21685.961419000036
# Coeficientes actuales: [ 6.379 -5.067  7.959], Error actual: 21636.717765000034
# Coeficientes actuales: [ 6.376 -5.058  7.965], Error actual: 21630.814173000024
# Coeficientes actuales: [ 6.367 -5.067  7.958], Error actual: 21542.18199600003
# Coeficientes actuales: [ 6.358 -5.07   7.964], Error actual: 21469.057008000018
# Coeficientes actuales: [ 6.348 -5.078  7.954], Error actual: 21373.447992000027
# Coeficientes actuales: [ 6.344 -5.088  7.956], Error actual: 21326.22561600002
# Coeficientes actuales: [ 6.34  -5.087  7.965], Error actual: 21300.318146000038
# Coeficientes actuales: [ 6.335 -5.09   7.973], Error actual: 21259.529870000024
# Coeficientes actuales: [ 6.326 -5.089  7.97 ], Error actual: 21190.022359000028
# Coeficientes actuales: [ 6.317 -5.091  7.979], Error actual: 21120.37077300002
# Coeficientes actuales: [ 6.314 -5.099  7.981], Error actual: 21084.52729400003
# Coeficientes actuales: [ 6.307 -5.096  7.973], Error actual: 21032.14959400002
# Coeficientes actuales: [ 6.308 -5.103  7.963], Error actual: 21024.255094000026
# Coeficientes actuales: [ 6.302 -5.096  7.962], Error actual: 20989.116840000024
# Coeficientes actuales: [ 6.295 -5.101  7.966], Error actual: 20928.27791200003
# Coeficientes actuales: [ 6.289 -5.11   7.969], Error actual: 20868.19822600003
# Coeficientes actuales: [ 6.279 -5.107  7.964], Error actual: 20794.180680000027
# Coeficientes actuales: [ 6.274 -5.112  7.963], Error actual: 20747.040877000025
# Coeficientes actuales: [ 6.272 -5.117  7.965], Error actual: 20724.174630000038
# Coeficientes actuales: [ 6.263 -5.118  7.969], Error actual: 20655.00062200002
# Coeficientes actuales: [ 6.261 -5.112  7.976], Error actual: 20652.31941900003
# Coeficientes actuales: [ 6.252 -5.108  7.981], Error actual: 20591.908221000027
# Coeficientes actuales: [ 6.248 -5.106  7.985], Error actual: 20566.148805000026
# Coeficientes actuales: [ 6.24  -5.101  7.992], Error actual: 20515.935695000026
# Coeficientes actuales: [ 6.239 -5.102  8.001], Error actual: 20510.15892600003
# Coeficientes actuales: [ 6.23  -5.096  7.996], Error actual: 20449.349132000032
# Coeficientes actuales: [ 6.23  -5.095  7.986], Error actual: 20447.096055000024
# Coeficientes actuales: [ 6.225 -5.089  7.983], Error actual: 20417.64912500003
# Coeficientes actuales: [ 6.221 -5.096  7.979], Error actual: 20374.112474000027
# Coeficientes actuales: [ 6.216 -5.088  7.988], Error actual: 20352.663504000026
# Coeficientes actuales: [ 6.212 -5.097  7.985], Error actual: 20306.30895000003
# Coeficientes actuales: [ 6.204 -5.095  7.989], Error actual: 20250.344546000037
# Coeficientes actuales: [ 6.197 -5.087  7.99 ], Error actual: 20210.685320000037
# Coeficientes actuales: [ 6.188 -5.096  7.988], Error actual: 20127.015776000033
# Coeficientes actuales: [ 6.19  -5.104  7.978], Error actual: 20125.246120000033
# Coeficientes actuales: [ 6.185 -5.095  7.982], Error actual: 20103.625000000036
# Coeficientes actuales: [ 6.182 -5.104  7.991], Error actual: 20069.750893000033
# Coeficientes actuales: [ 6.18  -5.106  7.983], Error actual: 20048.296053000035
# Coeficientes actuales: [ 6.177 -5.115  7.991], Error actual: 20014.085253000027
# Coeficientes actuales: [ 6.168 -5.125  7.998], Error actual: 19932.674639000026
# Coeficientes actuales: [ 6.163 -5.132  7.989], Error actual: 19880.23346600003
# Coeficientes actuales: [ 6.163 -5.133  7.988], Error actual: 19878.229884000033
# Coeficientes actuales: [ 6.161 -5.139  7.981], Error actual: 19850.791669000027
# Coeficientes actuales: [ 6.152 -5.149  7.971], Error actual: 19763.224818000035
# Coeficientes actuales: [ 6.144 -5.145  7.963], Error actual: 19706.670034000024
# Coeficientes actuales: [ 6.14  -5.138  7.964], Error actual: 19688.387132000036
# Coeficientes actuales: [ 6.133 -5.146  7.973], Error actual: 19626.58214600003
# Coeficientes actuales: [ 6.128 -5.137  7.981], Error actual: 19606.74840600003
# Coeficientes actuales: [ 6.126 -5.135  7.982], Error actual: 19595.408079000033
# Coeficientes actuales: [ 6.123 -5.144  7.978], Error actual: 19557.034755000033
# Coeficientes actuales: [ 6.114 -5.138  7.985], Error actual: 19502.232405000028
# Coeficientes actuales: [ 6.106 -5.148  7.988], Error actual: 19427.814924000035
# Coeficientes actuales: [ 6.096 -5.139  7.979], Error actual: 19364.51309400003
# Coeficientes actuales: [ 6.096 -5.148  7.981], Error actual: 19350.893845000042
# Coeficientes actuales: [ 6.092 -5.148  7.987], Error actual: 19323.49326100004
# Coeficientes actuales: [ 6.09  -5.151  7.986], Error actual: 19303.504767000042
# Coeficientes actuales: [ 6.086 -5.158  7.983], Error actual: 19261.590069000045
# Coeficientes actuales: [ 6.077 -5.167  7.976], Error actual: 19178.088652000035
# Coeficientes actuales: [ 6.069 -5.165  7.979], Error actual: 19123.34942100004
# Coeficientes actuales: [ 6.068 -5.163  7.973], Error actual: 19116.89555400003
# Coeficientes actuales: [ 6.062 -5.154  7.969], Error actual: 19085.443597000038
# Coeficientes actuales: [ 6.058 -5.148  7.966], Error actual: 19064.36504800004
# Coeficientes actuales: [ 6.051 -5.14   7.957], Error actual: 19022.144474000044
# Coeficientes actuales: [ 6.044 -5.137  7.954], Error actual: 18974.31205500004
# Coeficientes actuales: [ 6.038 -5.136  7.957], Error actual: 18932.961709000043
# Coeficientes actuales: [ 6.032 -5.141  7.961], Error actual: 18882.570086000036
# Coeficientes actuales: [ 6.032 -5.143  7.962], Error actual: 18879.79031100004
# Coeficientes actuales: [ 6.032 -5.146  7.96 ], Error actual: 18874.31593200004
# Coeficientes actuales: [ 6.026 -5.149  7.967], Error actual: 18828.26985400004
# Coeficientes actuales: [ 6.02  -5.153  7.972], Error actual: 18779.96531900004
# Coeficientes actuales: [ 6.012 -5.146  7.972], Error actual: 18732.538940000042
# Coeficientes actuales: [ 6.005 -5.14   7.962], Error actual: 18687.18451500004
# Coeficientes actuales: [ 5.998 -5.143  7.959], Error actual: 18630.38828200004
# Coeficientes actuales: [ 5.994 -5.136  7.952], Error actual: 18609.64772400004
# Coeficientes actuales: [ 5.991 -5.135  7.958], Error actual: 18591.61561200005
# Coeficientes actuales: [ 5.991 -5.136  7.961], Error actual: 18591.161706000046
# Coeficientes actuales: [ 5.986 -5.146  7.969], Error actual: 18542.167429000045
# Coeficientes actuales: [ 5.981 -5.147  7.959], Error actual: 18500.63486100005
# Coeficientes actuales: [ 5.974 -5.148  7.962], Error actual: 18449.45407200005
# Coeficientes actuales: [ 5.971 -5.154  7.969], Error actual: 18420.974974000048
# Coeficientes actuales: [ 5.961 -5.154  7.962], Error actual: 18346.116099000054
# Coeficientes actuales: [ 5.955 -5.152  7.963], Error actual: 18306.28405400005
# Coeficientes actuales: [ 5.952 -5.152  7.959], Error actual: 18283.185173000045
# Coeficientes actuales: [ 5.945 -5.151  7.951], Error actual: 18231.38151700005
# Coeficientes actuales: [ 5.938 -5.151  7.941], Error actual: 18177.377742000048
# Coeficientes actuales: [ 5.93  -5.156  7.935], Error actual: 18110.02914900005
# Coeficientes actuales: [ 5.928 -5.158  7.944], Error actual: 18095.88153200005
# Coeficientes actuales: [ 5.918 -5.153  7.95 ], Error actual: 18034.120815000053
# Coeficientes actuales: [ 5.912 -5.163  7.954], Error actual: 17977.287151000055
# Coeficientes actuales: [ 5.902 -5.17   7.951], Error actual: 17894.079133000054
# Coeficientes actuales: [ 5.896 -5.167  7.959], Error actual: 17858.81176600005
# Coeficientes actuales: [ 5.891 -5.166  7.962], Error actual: 17825.82998700005
# Coeficientes actuales: [ 5.888 -5.171  7.969], Error actual: 17799.376898000053
# Coeficientes actuales: [ 5.887 -5.174  7.974], Error actual: 17789.489987000044
# Coeficientes actuales: [ 5.879 -5.167  7.967], Error actual: 17740.81990900005
# Coeficientes actuales: [ 5.869 -5.166  7.963], Error actual: 17669.98833400005
# Coeficientes actuales: [ 5.868 -5.164  7.964], Error actual: 17666.308176000046
# Coeficientes actuales: [ 5.86  -5.169  7.973], Error actual: 17605.322070000053
# Coeficientes actuales: [ 5.855 -5.163  7.971], Error actual: 17578.37392500005
# Coeficientes actuales: [ 5.846 -5.155  7.97 ], Error actual: 17526.606943000046
# Coeficientes actuales: [ 5.839 -5.165  7.968], Error actual: 17461.41172400005
# Coeficientes actuales: [ 5.831 -5.159  7.963], Error actual: 17412.40202900005
# Coeficientes actuales: [ 5.823 -5.16   7.969], Error actual: 17356.826218000046
# Coeficientes actuales: [ 5.818 -5.154  7.978], Error actual: 17333.98786000005
# Coeficientes actuales: [ 5.816 -5.162  7.984], Error actual: 17310.04751600005
# Coeficientes actuales: [ 5.807 -5.169  7.976], Error actual: 17233.65298800005
# Coeficientes actuales: [ 5.797 -5.171  7.971], Error actual: 17159.010581000053
# Coeficientes actuales: [ 5.791 -5.166  7.977], Error actual: 17126.769102000053
# Coeficientes actuales: [ 5.787 -5.176  7.985], Error actual: 17086.761402000055
# Coeficientes actuales: [ 5.785 -5.171  7.994], Error actual: 17083.49077600005
# Coeficientes actuales: [ 5.781 -5.178  7.99 ], Error actual: 17043.78016300006
# Coeficientes actuales: [ 5.771 -5.181  7.984], Error actual: 16967.71788400006
# Coeficientes actuales: [ 5.766 -5.172  7.978], Error actual: 16944.325432000063
# Coeficientes actuales: [ 5.763 -5.176  7.972], Error actual: 16915.469459000058
# Coeficientes actuales: [ 5.753 -5.169  7.968], Error actual: 16855.245240000066
# Coeficientes actuales: [ 5.749 -5.17   7.968], Error actual: 16826.10985900007
# Coeficientes actuales: [ 5.745 -5.163  7.964], Error actual: 16807.456812000066
# Coeficientes actuales: [ 5.744 -5.166  7.956], Error actual: 16793.305884000067
# Coeficientes actuales: [ 5.737 -5.167  7.955], Error actual: 16743.19200500007
# Coeficientes actuales: [ 5.736 -5.174  7.95 ], Error actual: 16724.203864000065
# Coeficientes actuales: [ 5.736 -5.178  7.959], Error actual: 16721.43254100006
# Coeficientes actuales: [ 5.733 -5.182  7.951], Error actual: 16692.077726000065
# Coeficientes actuales: [ 5.728 -5.182  7.954], Error actual: 16658.733256000065
# Coeficientes actuales: [ 5.73  -5.192  7.953], Error actual: 16657.382269000063
# Coeficientes actuales: [ 5.729 -5.197  7.96 ], Error actual: 16645.57288800006
# Coeficientes actuales: [ 5.719 -5.199  7.956], Error actual: 16572.59786400006
# Coeficientes actuales: [ 5.716 -5.208  7.954], Error actual: 16538.114836000066
# Coeficientes actuales: [ 5.714 -5.206  7.957], Error actual: 16528.39782900007
# Coeficientes actuales: [ 5.708 -5.204  7.949], Error actual: 16487.507261000064
# Coeficientes actuales: [ 5.701 -5.196  7.948], Error actual: 16451.050123000063
# Coeficientes actuales: [ 5.699 -5.199  7.948], Error actual: 16432.99847200007
# Coeficientes actuales: [ 5.693 -5.191  7.952], Error actual: 16405.148524000062
# Coeficientes actuales: [ 5.684 -5.2    7.961], Error actual: 16333.780765000058
# Coeficientes actuales: [ 5.681 -5.204  7.961], Error actual: 16307.535734000063
# Coeficientes actuales: [ 5.673 -5.202  7.952], Error actual: 16253.001531000054
# Coeficientes actuales: [ 5.675 -5.21   7.946], Error actual: 16252.870235000059
# Coeficientes actuales: [ 5.675 -5.219  7.953], Error actual: 16242.17464500006
# Coeficientes actuales: [ 5.674 -5.214  7.943], Error actual: 16239.231597000053
# Coeficientes actuales: [ 5.665 -5.209  7.947], Error actual: 16186.85569300005
# Coeficientes actuales: [ 5.658 -5.206  7.939], Error actual: 16141.085813000056
# Coeficientes actuales: [ 5.648 -5.206  7.94 ], Error actual: 16073.855740000055
# Coeficientes actuales: [ 5.641 -5.213  7.944], Error actual: 16017.89093600006
# Coeficientes actuales: [ 5.636 -5.214  7.943], Error actual: 15982.436109000057
# Coeficientes actuales: [ 5.629 -5.219  7.944], Error actual: 15928.497116000064
# Coeficientes actuales: [ 5.621 -5.223  7.942], Error actual: 15868.366312000062
# Coeficientes actuales: [ 5.614 -5.217  7.933], Error actual: 15827.027482000067
# Coeficientes actuales: [ 5.608 -5.217  7.936], Error actual: 15787.887031000066
# Coeficientes actuales: [ 5.608 -5.219  7.943], Error actual: 15787.386310000065
# Coeficientes actuales: [ 5.607 -5.216  7.939], Error actual: 15783.646518000061
# Coeficientes actuales: [ 5.607 -5.225  7.947], Error actual: 15773.452909000065
# Coeficientes actuales: [ 5.598 -5.222  7.946], Error actual: 15717.297876000055
# Coeficientes actuales: [ 5.595 -5.213  7.952], Error actual: 15712.17356400006
# Coeficientes actuales: [ 5.596 -5.217  7.946], Error actual: 15711.102759000061
# Coeficientes actuales: [ 5.591 -5.208  7.942], Error actual: 15689.271187000064
# Coeficientes actuales: [ 5.585 -5.209  7.942], Error actual: 15647.867868000063
# Coeficientes actuales: [ 5.58  -5.213  7.943], Error actual: 15609.23137800006
# Coeficientes actuales: [ 5.576 -5.21   7.936], Error actual: 15584.565596000064
# Coeficientes actuales: [ 5.573 -5.209  7.934], Error actual: 15565.391116000064
# Coeficientes actuales: [ 5.563 -5.215  7.928], Error actual: 15488.539544000065
# Coeficientes actuales: [ 5.554 -5.225  7.935], Error actual: 15417.16743800006
# Coeficientes actuales: [ 5.544 -5.216  7.927], Error actual: 15361.21302900007
# Coeficientes actuales: [ 5.541 -5.208  7.936], Error actual: 15355.726315000067
# Coeficientes actuales: [ 5.532 -5.217  7.927], Error actual: 15280.763794000062
# Coeficientes actuales: [ 5.53  -5.212  7.931], Error actual: 15275.98075700006
# Coeficientes actuales: [ 5.52  -5.218  7.937], Error actual: 15203.84142900006
# Coeficientes actuales: [ 5.513 -5.22   7.942], Error actual: 15156.798595000068
# Coeficientes actuales: [ 5.505 -5.225  7.946], Error actual: 15098.761020000067
# Coeficientes actuales: [ 5.504 -5.222  7.948], Error actual: 15097.082972000064
# Coeficientes actuales: [ 5.498 -5.226  7.951], Error actual: 15053.282677000063
# Coeficientes actuales: [ 5.498 -5.235  7.95 ], Error actual: 15040.377807000064
# Coeficientes actuales: [ 5.496 -5.234  7.946], Error actual: 15027.411864000062
# Coeficientes actuales: [ 5.487 -5.229  7.936], Error actual: 14972.459788000066
# Coeficientes actuales: [ 5.479 -5.222  7.935], Error actual: 14929.84113800006
# Coeficientes actuales: [ 5.47  -5.223  7.942], Error actual: 14872.300399000058
# Coeficientes actuales: [ 5.469 -5.233  7.944], Error actual: 14852.58802400006
# Coeficientes actuales: [ 5.466 -5.232  7.95 ], Error actual: 14836.493160000055
# Coeficientes actuales: [ 5.458 -5.23   7.94 ], Error actual: 14784.213152000055
# Coeficientes actuales: [ 5.454 -5.226  7.931], Error actual: 14760.954789000058
# Coeficientes actuales: [ 5.447 -5.225  7.923], Error actual: 14714.533245000062
# Coeficientes actuales: [ 5.445 -5.22   7.919], Error actual: 14707.23321000006
# Coeficientes actuales: [ 5.439 -5.219  7.916], Error actual: 14668.962024000057
# Coeficientes actuales: [ 5.436 -5.229  7.923], Error actual: 14638.141794000063
# Coeficientes actuales: [ 5.437 -5.238  7.929], Error actual: 14634.130626000064
# Coeficientes actuales: [ 5.431 -5.244  7.922], Error actual: 14585.04321900006
# Coeficientes actuales: [ 5.431 -5.245  7.925], Error actual: 14584.639613000061
# Coeficientes actuales: [ 5.421 -5.252  7.915], Error actual: 14507.66841000006
# Coeficientes actuales: [ 5.413 -5.249  7.923], Error actual: 14463.152885000063
# Coeficientes actuales: [ 5.411 -5.247  7.914], Error actual: 14450.20407600006
# Coeficientes actuales: [ 5.405 -5.254  7.921], Error actual: 14404.571106000061
# Coeficientes actuales: [ 5.395 -5.255  7.921], Error actual: 14339.46500500006
# Coeficientes actuales: [ 5.393 -5.264  7.915], Error actual: 14312.568842000062
# Coeficientes actuales: [ 5.392 -5.269  7.923], Error actual: 14301.969874000062
# Coeficientes actuales: [ 5.389 -5.279  7.923], Error actual: 14269.319837000055
# Coeficientes actuales: [ 5.381 -5.281  7.924], Error actual: 14216.16938400006
# Coeficientes actuales: [ 5.38  -5.287  7.924], Error actual: 14201.70437500006
# Coeficientes actuales: [ 5.376 -5.286  7.927], Error actual: 14178.68331700006
# Coeficientes actuales: [ 5.369 -5.278  7.92 ], Error actual: 14142.993795000064
# Coeficientes actuales: [ 5.364 -5.28   7.914], Error actual: 14106.798996000063
# Coeficientes actuales: [ 5.354 -5.271  7.915], Error actual: 14056.172794000067
# Coeficientes actuales: [ 5.347 -5.264  7.911], Error actual: 14020.243718000069
# Coeficientes actuales: [ 5.344 -5.259  7.914], Error actual: 14009.039631000063
# Coeficientes actuales: [ 5.339 -5.257  7.917], Error actual: 13981.235229000065
# Coeficientes actuales: [ 5.336 -5.249  7.923], Error actual: 13975.023474000065
# Coeficientes actuales: [ 5.335 -5.259  7.915], Error actual: 13952.791909000067
# Coeficientes actuales: [ 5.336 -5.269  7.915], Error actual: 13945.653714000067
# Coeficientes actuales: [ 5.326 -5.266  7.92 ], Error actual: 13888.548400000067
# Coeficientes actuales: [ 5.321 -5.263  7.923], Error actual: 13862.203269000069
# Coeficientes actuales: [ 5.311 -5.257  7.919], Error actual: 13806.450581000066
# Coeficientes actuales: [ 5.307 -5.255  7.912], Error actual: 13781.955384000075
# Coeficientes actuales: [ 5.301 -5.246  7.917], Error actual: 13758.096802000076
# Coeficientes actuales: [ 5.296 -5.252  7.921], Error actual: 13720.217629000075
# Coeficientes actuales: [ 5.287 -5.261  7.927], Error actual: 13654.185085000066
# Coeficientes actuales: [ 5.277 -5.267  7.922], Error actual: 13582.671864000065
# Coeficientes actuales: [ 5.274 -5.27   7.915], Error actual: 13557.961893000072
# Coeficientes actuales: [ 5.266 -5.267  7.916], Error actual: 13512.781639000063
# Coeficientes actuales: [ 5.26  -5.275  7.92 ], Error actual: 13466.454775000066
# Coeficientes actuales: [ 5.258 -5.274  7.916], Error actual: 13454.206128000067
# Coeficientes actuales: [ 5.258 -5.279  7.919], Error actual: 13448.555306000068
# Coeficientes actuales: [ 5.254 -5.282  7.922], Error actual: 13420.90728400007
# Coeficientes actuales: [ 5.244 -5.291  7.921], Error actual: 13347.33323400007
# Coeficientes actuales: [ 5.235 -5.283  7.93 ], Error actual: 13305.385756000074
# Coeficientes actuales: [ 5.231 -5.282  7.92 ], Error actual: 13279.124595000074
# Coeficientes actuales: [ 5.228 -5.278  7.924], Error actual: 13267.218972000075
# Coeficientes actuales: [ 5.227 -5.282  7.917], Error actual: 13253.732174000066
# Coeficientes actuales: [ 5.224 -5.284  7.916], Error actual: 13232.478944000071
# Coeficientes actuales: [ 5.219 -5.289  7.921], Error actual: 13196.96542900007
# Coeficientes actuales: [ 5.212 -5.299  7.929], Error actual: 13143.736402000075
# Coeficientes actuales: [ 5.204 -5.298  7.933], Error actual: 13097.588293000072
# Coeficientes actuales: [ 5.203 -5.299  7.936], Error actual: 13091.128408000071
# Coeficientes actuales: [ 5.204 -5.303  7.932], Error actual: 13090.799847000071
# Coeficientes actuales: [ 5.195 -5.313  7.925], Error actual: 13021.11542100007
# Coeficientes actuales: [ 5.194 -5.318  7.915], Error actual: 13005.562405000072
# Coeficientes actuales: [ 5.184 -5.309  7.914], Error actual: 12956.37735100007
# Coeficientes actuales: [ 5.179 -5.311  7.921], Error actual: 12925.717069000071
# Coeficientes actuales: [ 5.169 -5.315  7.912], Error actual: 12857.574252000073
# Coeficientes actuales: [ 5.161 -5.312  7.905], Error actual: 12811.198790000075
# Coeficientes actuales: [ 5.151 -5.32   7.9  ], Error actual: 12739.459883000074
# Coeficientes actuales: [ 5.15  -5.328  7.907], Error actual: 12725.35110900007
# Coeficientes actuales: [ 5.14  -5.327  7.911], Error actual: 12668.01186200007
# Coeficientes actuales: [ 5.14  -5.336  7.903], Error actual: 12654.163693000075
# Coeficientes actuales: [ 5.142 -5.345  7.894], Error actual: 12651.964431000068
# Coeficientes actuales: [ 5.133 -5.338  7.901], Error actual: 12609.267618000065
# Coeficientes actuales: [ 5.131 -5.34   7.898], Error actual: 12593.91866700007
# Coeficientes actuales: [ 5.129 -5.349  7.907], Error actual: 12573.27045300007
# Coeficientes actuales: [ 5.12  -5.357  7.907], Error actual: 12509.650418000068
# Coeficientes actuales: [ 5.114 -5.356  7.911], Error actual: 12476.512029000067
# Coeficientes actuales: [ 5.111 -5.359  7.903], Error actual: 12452.584389000067
# Coeficientes actuales: [ 5.101 -5.358  7.903], Error actual: 12394.701694000072
# Coeficientes actuales: [ 5.099 -5.365  7.899], Error actual: 12372.90854100007
# Coeficientes actuales: [ 5.091 -5.356  7.9  ], Error actual: 12337.32975500007
# Coeficientes actuales: [ 5.082 -5.347  7.891], Error actual: 12292.98156200007
# Coeficientes actuales: [ 5.075 -5.341  7.883], Error actual: 12257.00041300007
# Coeficientes actuales: [ 5.065 -5.347  7.884], Error actual: 12191.144620000072
# Coeficientes actuales: [ 5.059 -5.347  7.888], Error actual: 12157.19471200007
# Coeficientes actuales: [ 5.051 -5.353  7.88 ], Error actual: 12100.66586800007
# Coeficientes actuales: [ 5.044 -5.348  7.882], Error actual: 12066.64037200007
# Coeficientes actuales: [ 5.04  -5.346  7.889], Error actual: 12047.857461000076
# Coeficientes actuales: [ 5.039 -5.346  7.881], Error actual: 12039.714174000075
# Coeficientes actuales: [ 5.031 -5.338  7.872], Error actual: 12000.488627000073
# Coeficientes actuales: [ 5.024 -5.342  7.872], Error actual: 11954.916444000073
# Coeficientes actuales: [ 5.018 -5.337  7.869], Error actual: 11925.44730600007
# Coeficientes actuales: [ 5.012 -5.342  7.876], Error actual: 11886.590012000072
# Coeficientes actuales: [ 5.005 -5.352  7.87 ], Error actual: 11832.152131000077
# Coeficientes actuales: [ 4.998 -5.359  7.87 ], Error actual: 11783.239967000074
# Coeficientes actuales: [ 4.995 -5.368  7.877], Error actual: 11756.975514000073
# Coeficientes actuales: [ 4.991 -5.371  7.876], Error actual: 11730.041736000077
# Coeficientes actuales: [ 4.983 -5.375  7.867], Error actual: 11676.712125000078
# Coeficientes actuales: [ 4.977 -5.378  7.862], Error actual: 11637.29681100007
# Coeficientes actuales: [ 4.978 -5.385  7.856], Error actual: 11632.796511000077
# Coeficientes actuales: [ 4.976 -5.392  7.847], Error actual: 11610.305653000076
# Coeficientes actuales: [ 4.974 -5.4    7.851], Error actual: 11590.313925000079
# Coeficientes actuales: [ 4.974 -5.407  7.841], Error actual: 11578.989006000078
# Coeficientes actuales: [ 4.97  -5.404  7.839], Error actual: 11559.256077000082
# Coeficientes actuales: [ 4.961 -5.409  7.846], Error actual: 11503.968604000082
# Coeficientes actuales: [ 4.963 -5.419  7.842], Error actual: 11502.12588400008
# Coeficientes actuales: [ 4.957 -5.41   7.832], Error actual: 11476.089539000077
# Coeficientes actuales: [ 4.95  -5.416  7.831], Error actual: 11428.882877000084
# Coeficientes actuales: [ 4.943 -5.412  7.84 ], Error actual: 11396.600491000083
# Coeficientes actuales: [ 4.944 -5.419  7.846], Error actual: 11395.528439000083
# Coeficientes actuales: [ 4.941 -5.422  7.847], Error actual: 11375.244798000082
# Coeficientes actuales: [ 4.938 -5.415  7.845], Error actual: 11366.137902000082
# Coeficientes actuales: [ 4.931 -5.413  7.839], Error actual: 11327.349381000085
# Coeficientes actuales: [ 4.922 -5.413  7.832], Error actual: 11274.70551100008
# Coeficientes actuales: [ 4.915 -5.422  7.829], Error actual: 11223.79859000008
# Coeficientes actuales: [ 4.916 -5.427  7.83 ], Error actual: 11223.729135000083
# Coeficientes actuales: [ 4.911 -5.425  7.829], Error actual: 11197.791045000084
# Coeficientes actuales: [ 4.907 -5.427  7.819], Error actual: 11170.228093000087
# Coeficientes actuales: [ 4.905 -5.423  7.824], Error actual: 11165.175772000086
# Coeficientes actuales: [ 4.897 -5.429  7.827], Error actual: 11114.164421000085
# Coeficientes actuales: [ 4.894 -5.431  7.827], Error actual: 11095.051594000088
# Coeficientes actuales: [ 4.892 -5.426  7.83 ], Error actual: 11090.647032000086
# Coeficientes actuales: [ 4.886 -5.434  7.839], Error actual: 11050.235709000088
# Coeficientes actuales: [ 4.883 -5.429  7.847], Error actual: 11041.654229000083
# Coeficientes actuales: [ 4.873 -5.431  7.856], Error actual: 10986.198812000084
# Coeficientes actuales: [ 4.869 -5.438  7.862], Error actual: 10957.420107000087
# Coeficientes actuales: [ 4.863 -5.439  7.864], Error actual: 10923.563416000088
# Coeficientes actuales: [ 4.856 -5.436  7.859], Error actual: 10887.009909000088
# Coeficientes actuales: [ 4.853 -5.435  7.854], Error actual: 10870.24720800009
# Coeficientes actuales: [ 4.844 -5.435  7.852], Error actual: 10820.080367000086
# Coeficientes actuales: [ 4.836 -5.44   7.856], Error actual: 10771.331376000087
# Coeficientes actuales: [ 4.83  -5.44   7.851], Error actual: 10737.035765000088
# Coeficientes actuales: [ 4.824 -5.444  7.848], Error actual: 10698.693232000087
# Coeficientes actuales: [ 4.821 -5.44   7.839], Error actual: 10684.480730000085
# Coeficientes actuales: [ 4.817 -5.443  7.831], Error actual: 10656.968661000086
# Coeficientes actuales: [ 4.817 -5.445  7.835], Error actual: 10655.732277000085
# Coeficientes actuales: [ 4.808 -5.441  7.842], Error actual: 10613.133759000082
# Coeficientes actuales: [ 4.799 -5.446  7.844], Error actual: 10558.89577900008
# Coeficientes actuales: [ 4.789 -5.438  7.844], Error actual: 10513.793539000078
# Coeficientes actuales: [ 4.79  -5.445  7.843], Error actual: 10510.898110000086
# Coeficientes actuales: [ 4.79  -5.452  7.847], Error actual: 10503.921013000085
# Coeficientes actuales: [ 4.785 -5.454  7.852], Error actual: 10475.867323000086
# Coeficientes actuales: [ 4.778 -5.448  7.856], Error actual: 10445.941068000087
# Coeficientes actuales: [ 4.774 -5.444  7.859], Error actual: 10429.705261000086
# Coeficientes actuales: [ 4.772 -5.449  7.867], Error actual: 10415.314146000092
# Coeficientes actuales: [ 4.763 -5.448  7.873], Error actual: 10369.518394000088
# Coeficientes actuales: [ 4.76  -5.453  7.876], Error actual: 10348.45773500009
# Coeficientes actuales: [ 4.753 -5.449  7.875], Error actual: 10315.111837000088
# Coeficientes actuales: [ 4.75  -5.448  7.874], Error actual: 10299.87319200009
# Coeficientes actuales: [ 4.748 -5.444  7.881], Error actual: 10295.54589300009
# Coeficientes actuales: [ 4.748 -5.444  7.877], Error actual: 10294.48442900009
# Coeficientes actuales: [ 4.746 -5.438  7.882], Error actual: 10291.902612000089
# Coeficientes actuales: [ 4.747 -5.448  7.877], Error actual: 10284.569946000092
# Coeficientes actuales: [ 4.741 -5.457  7.882], Error actual: 10243.521388000094
# Coeficientes actuales: [ 4.732 -5.464  7.88 ], Error actual: 10186.956080000089
# Coeficientes actuales: [ 4.723 -5.474  7.885], Error actual: 10129.013422000085
# Coeficientes actuales: [ 4.721 -5.465  7.879], Error actual: 10126.938725000087
# Coeficientes actuales: [ 4.715 -5.472  7.872], Error actual: 10085.32620300009
# Coeficientes actuales: [ 4.711 -5.467  7.875], Error actual: 10070.501365000091
# Coeficientes actuales: [ 4.71  -5.473  7.869], Error actual: 10056.886682000088
# Coeficientes actuales: [ 4.7   -5.464  7.864], Error actual: 10012.71211200009
# Coeficientes actuales: [ 4.695 -5.472  7.864], Error actual: 9977.332915000092
# Coeficientes actuales: [ 4.688 -5.475  7.863], Error actual: 9936.799014000091
# Coeficientes actuales: [ 4.68 -5.48  7.86], Error actual: 9888.350800000087
# Coeficientes actuales: [ 4.673 -5.484  7.862], Error actual: 9847.67241900009
# Coeficientes actuales: [ 4.67  -5.484  7.862], Error actual: 9831.945288000092
# Coeficientes actuales: [ 4.667 -5.487  7.852], Error actual: 9810.328744000093
# Coeficientes actuales: [ 4.661 -5.481  7.858], Error actual: 9787.130188000092
# Coeficientes actuales: [ 4.66  -5.478  7.855], Error actual: 9784.448461000087
# Coeficientes actuales: [ 4.652 -5.47   7.851], Error actual: 9750.479733000087
# Coeficientes actuales: [ 4.645 -5.474  7.851], Error actual: 9709.583966000091
# Coeficientes actuales: [ 4.639 -5.478  7.845], Error actual: 9672.43923000009
# Coeficientes actuales: [ 4.63  -5.479  7.842], Error actual: 9623.872663000086
# Coeficientes actuales: [ 4.622 -5.48   7.843], Error actual: 9581.620565000088
# Coeficientes actuales: [ 4.615 -5.471  7.844], Error actual: 9555.539176000088
# Coeficientes actuales: [ 4.609 -5.464  7.85 ], Error actual: 9533.738435000087
# Coeficientes actuales: [ 4.604 -5.461  7.84 ], Error actual: 9508.702119000089
# Coeficientes actuales: [ 4.604 -5.469  7.835], Error actual: 9498.726690000087
# Coeficientes actuales: [ 4.602 -5.474  7.828], Error actual: 9481.22750400009
# Coeficientes actuales: [ 4.603 -5.48   7.832], Error actual: 9480.858715000091
# Coeficientes actuales: [ 4.601 -5.485  7.825], Error actual: 9463.378653000094
# Coeficientes actuales: [ 4.595 -5.482  7.831], Error actual: 9437.34592200009
# Coeficientes actuales: [ 4.594 -5.479  7.838], Error actual: 9437.23384700009
# Coeficientes actuales: [ 4.589 -5.48   7.838], Error actual: 9410.518979000088
# Coeficientes actuales: [ 4.586 -5.478  7.831], Error actual: 9395.560765000086
# Coeficientes actuales: [ 4.58  -5.474  7.829], Error actual: 9368.694677000085
# Coeficientes actuales: [ 4.57  -5.468  7.831], Error actual: 9324.623005000089
# Coeficientes actuales: [ 4.562 -5.47   7.838], Error actual: 9283.482100000087
# Coeficientes actuales: [ 4.559 -5.474  7.844], Error actual: 9265.431611000087
# Coeficientes actuales: [ 4.549 -5.479  7.841], Error actual: 9208.591709000088
# Coeficientes actuales: [ 4.547 -5.48   7.848], Error actual: 9199.134795000087
# Coeficientes actuales: [ 4.537 -5.48   7.848], Error actual: 9148.58163500009
# Coeficientes actuales: [ 4.533 -5.485  7.844], Error actual: 9122.088168000091
# Coeficientes actuales: [ 4.528 -5.487  7.842], Error actual: 9094.285191000092
# Coeficientes actuales: [ 4.524 -5.478  7.836], Error actual: 9082.241436000095
# Coeficientes actuales: [ 4.518 -5.482  7.83 ], Error actual: 9046.377716000095
# Coeficientes actuales: [ 4.518 -5.489  7.837], Error actual: 9040.685274000098
# Coeficientes actuales: [ 4.509 -5.486  7.837], Error actual: 8998.760994000095
# Coeficientes actuales: [ 4.507 -5.494  7.838], Error actual: 8980.555739000092
# Coeficientes actuales: [ 4.504 -5.495  7.846], Error actual: 8966.468575000092
# Coeficientes actuales: [ 4.502 -5.503  7.846], Error actual: 8948.054031000094
# Coeficientes actuales: [ 4.498 -5.497  7.853], Error actual: 8936.128586000093
# Coeficientes actuales: [ 4.49  -5.504  7.854], Error actual: 8889.179112000096
# Coeficientes actuales: [ 4.488 -5.507  7.852], Error actual: 8875.603911000098
# Coeficientes actuales: [ 4.487 -5.513  7.846], Error actual: 8862.889976000097
# Coeficientes actuales: [ 4.485 -5.516  7.845], Error actual: 8849.579974000097
# Coeficientes actuales: [ 4.477 -5.51   7.85 ], Error actual: 8817.415027000096
# Coeficientes actuales: [ 4.471 -5.516  7.857], Error actual: 8783.169482000094
# Coeficientes actuales: [ 4.461 -5.52   7.861], Error actual: 8730.633046000095
# Coeficientes actuales: [ 4.457 -5.515  7.858], Error actual: 8715.405240000098
# Coeficientes actuales: [ 4.454 -5.511  7.85 ], Error actual: 8702.868519000098
# Coeficientes actuales: [ 4.452 -5.516  7.844], Error actual: 8686.411728000097
# Coeficientes actuales: [ 4.442 -5.524  7.852], Error actual: 8631.008076000096
# Coeficientes actuales: [ 4.434 -5.518  7.853], Error actual: 8598.297573000096
# Coeficientes actuales: [ 4.425 -5.515  7.85 ], Error actual: 8556.737400000095
# Coeficientes actuales: [ 4.416 -5.512  7.845], Error actual: 8514.806285000093
# Coeficientes actuales: [ 4.411 -5.507  7.852], Error actual: 8497.289128000097
# Coeficientes actuales: [ 4.408 -5.501  7.847], Error actual: 8487.673474000096
# Coeficientes actuales: [ 4.405 -5.502  7.853], Error actual: 8473.516194000094
# Coeficientes actuales: [ 4.398 -5.503  7.862], Error actual: 8440.707231000093
# Coeficientes actuales: [ 4.392 -5.506  7.854], Error actual: 8406.746888000092
# Coeficientes actuales: [ 4.387 -5.505  7.851], Error actual: 8382.921573000094
# Coeficientes actuales: [ 4.383 -5.497  7.852], Error actual: 8371.994876000095
# Coeficientes actuales: [ 4.38  -5.505  7.861], Error actual: 8351.544310000098
# Coeficientes actuales: [ 4.37  -5.498  7.867], Error actual: 8311.960349000097
# Coeficientes actuales: [ 4.362 -5.508  7.861], Error actual: 8262.102061000098
# Coeficientes actuales: [ 4.352 -5.505  7.865], Error actual: 8218.250262000094
# Coeficientes actuales: [ 4.349 -5.506  7.855], Error actual: 8200.604334000094
# Coeficientes actuales: [ 4.341 -5.506  7.864], Error actual: 8164.5918590000965
# Coeficientes actuales: [ 4.34  -5.513  7.872], Error actual: 8154.685119000093
# Coeficientes actuales: [ 4.334 -5.52   7.872], Error actual: 8119.195212000092
# Coeficientes actuales: [ 4.326 -5.529  7.874], Error actual: 8072.796999000093
# Coeficientes actuales: [ 4.319 -5.524  7.871], Error actual: 8044.001974000092
# Coeficientes actuales: [ 4.317 -5.521  7.869], Error actual: 8037.081413000093
# Coeficientes actuales: [ 4.319 -5.531  7.87 ], Error actual: 8036.822924000094
# Coeficientes actuales: [ 4.312 -5.533  7.868], Error actual: 8001.392471000095
# Coeficientes actuales: [ 4.302 -5.538  7.865], Error actual: 7948.7744610000955
# Coeficientes actuales: [ 4.303 -5.546  7.865], Error actual: 7945.575550000095
# Coeficientes actuales: [ 4.303 -5.55   7.871], Error actual: 7943.001426000099
# Coeficientes actuales: [ 4.293 -5.548  7.865], Error actual: 7896.784470000097
# Coeficientes actuales: [ 4.292 -5.544  7.866], Error actual: 7896.2678280000955
# Coeficientes actuales: [ 4.29  -5.538  7.872], Error actual: 7894.179744000097
# Coeficientes actuales: [ 4.281 -5.548  7.879], Error actual: 7843.964426000096
# Coeficientes actuales: [ 4.273 -5.553  7.879], Error actual: 7801.861717000096
# Coeficientes actuales: [ 4.272 -5.549  7.872], Error actual: 7799.539711000092
# Coeficientes actuales: [ 4.265 -5.546  7.867], Error actual: 7768.857950000098
# Coeficientes actuales: [ 4.262 -5.544  7.868], Error actual: 7757.130444000094
# Coeficientes actuales: [ 4.257 -5.545  7.862], Error actual: 7731.671964000092
# Coeficientes actuales: [ 4.256 -5.541  7.855], Error actual: 7729.360930000094
# Coeficientes actuales: [ 4.249 -5.546  7.859], Error actual: 7693.090654000092
# Coeficientes actuales: [ 4.248 -5.546  7.865], Error actual: 7689.823845000092
# Coeficientes actuales: [ 4.244 -5.551  7.86 ], Error actual: 7665.442599000094
# Coeficientes actuales: [ 4.242 -5.548  7.869], Error actual: 7661.149661000095
# Coeficientes actuales: [ 4.237 -5.558  7.867], Error actual: 7628.072686000099
# Coeficientes actuales: [ 4.237 -5.565  7.872], Error actual: 7622.441304000098
# Coeficientes actuales: [ 4.233 -5.575  7.863], Error actual: 7592.4804290000975
# Coeficientes actuales: [ 4.232 -5.585  7.865], Error actual: 7578.741302000096
# Coeficientes actuales: [ 4.226 -5.581  7.855], Error actual: 7552.938750000096
# Coeficientes actuales: [ 4.225 -5.583  7.862], Error actual: 7548.006504000094
# Coeficientes actuales: [ 4.224 -5.584  7.87 ], Error actual: 7544.255060000091
# Coeficientes actuales: [ 4.215 -5.587  7.874], Error actual: 7501.2583800000875
# Coeficientes actuales: [ 4.21  -5.588  7.866], Error actual: 7475.812040000091
# Coeficientes actuales: [ 4.202 -5.581  7.862], Error actual: 7445.298415000089
# Coeficientes actuales: [ 4.201 -5.582  7.854], Error actual: 7438.06093100009
# Coeficientes actuales: [ 4.192 -5.581  7.856], Error actual: 7398.735551000086
# Coeficientes actuales: [ 4.191 -5.578  7.854], Error actual: 7396.622891000084
# Coeficientes actuales: [ 4.186 -5.569  7.862], Error actual: 7384.319639000085
# Coeficientes actuales: [ 4.181 -5.576  7.863], Error actual: 7355.378778000088
# Coeficientes actuales: [ 4.173 -5.567  7.863], Error actual: 7327.875541000087
# Coeficientes actuales: [ 4.172 -5.562  7.856], Error actual: 7326.569532000083
# Coeficientes actuales: [ 4.164 -5.569  7.863], Error actual: 7285.601042000084
# Coeficientes actuales: [ 4.163 -5.567  7.866], Error actual: 7283.649516000084
# Coeficientes actuales: [ 4.161 -5.567  7.868], Error actual: 7275.1245720000825
# Coeficientes actuales: [ 4.157 -5.571  7.861], Error actual: 7251.9610210000865
# Coeficientes actuales: [ 4.156 -5.579  7.866], Error actual: 7241.081159000083
# Coeficientes actuales: [ 4.147 -5.586  7.857], Error actual: 7192.472190000082
# Coeficientes actuales: [ 4.146 -5.583  7.861], Error actual: 7191.679630000082
# Coeficientes actuales: [ 4.139 -5.574  7.851], Error actual: 7166.788674000082
# Coeficientes actuales: [ 4.138 -5.581  7.853], Error actual: 7156.265066000081
# Coeficientes actuales: [ 4.128 -5.574  7.846], Error actual: 7116.938968000084
# Coeficientes actuales: [ 4.122 -5.58   7.855], Error actual: 7086.777517000082
# Coeficientes actuales: [ 4.12  -5.58   7.852], Error actual: 7077.308320000083
# Coeficientes actuales: [ 4.116 -5.585  7.858], Error actual: 7056.330087000086
# Coeficientes actuales: [ 4.113 -5.58   7.856], Error actual: 7047.301611000082
# Coeficientes actuales: [ 4.103 -5.585  7.85 ], Error actual: 6997.476872000081
# Coeficientes actuales: [ 4.098 -5.591  7.842], Error actual: 6968.373439000085
# Coeficientes actuales: [ 4.094 -5.584  7.849], Error actual: 6958.758021000087
# Coeficientes actuales: [ 4.086 -5.592  7.848], Error actual: 6916.301292000084
# Coeficientes actuales: [ 4.076 -5.594  7.857], Error actual: 6872.841549000086
# Coeficientes actuales: [ 4.074 -5.604  7.857], Error actual: 6855.073893000087
# Coeficientes actuales: [ 4.071 -5.609  7.85 ], Error actual: 6836.069544000086
# Coeficientes actuales: [ 4.071 -5.614  7.842], Error actual: 6829.872299000086
# Coeficientes actuales: [ 4.063 -5.618  7.85 ], Error actual: 6793.324675000086
# Coeficientes actuales: [ 4.054 -5.622  7.852], Error actual: 6751.332784000087
# Coeficientes actuales: [ 4.044 -5.617  7.856], Error actual: 6713.671071000085
# Coeficientes actuales: [ 4.04  -5.621  7.859], Error actual: 6693.552146000089
# Coeficientes actuales: [ 4.03  -5.626  7.867], Error actual: 6647.95760500009
# Coeficientes actuales: [ 4.025 -5.634  7.873], Error actual: 6620.736850000088
# Coeficientes actuales: [ 4.024 -5.63   7.869], Error actual: 6619.217141000086
# Coeficientes actuales: [ 4.024 -5.634  7.863], Error actual: 6614.431437000087
# Coeficientes actuales: [ 4.018 -5.628  7.869], Error actual: 6595.461117000085
# Coeficientes actuales: [ 4.016 -5.633  7.861], Error actual: 6580.893590000089
# Coeficientes actuales: [ 4.012 -5.634  7.866], Error actual: 6564.052008000089
# Coeficientes actuales: [ 4.005 -5.634  7.869], Error actual: 6535.01152200009
# Coeficientes actuales: [ 4.003 -5.64   7.865], Error actual: 6520.447002000089
# Coeficientes actuales: [ 4.003 -5.642  7.865], Error actual: 6518.68300600009
# Coeficientes actuales: [ 3.994 -5.646  7.858], Error actual: 6475.786804000093
# Coeficientes actuales: [ 3.984 -5.646  7.856], Error actual: 6433.354524000091
# Coeficientes actuales: [ 3.984 -5.651  7.849], Error actual: 6427.572354000092
# Coeficientes actuales: [ 3.983 -5.648  7.846], Error actual: 6425.400563000094
# Coeficientes actuales: [ 3.974 -5.655  7.84 ], Error actual: 6380.424463000094
# Coeficientes actuales: [ 3.965 -5.66   7.835], Error actual: 6337.554650000095
# Coeficientes actuales: [ 3.957 -5.655  7.837], Error actual: 6309.028309000094
# Coeficientes actuales: [ 3.947 -5.656  7.829], Error actual: 6265.134298000093
# Coeficientes actuales: [ 3.945 -5.652  7.83 ], Error actual: 6260.507331000091
# Coeficientes actuales: [ 3.939 -5.652  7.829], Error actual: 6235.524570000096
# Coeficientes actuales: [ 3.93  -5.661  7.823], Error actual: 6189.558558000094
# ...
# Coeficientes actuales: [-1.659  8.258  1.359], Error actual: 2.4988460000005395
# Coeficientes actuales: [-1.663  8.266  1.35 ], Error actual: 2.4613950000003326
# Coeficientes actuales: [-1.664  8.264  1.346], Error actual: 2.456756000000203
# Coeficientes actuales: [-1.664  8.268  1.337], Error actual: 2.437293000000233
# Coeficientes actuales: [-1.666  8.277  1.329], Error actual: 2.4114540000001954
# Coeficientes actuales: [-1.668  8.28   1.322], Error actual: 2.3991240000000635
# Coeficientes actuales: [-1.668  8.282  1.319], Error actual: 2.3910210000000824
# Coeficientes actuales: [-1.667  8.288  1.317], Error actual: 2.3773660000002557
# Coeficientes actuales: [-1.674  8.296  1.307], Error actual: 2.3691089999998116
# Coeficientes actuales: [-1.668  8.3    1.311], Error actual: 2.3530130000003586
# Coeficientes actuales: [-1.67   8.304  1.313], Error actual: 2.3477730000002888
# Coeficientes actuales: [-1.67   8.299  1.305], Error actual: 2.343194000000166
# Coeficientes actuales: [-1.672  8.304  1.308], Error actual: 2.3408160000001117
# Coeficientes actuales: [-1.676  8.312  1.305], Error actual: 2.333004999999931
# Coeficientes actuales: [-1.673  8.314  1.303], Error actual: 2.317714000000187
# Coeficientes actuales: [-1.671  8.322  1.301], Error actual: 2.311506000000466
# Coeficientes actuales: [-1.678  8.329  1.3  ], Error actual: 2.295167000000053
# Coeficientes actuales: [-1.679  8.329  1.291], Error actual: 2.2878609999999333
# Coeficientes actuales: [-1.671  8.325  1.285], Error actual: 2.2830130000004463
# Coeficientes actuales: [-1.671  8.332  1.284], Error actual: 2.280019000000561
# Coeficientes actuales: [-1.677  8.334  1.285], Error actual: 2.2631500000001434
# Coeficientes actuales: [-1.675  8.333  1.277], Error actual: 2.2528930000002427
# Coeficientes actuales: [-1.678  8.339  1.273], Error actual: 2.2396740000000963
# Coeficientes actuales: [-1.676  8.343  1.275], Error actual: 2.237538000000328
# Coeficientes actuales: [-1.68   8.35   1.265], Error actual: 2.212725000000101
# Coeficientes actuales: [-1.676  8.353  1.261], Error actual: 2.208706000000437
# Coeficientes actuales: [-1.682  8.357  1.251], Error actual: 2.186698000000004
# Coeficientes actuales: [-1.681  8.357  1.25 ], Error actual: 2.182540000000076
# Coeficientes actuales: [-1.676  8.362  1.245], Error actual: 2.180045000000519
# Coeficientes actuales: [-1.681  8.37   1.246], Error actual: 2.157955000000282
# Coeficientes actuales: [-1.679  8.375  1.241], Error actual: 2.1545810000004963
# Coeficientes actuales: [-1.689  8.384  1.247], Error actual: 2.150021999999917
# Coeficientes actuales: [-1.682  8.384  1.247], Error actual: 2.14778900000045
# Coeficientes actuales: [-1.685  8.377  1.245], Error actual: 2.1476210000000915
# Coeficientes actuales: [-1.686  8.383  1.238], Error actual: 2.1298470000000855
# Coeficientes actuales: [-1.688  8.387  1.234], Error actual: 2.1229509999999854
# Coeficientes actuales: [-1.683  8.391  1.236], Error actual: 2.122728000000447
# Coeficientes actuales: [-1.689  8.391  1.227], Error actual: 2.110028999999946
# Coeficientes actuales: [-1.687  8.4    1.233], Error actual: 2.1002940000002814
# Coeficientes actuales: [-1.689  8.408  1.226], Error actual: 2.0795790000002374
# Coeficientes actuales: [-1.693  8.416  1.217], Error actual: 2.0601860000000305
# Coeficientes actuales: [-1.69   8.421  1.212], Error actual: 2.0453430000003205
# Coeficientes actuales: [-1.69   8.412  1.203], Error actual: 2.042733000000125
# Coeficientes actuales: [-1.691  8.421  1.205], Error actual: 2.033565000000215
# Coeficientes actuales: [-1.694  8.424  1.201], Error actual: 2.0280610000000174
# Coeficientes actuales: [-1.693  8.429  1.197], Error actual: 2.01268500000016
# Coeficientes actuales: [-1.698  8.437  1.187], Error actual: 2.001545999999872
# Coeficientes actuales: [-1.691  8.43   1.177], Error actual: 1.985122000000242
# Coeficientes actuales: [-1.69   8.432  1.17 ], Error actual: 1.9756560000003165
# Coeficientes actuales: [-1.689  8.423  1.161], Error actual: 1.9749890000001993
# Coeficientes actuales: [-1.689  8.425  1.152], Error actual: 1.9619440000001902
# Coeficientes actuales: [-1.692  8.431  1.147], Error actual: 1.9496340000000407
# Coeficientes actuales: [-1.691  8.433  1.142], Error actual: 1.9394640000001278
# Coeficientes actuales: [-1.69   8.441  1.134], Error actual: 1.9216470000003083
# Coeficientes actuales: [-1.692  8.445  1.125], Error actual: 1.9038420000001863
# Coeficientes actuales: [-1.693  8.451  1.129], Error actual: 1.899997000000228
# Coeficientes actuales: [-1.696  8.454  1.119], Error actual: 1.8875490000000057
# Coeficientes actuales: [-1.691  8.453  1.111], Error actual: 1.8816610000003335
# Coeficientes actuales: [-1.695  8.46   1.112], Error actual: 1.8687150000001547
# Coeficientes actuales: [-1.696  8.462  1.105], Error actual: 1.859445000000079
# Coeficientes actuales: [-1.696  8.462  1.097], Error actual: 1.8523570000000409
# Coeficientes actuales: [-1.697  8.465  1.099], Error actual: 1.8504130000000256
# Coeficientes actuales: [-1.695  8.463  1.096], Error actual: 1.848472000000132
# Coeficientes actuales: [-1.694  8.468  1.097], Error actual: 1.8446930000003001
# Coeficientes actuales: [-1.694  8.477  1.088], Error actual: 1.828799000000416
# Coeficientes actuales: [-1.701  8.482  1.086], Error actual: 1.8161709999999507
# Coeficientes actuales: [-1.694  8.487  1.077], Error actual: 1.8139620000005405
# Coeficientes actuales: [-1.701  8.48   1.075], Error actual: 1.8132379999998622
# Coeficientes actuales: [-1.703  8.484  1.067], Error actual: 1.8099299999997407
# Coeficientes actuales: [-1.7    8.488  1.068], Error actual: 1.7867840000000481
# Coeficientes actuales: [-1.699  8.489  1.058], Error actual: 1.7756080000000982
# Coeficientes actuales: [-1.701  8.496  1.054], Error actual: 1.7626510000000493
# Coeficientes actuales: [-1.7    8.496  1.045], Error actual: 1.7543890000000886
# Coeficientes actuales: [-1.696  8.496  1.036], Error actual: 1.7527840000003492
# Coeficientes actuales: [-1.702  8.503  1.028], Error actual: 1.7331109999999756
# Coeficientes actuales: [-1.704  8.509  1.025], Error actual: 1.7246099999999105
# Coeficientes actuales: [-1.706  8.515  1.029], Error actual: 1.7208259999998785
# Coeficientes actuales: [-1.706  8.519  1.032], Error actual: 1.7133189999999654
# Coeficientes actuales: [-1.703  8.514  1.023], Error actual: 1.7101740000000685
# Coeficientes actuales: [-1.707  8.521  1.02 ], Error actual: 1.70561199999987
# Coeficientes actuales: [-1.703  8.517  1.017], Error actual: 1.7007810000000936
# Coeficientes actuales: [-1.702  8.516  1.01 ], Error actual: 1.6970320000001156
# Coeficientes actuales: [-1.705  8.525  1.01 ], Error actual: 1.6843000000000434
# Coeficientes actuales: [-1.705  8.534  1.01 ], Error actual: 1.670899000000199
# Coeficientes actuales: [-1.708  8.539  1.007], Error actual: 1.661810000000043
# Coeficientes actuales: [-1.709  8.544  1.007], Error actual: 1.6546620000000491
# Coeficientes actuales: [-1.706  8.551  1.005], Error actual: 1.6511300000003981
# Coeficientes actuales: [-1.707  8.551  1.006], Error actual: 1.6479480000003242
# Coeficientes actuales: [-1.711  8.56   0.996], Error actual: 1.6231950000001234
# Coeficientes actuales: [-1.713  8.569  1.003], Error actual: 1.6177890000001613
# Coeficientes actuales: [-1.716  8.574  0.993], Error actual: 1.605788999999967
# Coeficientes actuales: [-1.719  8.58   0.992], Error actual: 1.604858999999833
# Coeficientes actuales: [-1.711  8.575  0.984], Error actual: 1.5986160000003327
# Coeficientes actuales: [-1.712  8.584  0.984], Error actual: 1.5918080000004171
# Coeficientes actuales: [-1.72   8.592  0.992], Error actual: 1.583423999999972
# Coeficientes actuales: [-1.715  8.601  0.987], Error actual: 1.5802530000004966
# Coeficientes actuales: [-1.722  8.61   0.986], Error actual: 1.5545160000001041
# Coeficientes actuales: [-1.719  8.612  0.982], Error actual: 1.5537470000003515
# Coeficientes actuales: [-1.719  8.609  0.975], Error actual: 1.5469250000002648
# Coeficientes actuales: [-1.718  8.618  0.966], Error actual: 1.5394120000004636
# Coeficientes actuales: [-1.725  8.615  0.96 ], Error actual: 1.5346999999998328
# Coeficientes actuales: [-1.723  8.61   0.955], Error actual: 1.5332619999998802
# Coeficientes actuales: [-1.723  8.614  0.951], Error actual: 1.5224459999999354
# Coeficientes actuales: [-1.721  8.623  0.945], Error actual: 1.503533000000221
# Coeficientes actuales: [-1.72   8.624  0.937], Error actual: 1.4977650000002767
# Coeficientes actuales: [-1.72   8.629  0.931], Error actual: 1.4898620000003382
# Coeficientes actuales: [-1.726  8.633  0.932], Error actual: 1.4839989999999477
# Coeficientes actuales: [-1.727  8.641  0.938], Error actual: 1.477240000000037
# Coeficientes actuales: [-1.728  8.644  0.93 ], Error actual: 1.468851999999976
# Coeficientes actuales: [-1.726  8.652  0.925], Error actual: 1.455085000000249
# Coeficientes actuales: [-1.726  8.655  0.924], Error actual: 1.452711000000297
# Coeficientes actuales: [-1.727  8.651  0.915], Error actual: 1.4462770000001077
# Coeficientes actuales: [-1.725  8.656  0.911], Error actual: 1.4428860000003334
# Coeficientes actuales: [-1.726  8.66   0.901], Error actual: 1.428525000000277
# Coeficientes actuales: [-1.728  8.668  0.901], Error actual: 1.4189970000002616
# Coeficientes actuales: [-1.732  8.674  0.903], Error actual: 1.4120610000000653
# Coeficientes actuales: [-1.731  8.68   0.902], Error actual: 1.4065470000002447
# Coeficientes actuales: [-1.732  8.683  0.9  ], Error actual: 1.4009910000002106
# Coeficientes actuales: [-1.73   8.68   0.891], Error actual: 1.398725000000272
# Coeficientes actuales: [-1.732  8.685  0.897], Error actual: 1.3970100000002328
# Coeficientes actuales: [-1.735  8.694  0.905], Error actual: 1.3945140000001968
# Coeficientes actuales: [-1.737  8.696  0.904], Error actual: 1.3916510000000695
# Coeficientes actuales: [-1.735  8.704  0.895], Error actual: 1.3805540000003262
# Coeficientes actuales: [-1.738  8.7    0.886], Error actual: 1.3740879999999756
# Coeficientes actuales: [-1.736  8.699  0.876], Error actual: 1.3648390000000667
# Coeficientes actuales: [-1.734  8.702  0.869], Error actual: 1.3583010000002465
# Coeficientes actuales: [-1.737  8.704  0.874], Error actual: 1.358283000000069
# Coeficientes actuales: [-1.739  8.706  0.869], Error actual: 1.3563539999999188
# Coeficientes actuales: [-1.737  8.71   0.861], Error actual: 1.3421260000001145
# Coeficientes actuales: [-1.735  8.719  0.852], Error actual: 1.3357200000003913
# Coeficientes actuales: [-1.737  8.711  0.853], Error actual: 1.335365000000092
# Coeficientes actuales: [-1.736  8.715  0.851], Error actual: 1.3317300000002312
# Coeficientes actuales: [-1.737  8.714  0.845], Error actual: 1.3267500000001087
# Coeficientes actuales: [-1.737  8.716  0.837], Error actual: 1.319434000000106
# Coeficientes actuales: [-1.739  8.724  0.835], Error actual: 1.3096900000000802
# Coeficientes actuales: [-1.739  8.729  0.832], Error actual: 1.3028920000001571
# Coeficientes actuales: [-1.745  8.738  0.833], Error actual: 1.3017739999998477
# Coeficientes actuales: [-1.74   8.73   0.832], Error actual: 1.3015000000000942
# Coeficientes actuales: [-1.737  8.739  0.822], Error actual: 1.299864000000449
# Coeficientes actuales: [-1.745  8.748  0.813], Error actual: 1.2741539999999276
# Coeficientes actuales: [-1.742  8.757  0.804], Error actual: 1.2608070000002867
# Coeficientes actuales: [-1.745  8.756  0.807], Error actual: 1.2596380000000422
# Coeficientes actuales: [-1.743  8.76   0.797], Error actual: 1.2514140000002296
# Coeficientes actuales: [-1.747  8.769  0.792], Error actual: 1.237644000000045
# Coeficientes actuales: [-1.746  8.771  0.785], Error actual: 1.2315300000001266
# Coeficientes actuales: [-1.744  8.777  0.779], Error actual: 1.2311260000003694
# Coeficientes actuales: [-1.746  8.783  0.778], Error actual: 1.2215270000003144
# Coeficientes actuales: [-1.748  8.792  0.773], Error actual: 1.2092210000002928
# Coeficientes actuales: [-1.75   8.796  0.775], Error actual: 1.2039490000002147
# Coeficientes actuales: [-1.751  8.793  0.769], Error actual: 1.201285000000054
# Coeficientes actuales: [-1.753  8.795  0.76 ], Error actual: 1.1985719999998776
# Coeficientes actuales: [-1.75   8.798  0.763], Error actual: 1.1944290000001905
# Coeficientes actuales: [-1.751  8.805  0.764], Error actual: 1.190316000000248
# Coeficientes actuales: [-1.756  8.809  0.767], Error actual: 1.1888539999999315
# Coeficientes actuales: [-1.752  8.81   0.758], Error actual: 1.1817840000002267
# Coeficientes actuales: [-1.752  8.81   0.748], Error actual: 1.1748440000001776
# Coeficientes actuales: [-1.754  8.813  0.741], Error actual: 1.1674540000000384
# Coeficientes actuales: [-1.757  8.822  0.75 ], Error actual: 1.1653150000000039
# Coeficientes actuales: [-1.756  8.83   0.74 ], Error actual: 1.1531480000001857
# Coeficientes actuales: [-1.759  8.837  0.749], Error actual: 1.152421000000117
# Coeficientes actuales: [-1.762  8.845  0.753], Error actual: 1.1500140000000358
# Coeficientes actuales: [-1.763  8.848  0.751], Error actual: 1.1471620000000031
# Coeficientes actuales: [-1.763  8.855  0.755], Error actual: 1.145237000000153
# Coeficientes actuales: [-1.765  8.854  0.746], Error actual: 1.1417869999999262
# Coeficientes actuales: [-1.76   8.846  0.739], Error actual: 1.1395570000001523
# Coeficientes actuales: [-1.759  8.851  0.732], Error actual: 1.1354640000002885
# Coeficientes actuales: [-1.764  8.859  0.726], Error actual: 1.1222310000000013
# Coeficientes actuales: [-1.766  8.868  0.732], Error actual: 1.1200440000000351
# Coeficientes actuales: [-1.765  8.876  0.724], Error actual: 1.110987000000222
# Coeficientes actuales: [-1.767  8.874  0.714], Error actual: 1.1048429999999794
# Coeficientes actuales: [-1.765  8.871  0.706], Error actual: 1.1007760000000448
# Coeficientes actuales: [-1.764  8.874  0.699], Error actual: 1.0949490000001492
# Coeficientes actuales: [-1.769  8.882  0.7  ], Error actual: 1.0933629999998955
# Coeficientes actuales: [-1.765  8.888  0.694], Error actual: 1.0870350000002937
# Coeficientes actuales: [-1.772  8.893  0.69 ], Error actual: 1.0846309999998056
# Coeficientes actuales: [-1.767  8.902  0.694], Error actual: 1.0836270000003925
# Coeficientes actuales: [-1.771  8.904  0.696], Error actual: 1.0734990000001186
# Coeficientes actuales: [-1.769  8.903  0.686], Error actual: 1.0693040000002112
# Coeficientes actuales: [-1.775  8.911  0.685], Error actual: 1.0673889999998687
# Coeficientes actuales: [-1.772  8.911  0.687], Error actual: 1.0636340000001212
# Coeficientes actuales: [-1.773  8.919  0.681], Error actual: 1.0557810000001562
# Coeficientes actuales: [-1.775  8.921  0.678], Error actual: 1.0526800000000152
# Coeficientes actuales: [-1.774  8.921  0.675], Error actual: 1.050234000000082
# Coeficientes actuales: [-1.777  8.928  0.677], Error actual: 1.0492259999999807
# Coeficientes actuales: [-1.776  8.931  0.674], Error actual: 1.0444710000000996
# Coeficientes actuales: [-1.774  8.936  0.664], Error actual: 1.0408440000003032
# Coeficientes actuales: [-1.776  8.941  0.669], Error actual: 1.0396660000002584
# Coeficientes actuales: [-1.776  8.938  0.659], Error actual: 1.0318050000001548
# Coeficientes actuales: [-1.775  8.941  0.652], Error actual: 1.0289080000002573
# Coeficientes actuales: [-1.778  8.942  0.656], Error actual: 1.0273760000000502
# Coeficientes actuales: [-1.782  8.95   0.652], Error actual: 1.0264799999998586
# Coeficientes actuales: [-1.778  8.95   0.655], Error actual: 1.0242370000001957
# Coeficientes actuales: [-1.782  8.952  0.652], Error actual: 1.0239159999998921
# Coeficientes actuales: [-1.781  8.96   0.66 ], Error actual: 1.022803000000159
# Coeficientes actuales: [-1.784  8.961  0.657], Error actual: 1.0227539999999202
# Coeficientes actuales: [-1.781  8.955  0.647], Error actual: 1.0160370000000039
# Coeficientes actuales: [-1.781  8.954  0.637], Error actual: 1.0119339999999384
# Coeficientes actuales: [-1.779  8.957  0.629], Error actual: 1.0040610000001138
# Coeficientes actuales: [-1.778  8.961  0.626], Error actual: 1.0038630000002537
# Coeficientes actuales: [-1.778  8.968  0.616], Error actual: 0.9990520000003343
# array([-1.778,  8.968,  0.616])
